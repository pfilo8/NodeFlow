# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/avocado/avocado.csv', index_col=0)

# %%
x = df.drop(columns = ['Date', 'AveragePrice'])
x = pd.get_dummies(x)
y = df[['AveragePrice']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((14599, 65), (3650, 65))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 0.3857, Validation metric: 0.3950
# Estimator 1/2000, Train metric: 0.3711, Validation metric: 0.3802
# Estimator 2/2000, Train metric: 0.3588, Validation metric: 0.3681
# Estimator 3/2000, Train metric: 0.3479, Validation metric: 0.3570
# Estimator 4/2000, Train metric: 0.3383, Validation metric: 0.3475
# Estimator 5/2000, Train metric: 0.3306, Validation metric: 0.3396
# Estimator 6/2000, Train metric: 0.3236, Validation metric: 0.3324
# Estimator 7/2000, Train metric: 0.3177, Validation metric: 0.3265
# Estimator 8/2000, Train metric: 0.3124, Validation metric: 0.3212
# Estimator 9/2000, Train metric: 0.3077, Validation metric: 0.3165
# Estimator 10/2000, Train metric: 0.3039, Validation metric: 0.3126
# Estimator 11/2000, Train metric: 0.3006, Validation metric: 0.3093
# Estimator 12/2000, Train metric: 0.2978, Validation metric: 0.3066
# Estimator 13/2000, Train metric: 0.2949, Validation metric: 0.3036
# Estimator 14/2000, Train metric: 0.2921, Validation metric: 0.3010
# Estimator 15/2000, Train metric: 0.2897, Validation metric: 0.2983
# Estimator 16/2000, Train metric: 0.2876, Validation metric: 0.2964
# Estimator 17/2000, Train metric: 0.2857, Validation metric: 0.2943
# Estimator 18/2000, Train metric: 0.2840, Validation metric: 0.2925
# Estimator 19/2000, Train metric: 0.2824, Validation metric: 0.2908
# Estimator 20/2000, Train metric: 0.2810, Validation metric: 0.2894
# Estimator 21/2000, Train metric: 0.2796, Validation metric: 0.2880
# Estimator 22/2000, Train metric: 0.2782, Validation metric: 0.2866
# Estimator 23/2000, Train metric: 0.2771, Validation metric: 0.2853
# Estimator 24/2000, Train metric: 0.2760, Validation metric: 0.2843
# Estimator 25/2000, Train metric: 0.2750, Validation metric: 0.2833
# Estimator 26/2000, Train metric: 0.2741, Validation metric: 0.2823
# Estimator 27/2000, Train metric: 0.2733, Validation metric: 0.2816
# Estimator 28/2000, Train metric: 0.2724, Validation metric: 0.2805
# Estimator 29/2000, Train metric: 0.2716, Validation metric: 0.2796
# Estimator 30/2000, Train metric: 0.2709, Validation metric: 0.2788
# Estimator 31/2000, Train metric: 0.2703, Validation metric: 0.2783
# Estimator 32/2000, Train metric: 0.2693, Validation metric: 0.2774
# Estimator 33/2000, Train metric: 0.2688, Validation metric: 0.2768
# Estimator 34/2000, Train metric: 0.2678, Validation metric: 0.2757
# Estimator 35/2000, Train metric: 0.2674, Validation metric: 0.2753
# Estimator 36/2000, Train metric: 0.2668, Validation metric: 0.2747
# Estimator 37/2000, Train metric: 0.2663, Validation metric: 0.2742
# Estimator 38/2000, Train metric: 0.2660, Validation metric: 0.2738
# Estimator 39/2000, Train metric: 0.2652, Validation metric: 0.2731
# Estimator 40/2000, Train metric: 0.2648, Validation metric: 0.2727
# Estimator 41/2000, Train metric: 0.2640, Validation metric: 0.2718
# Estimator 42/2000, Train metric: 0.2636, Validation metric: 0.2715
# Estimator 43/2000, Train metric: 0.2631, Validation metric: 0.2709
# Estimator 44/2000, Train metric: 0.2628, Validation metric: 0.2706
# Estimator 45/2000, Train metric: 0.2625, Validation metric: 0.2703
# Estimator 46/2000, Train metric: 0.2617, Validation metric: 0.2694
# Estimator 47/2000, Train metric: 0.2614, Validation metric: 0.2691
# Estimator 48/2000, Train metric: 0.2611, Validation metric: 0.2688
# Estimator 49/2000, Train metric: 0.2605, Validation metric: 0.2681
# Estimator 50/2000, Train metric: 0.2601, Validation metric: 0.2678
# Estimator 51/2000, Train metric: 0.2597, Validation metric: 0.2673
# Estimator 52/2000, Train metric: 0.2594, Validation metric: 0.2669
# Estimator 53/2000, Train metric: 0.2591, Validation metric: 0.2666
# Estimator 54/2000, Train metric: 0.2586, Validation metric: 0.2662
# Estimator 55/2000, Train metric: 0.2583, Validation metric: 0.2658
# Estimator 56/2000, Train metric: 0.2581, Validation metric: 0.2656
# Estimator 57/2000, Train metric: 0.2576, Validation metric: 0.2651
# Estimator 58/2000, Train metric: 0.2574, Validation metric: 0.2649
# Estimator 59/2000, Train metric: 0.2571, Validation metric: 0.2646
# Estimator 60/2000, Train metric: 0.2568, Validation metric: 0.2644
# Estimator 61/2000, Train metric: 0.2567, Validation metric: 0.2642
# Estimator 62/2000, Train metric: 0.2565, Validation metric: 0.2640
# Estimator 63/2000, Train metric: 0.2560, Validation metric: 0.2634
# Estimator 64/2000, Train metric: 0.2557, Validation metric: 0.2630
# Estimator 65/2000, Train metric: 0.2555, Validation metric: 0.2628
# Estimator 66/2000, Train metric: 0.2552, Validation metric: 0.2625
# Estimator 67/2000, Train metric: 0.2545, Validation metric: 0.2619
# Estimator 68/2000, Train metric: 0.2540, Validation metric: 0.2612
# Estimator 69/2000, Train metric: 0.2534, Validation metric: 0.2605
# Estimator 70/2000, Train metric: 0.2531, Validation metric: 0.2602
# Estimator 71/2000, Train metric: 0.2527, Validation metric: 0.2597
# Estimator 72/2000, Train metric: 0.2526, Validation metric: 0.2596
# Estimator 73/2000, Train metric: 0.2524, Validation metric: 0.2595
# Estimator 74/2000, Train metric: 0.2518, Validation metric: 0.2588
# Estimator 75/2000, Train metric: 0.2513, Validation metric: 0.2581
# Estimator 76/2000, Train metric: 0.2510, Validation metric: 0.2578
# Estimator 77/2000, Train metric: 0.2507, Validation metric: 0.2575
# Estimator 78/2000, Train metric: 0.2504, Validation metric: 0.2573
# Estimator 79/2000, Train metric: 0.2503, Validation metric: 0.2571
# Estimator 80/2000, Train metric: 0.2498, Validation metric: 0.2566
# Estimator 81/2000, Train metric: 0.2497, Validation metric: 0.2565
# Estimator 82/2000, Train metric: 0.2492, Validation metric: 0.2560
# Estimator 83/2000, Train metric: 0.2488, Validation metric: 0.2555
# Estimator 84/2000, Train metric: 0.2486, Validation metric: 0.2553
# Estimator 85/2000, Train metric: 0.2482, Validation metric: 0.2550
# Estimator 86/2000, Train metric: 0.2480, Validation metric: 0.2548
# Estimator 87/2000, Train metric: 0.2479, Validation metric: 0.2547
# Estimator 88/2000, Train metric: 0.2475, Validation metric: 0.2543
# Estimator 89/2000, Train metric: 0.2474, Validation metric: 0.2542
# Estimator 90/2000, Train metric: 0.2472, Validation metric: 0.2540
# Estimator 91/2000, Train metric: 0.2470, Validation metric: 0.2537
# Estimator 92/2000, Train metric: 0.2467, Validation metric: 0.2534
# Estimator 93/2000, Train metric: 0.2466, Validation metric: 0.2534
# Estimator 94/2000, Train metric: 0.2464, Validation metric: 0.2532
# Estimator 95/2000, Train metric: 0.2463, Validation metric: 0.2530
# Estimator 96/2000, Train metric: 0.2462, Validation metric: 0.2529
# Estimator 97/2000, Train metric: 0.2460, Validation metric: 0.2527
# Estimator 98/2000, Train metric: 0.2457, Validation metric: 0.2524
# Estimator 99/2000, Train metric: 0.2455, Validation metric: 0.2520
# Estimator 100/2000, Train metric: 0.2452, Validation metric: 0.2517
# Estimator 101/2000, Train metric: 0.2450, Validation metric: 0.2514
# Estimator 102/2000, Train metric: 0.2448, Validation metric: 0.2513
# Estimator 103/2000, Train metric: 0.2445, Validation metric: 0.2509
# Estimator 104/2000, Train metric: 0.2442, Validation metric: 0.2507
# Estimator 105/2000, Train metric: 0.2441, Validation metric: 0.2506
# Estimator 106/2000, Train metric: 0.2437, Validation metric: 0.2501
# Estimator 107/2000, Train metric: 0.2436, Validation metric: 0.2500
# Estimator 108/2000, Train metric: 0.2432, Validation metric: 0.2494
# Estimator 109/2000, Train metric: 0.2430, Validation metric: 0.2493
# Estimator 110/2000, Train metric: 0.2426, Validation metric: 0.2489
# Estimator 111/2000, Train metric: 0.2421, Validation metric: 0.2484
# Estimator 112/2000, Train metric: 0.2419, Validation metric: 0.2482
# Estimator 113/2000, Train metric: 0.2414, Validation metric: 0.2477
# Estimator 114/2000, Train metric: 0.2413, Validation metric: 0.2476
# Estimator 115/2000, Train metric: 0.2411, Validation metric: 0.2473
# Estimator 116/2000, Train metric: 0.2409, Validation metric: 0.2471
# Estimator 117/2000, Train metric: 0.2407, Validation metric: 0.2469
# Estimator 118/2000, Train metric: 0.2406, Validation metric: 0.2468
# Estimator 119/2000, Train metric: 0.2404, Validation metric: 0.2465
# Estimator 120/2000, Train metric: 0.2404, Validation metric: 0.2464
# Estimator 121/2000, Train metric: 0.2401, Validation metric: 0.2461
# Estimator 122/2000, Train metric: 0.2400, Validation metric: 0.2460
# Estimator 123/2000, Train metric: 0.2399, Validation metric: 0.2459
# Estimator 124/2000, Train metric: 0.2397, Validation metric: 0.2458
# Estimator 125/2000, Train metric: 0.2396, Validation metric: 0.2457
# Estimator 126/2000, Train metric: 0.2394, Validation metric: 0.2455
# Estimator 127/2000, Train metric: 0.2392, Validation metric: 0.2453
# Estimator 128/2000, Train metric: 0.2391, Validation metric: 0.2452
# Estimator 129/2000, Train metric: 0.2389, Validation metric: 0.2449
# Estimator 130/2000, Train metric: 0.2387, Validation metric: 0.2448
# Estimator 131/2000, Train metric: 0.2386, Validation metric: 0.2447
# Estimator 132/2000, Train metric: 0.2384, Validation metric: 0.2444
# Estimator 133/2000, Train metric: 0.2382, Validation metric: 0.2443
# Estimator 134/2000, Train metric: 0.2381, Validation metric: 0.2442
# Estimator 135/2000, Train metric: 0.2377, Validation metric: 0.2438
# Estimator 136/2000, Train metric: 0.2373, Validation metric: 0.2433
# Estimator 137/2000, Train metric: 0.2371, Validation metric: 0.2431
# Estimator 138/2000, Train metric: 0.2369, Validation metric: 0.2428
# Estimator 139/2000, Train metric: 0.2367, Validation metric: 0.2426
# Estimator 140/2000, Train metric: 0.2366, Validation metric: 0.2425
# Estimator 141/2000, Train metric: 0.2364, Validation metric: 0.2423
# Estimator 142/2000, Train metric: 0.2363, Validation metric: 0.2422
# Estimator 143/2000, Train metric: 0.2362, Validation metric: 0.2421
# Estimator 144/2000, Train metric: 0.2361, Validation metric: 0.2420
# Estimator 145/2000, Train metric: 0.2358, Validation metric: 0.2417
# Estimator 146/2000, Train metric: 0.2356, Validation metric: 0.2415
# Estimator 147/2000, Train metric: 0.2356, Validation metric: 0.2414
# Estimator 148/2000, Train metric: 0.2354, Validation metric: 0.2412
# Estimator 149/2000, Train metric: 0.2350, Validation metric: 0.2408
# Estimator 150/2000, Train metric: 0.2349, Validation metric: 0.2406
# Estimator 151/2000, Train metric: 0.2348, Validation metric: 0.2405
# Estimator 152/2000, Train metric: 0.2346, Validation metric: 0.2404
# Estimator 153/2000, Train metric: 0.2345, Validation metric: 0.2402
# Estimator 154/2000, Train metric: 0.2343, Validation metric: 0.2401
# Estimator 155/2000, Train metric: 0.2342, Validation metric: 0.2399
# Estimator 156/2000, Train metric: 0.2341, Validation metric: 0.2398
# Estimator 157/2000, Train metric: 0.2340, Validation metric: 0.2397
# Estimator 158/2000, Train metric: 0.2340, Validation metric: 0.2396
# Estimator 159/2000, Train metric: 0.2339, Validation metric: 0.2396
# Estimator 160/2000, Train metric: 0.2338, Validation metric: 0.2395
# Estimator 161/2000, Train metric: 0.2337, Validation metric: 0.2394
# Estimator 162/2000, Train metric: 0.2334, Validation metric: 0.2391
# Estimator 163/2000, Train metric: 0.2331, Validation metric: 0.2388
# Estimator 164/2000, Train metric: 0.2329, Validation metric: 0.2386
# Estimator 165/2000, Train metric: 0.2329, Validation metric: 0.2386
# Estimator 166/2000, Train metric: 0.2328, Validation metric: 0.2385
# Estimator 167/2000, Train metric: 0.2327, Validation metric: 0.2384
# Estimator 168/2000, Train metric: 0.2326, Validation metric: 0.2382
# Estimator 169/2000, Train metric: 0.2323, Validation metric: 0.2379
# Estimator 170/2000, Train metric: 0.2322, Validation metric: 0.2378
# Estimator 171/2000, Train metric: 0.2321, Validation metric: 0.2377
# Estimator 172/2000, Train metric: 0.2319, Validation metric: 0.2375
# Estimator 173/2000, Train metric: 0.2318, Validation metric: 0.2374
# Estimator 174/2000, Train metric: 0.2316, Validation metric: 0.2372
# Estimator 175/2000, Train metric: 0.2315, Validation metric: 0.2371
# Estimator 176/2000, Train metric: 0.2314, Validation metric: 0.2370
# Estimator 177/2000, Train metric: 0.2312, Validation metric: 0.2368
# Estimator 178/2000, Train metric: 0.2310, Validation metric: 0.2366
# Estimator 179/2000, Train metric: 0.2309, Validation metric: 0.2365
# Estimator 180/2000, Train metric: 0.2307, Validation metric: 0.2363
# Estimator 181/2000, Train metric: 0.2305, Validation metric: 0.2361
# Estimator 182/2000, Train metric: 0.2303, Validation metric: 0.2359
# Estimator 183/2000, Train metric: 0.2302, Validation metric: 0.2357
# Estimator 184/2000, Train metric: 0.2300, Validation metric: 0.2354
# Estimator 185/2000, Train metric: 0.2299, Validation metric: 0.2353
# Estimator 186/2000, Train metric: 0.2298, Validation metric: 0.2353
# Estimator 187/2000, Train metric: 0.2296, Validation metric: 0.2350
# Estimator 188/2000, Train metric: 0.2295, Validation metric: 0.2349
# Estimator 189/2000, Train metric: 0.2295, Validation metric: 0.2349
# Estimator 190/2000, Train metric: 0.2293, Validation metric: 0.2347
# Estimator 191/2000, Train metric: 0.2292, Validation metric: 0.2346
# Estimator 192/2000, Train metric: 0.2292, Validation metric: 0.2345
# Estimator 193/2000, Train metric: 0.2291, Validation metric: 0.2344
# Estimator 194/2000, Train metric: 0.2290, Validation metric: 0.2343
# Estimator 195/2000, Train metric: 0.2289, Validation metric: 0.2343
# Estimator 196/2000, Train metric: 0.2289, Validation metric: 0.2342
# Estimator 197/2000, Train metric: 0.2287, Validation metric: 0.2340
# Estimator 198/2000, Train metric: 0.2286, Validation metric: 0.2338
# Estimator 199/2000, Train metric: 0.2285, Validation metric: 0.2336
# Estimator 200/2000, Train metric: 0.2284, Validation metric: 0.2336
# Estimator 201/2000, Train metric: 0.2282, Validation metric: 0.2334
# Estimator 202/2000, Train metric: 0.2282, Validation metric: 0.2333
# Estimator 203/2000, Train metric: 0.2280, Validation metric: 0.2331
# Estimator 204/2000, Train metric: 0.2279, Validation metric: 0.2330
# Estimator 205/2000, Train metric: 0.2276, Validation metric: 0.2327
# Estimator 206/2000, Train metric: 0.2274, Validation metric: 0.2325
# Estimator 207/2000, Train metric: 0.2273, Validation metric: 0.2324
# Estimator 208/2000, Train metric: 0.2272, Validation metric: 0.2323
# Estimator 209/2000, Train metric: 0.2271, Validation metric: 0.2321
# Estimator 210/2000, Train metric: 0.2269, Validation metric: 0.2320
# Estimator 211/2000, Train metric: 0.2268, Validation metric: 0.2319
# Estimator 212/2000, Train metric: 0.2267, Validation metric: 0.2318
# Estimator 213/2000, Train metric: 0.2266, Validation metric: 0.2317
# Estimator 214/2000, Train metric: 0.2264, Validation metric: 0.2316
# Estimator 215/2000, Train metric: 0.2263, Validation metric: 0.2314
# Estimator 216/2000, Train metric: 0.2261, Validation metric: 0.2312
# Estimator 217/2000, Train metric: 0.2259, Validation metric: 0.2310
# Estimator 218/2000, Train metric: 0.2258, Validation metric: 0.2309
# Estimator 219/2000, Train metric: 0.2256, Validation metric: 0.2307
# Estimator 220/2000, Train metric: 0.2254, Validation metric: 0.2305
# Estimator 221/2000, Train metric: 0.2253, Validation metric: 0.2304
# Estimator 222/2000, Train metric: 0.2252, Validation metric: 0.2303
# Estimator 223/2000, Train metric: 0.2252, Validation metric: 0.2303
# Estimator 224/2000, Train metric: 0.2251, Validation metric: 0.2302
# Estimator 225/2000, Train metric: 0.2250, Validation metric: 0.2301
# Estimator 226/2000, Train metric: 0.2250, Validation metric: 0.2301
# Estimator 227/2000, Train metric: 0.2249, Validation metric: 0.2300
# Estimator 228/2000, Train metric: 0.2248, Validation metric: 0.2299
# Estimator 229/2000, Train metric: 0.2246, Validation metric: 0.2296
# Estimator 230/2000, Train metric: 0.2245, Validation metric: 0.2294
# Estimator 231/2000, Train metric: 0.2244, Validation metric: 0.2293
# Estimator 232/2000, Train metric: 0.2243, Validation metric: 0.2293
# Estimator 233/2000, Train metric: 0.2242, Validation metric: 0.2291
# Estimator 234/2000, Train metric: 0.2241, Validation metric: 0.2290
# Estimator 235/2000, Train metric: 0.2239, Validation metric: 0.2288
# Estimator 236/2000, Train metric: 0.2238, Validation metric: 0.2288
# Estimator 237/2000, Train metric: 0.2237, Validation metric: 0.2286
# Estimator 238/2000, Train metric: 0.2236, Validation metric: 0.2285
# Estimator 239/2000, Train metric: 0.2235, Validation metric: 0.2284
# Estimator 240/2000, Train metric: 0.2234, Validation metric: 0.2283
# Estimator 241/2000, Train metric: 0.2232, Validation metric: 0.2281
# Estimator 242/2000, Train metric: 0.2231, Validation metric: 0.2280
# Estimator 243/2000, Train metric: 0.2229, Validation metric: 0.2278
# Estimator 244/2000, Train metric: 0.2228, Validation metric: 0.2277
# Estimator 245/2000, Train metric: 0.2228, Validation metric: 0.2277
# Estimator 246/2000, Train metric: 0.2226, Validation metric: 0.2275
# Estimator 247/2000, Train metric: 0.2225, Validation metric: 0.2274
# Estimator 248/2000, Train metric: 0.2224, Validation metric: 0.2273
# Estimator 249/2000, Train metric: 0.2223, Validation metric: 0.2272
# Estimator 250/2000, Train metric: 0.2222, Validation metric: 0.2270
# Estimator 251/2000, Train metric: 0.2221, Validation metric: 0.2270
# Estimator 252/2000, Train metric: 0.2220, Validation metric: 0.2268
# Estimator 253/2000, Train metric: 0.2219, Validation metric: 0.2267
# Estimator 254/2000, Train metric: 0.2218, Validation metric: 0.2266
# Estimator 255/2000, Train metric: 0.2217, Validation metric: 0.2266
# Estimator 256/2000, Train metric: 0.2217, Validation metric: 0.2265
# Estimator 257/2000, Train metric: 0.2216, Validation metric: 0.2265
# Estimator 258/2000, Train metric: 0.2216, Validation metric: 0.2264
# Estimator 259/2000, Train metric: 0.2215, Validation metric: 0.2263
# Estimator 260/2000, Train metric: 0.2214, Validation metric: 0.2262
# Estimator 261/2000, Train metric: 0.2213, Validation metric: 0.2262
# Estimator 262/2000, Train metric: 0.2213, Validation metric: 0.2261
# Estimator 263/2000, Train metric: 0.2213, Validation metric: 0.2261
# Estimator 264/2000, Train metric: 0.2212, Validation metric: 0.2260
# Estimator 265/2000, Train metric: 0.2211, Validation metric: 0.2259
# Estimator 266/2000, Train metric: 0.2211, Validation metric: 0.2258
# Estimator 267/2000, Train metric: 0.2209, Validation metric: 0.2257
# Estimator 268/2000, Train metric: 0.2208, Validation metric: 0.2256
# Estimator 269/2000, Train metric: 0.2206, Validation metric: 0.2254
# Estimator 270/2000, Train metric: 0.2205, Validation metric: 0.2253
# Estimator 271/2000, Train metric: 0.2204, Validation metric: 0.2252
# Estimator 272/2000, Train metric: 0.2203, Validation metric: 0.2251
# Estimator 273/2000, Train metric: 0.2201, Validation metric: 0.2249
# Estimator 274/2000, Train metric: 0.2200, Validation metric: 0.2248
# Estimator 275/2000, Train metric: 0.2199, Validation metric: 0.2247
# Estimator 276/2000, Train metric: 0.2199, Validation metric: 0.2246
# Estimator 277/2000, Train metric: 0.2198, Validation metric: 0.2245
# Estimator 278/2000, Train metric: 0.2197, Validation metric: 0.2244
# Estimator 279/2000, Train metric: 0.2196, Validation metric: 0.2244
# Estimator 280/2000, Train metric: 0.2195, Validation metric: 0.2242
# Estimator 281/2000, Train metric: 0.2194, Validation metric: 0.2242
# Estimator 282/2000, Train metric: 0.2194, Validation metric: 0.2241
# Estimator 283/2000, Train metric: 0.2192, Validation metric: 0.2239
# Estimator 284/2000, Train metric: 0.2191, Validation metric: 0.2238
# Estimator 285/2000, Train metric: 0.2191, Validation metric: 0.2238
# Estimator 286/2000, Train metric: 0.2191, Validation metric: 0.2238
# Estimator 287/2000, Train metric: 0.2190, Validation metric: 0.2237
# Estimator 288/2000, Train metric: 0.2190, Validation metric: 0.2237
# Estimator 289/2000, Train metric: 0.2190, Validation metric: 0.2237
# Estimator 290/2000, Train metric: 0.2189, Validation metric: 0.2235
# Estimator 291/2000, Train metric: 0.2187, Validation metric: 0.2234
# Estimator 292/2000, Train metric: 0.2186, Validation metric: 0.2233
# Estimator 293/2000, Train metric: 0.2184, Validation metric: 0.2231
# Estimator 294/2000, Train metric: 0.2184, Validation metric: 0.2231
# Estimator 295/2000, Train metric: 0.2183, Validation metric: 0.2230
# Estimator 296/2000, Train metric: 0.2182, Validation metric: 0.2229
# Estimator 297/2000, Train metric: 0.2181, Validation metric: 0.2228
# Estimator 298/2000, Train metric: 0.2180, Validation metric: 0.2227
# Estimator 299/2000, Train metric: 0.2178, Validation metric: 0.2225
# Estimator 300/2000, Train metric: 0.2178, Validation metric: 0.2224
# Estimator 301/2000, Train metric: 0.2177, Validation metric: 0.2224
# Estimator 302/2000, Train metric: 0.2177, Validation metric: 0.2224
# Estimator 303/2000, Train metric: 0.2176, Validation metric: 0.2223
# Estimator 304/2000, Train metric: 0.2175, Validation metric: 0.2222
# Estimator 305/2000, Train metric: 0.2175, Validation metric: 0.2221
# Estimator 306/2000, Train metric: 0.2174, Validation metric: 0.2220
# Estimator 307/2000, Train metric: 0.2173, Validation metric: 0.2219
# Estimator 308/2000, Train metric: 0.2172, Validation metric: 0.2218
# Estimator 309/2000, Train metric: 0.2171, Validation metric: 0.2218
# Estimator 310/2000, Train metric: 0.2171, Validation metric: 0.2217
# Estimator 311/2000, Train metric: 0.2171, Validation metric: 0.2217
# Estimator 312/2000, Train metric: 0.2170, Validation metric: 0.2216
# Estimator 313/2000, Train metric: 0.2169, Validation metric: 0.2216
# Estimator 314/2000, Train metric: 0.2168, Validation metric: 0.2215
# Estimator 315/2000, Train metric: 0.2168, Validation metric: 0.2214
# Estimator 316/2000, Train metric: 0.2167, Validation metric: 0.2214
# Estimator 317/2000, Train metric: 0.2167, Validation metric: 0.2213
# Estimator 318/2000, Train metric: 0.2167, Validation metric: 0.2213
# Estimator 319/2000, Train metric: 0.2166, Validation metric: 0.2212
# Estimator 320/2000, Train metric: 0.2165, Validation metric: 0.2211
# Estimator 321/2000, Train metric: 0.2163, Validation metric: 0.2209
# Estimator 322/2000, Train metric: 0.2163, Validation metric: 0.2208
# Estimator 323/2000, Train metric: 0.2162, Validation metric: 0.2208
# Estimator 324/2000, Train metric: 0.2162, Validation metric: 0.2207
# Estimator 325/2000, Train metric: 0.2161, Validation metric: 0.2206
# Estimator 326/2000, Train metric: 0.2160, Validation metric: 0.2206
# Estimator 327/2000, Train metric: 0.2159, Validation metric: 0.2205
# Estimator 328/2000, Train metric: 0.2159, Validation metric: 0.2204
# Estimator 329/2000, Train metric: 0.2158, Validation metric: 0.2203
# Estimator 330/2000, Train metric: 0.2157, Validation metric: 0.2202
# Estimator 331/2000, Train metric: 0.2156, Validation metric: 0.2201
# Estimator 332/2000, Train metric: 0.2156, Validation metric: 0.2201
# Estimator 333/2000, Train metric: 0.2155, Validation metric: 0.2200
# Estimator 334/2000, Train metric: 0.2155, Validation metric: 0.2199
# Estimator 335/2000, Train metric: 0.2154, Validation metric: 0.2198
# Estimator 336/2000, Train metric: 0.2153, Validation metric: 0.2197
# Estimator 337/2000, Train metric: 0.2152, Validation metric: 0.2197
# Estimator 338/2000, Train metric: 0.2152, Validation metric: 0.2196
# Estimator 339/2000, Train metric: 0.2150, Validation metric: 0.2194
# Estimator 340/2000, Train metric: 0.2149, Validation metric: 0.2193
# Estimator 341/2000, Train metric: 0.2149, Validation metric: 0.2192
# Estimator 342/2000, Train metric: 0.2148, Validation metric: 0.2191
# Estimator 343/2000, Train metric: 0.2147, Validation metric: 0.2190
# Estimator 344/2000, Train metric: 0.2146, Validation metric: 0.2189
# Estimator 345/2000, Train metric: 0.2146, Validation metric: 0.2188
# Estimator 346/2000, Train metric: 0.2145, Validation metric: 0.2188
# Estimator 347/2000, Train metric: 0.2145, Validation metric: 0.2187
# Estimator 348/2000, Train metric: 0.2144, Validation metric: 0.2186
# Estimator 349/2000, Train metric: 0.2143, Validation metric: 0.2185
# Estimator 350/2000, Train metric: 0.2142, Validation metric: 0.2184
# Estimator 351/2000, Train metric: 0.2141, Validation metric: 0.2183
# Estimator 352/2000, Train metric: 0.2140, Validation metric: 0.2182
# Estimator 353/2000, Train metric: 0.2139, Validation metric: 0.2181
# Estimator 354/2000, Train metric: 0.2139, Validation metric: 0.2181
# Estimator 355/2000, Train metric: 0.2137, Validation metric: 0.2179
# Estimator 356/2000, Train metric: 0.2136, Validation metric: 0.2178
# Estimator 357/2000, Train metric: 0.2135, Validation metric: 0.2177
# Estimator 358/2000, Train metric: 0.2135, Validation metric: 0.2177
# Estimator 359/2000, Train metric: 0.2134, Validation metric: 0.2176
# Estimator 360/2000, Train metric: 0.2134, Validation metric: 0.2176
# Estimator 361/2000, Train metric: 0.2133, Validation metric: 0.2175
# Estimator 362/2000, Train metric: 0.2133, Validation metric: 0.2174
# Estimator 363/2000, Train metric: 0.2132, Validation metric: 0.2174
# Estimator 364/2000, Train metric: 0.2131, Validation metric: 0.2173
# Estimator 365/2000, Train metric: 0.2131, Validation metric: 0.2172
# Estimator 366/2000, Train metric: 0.2130, Validation metric: 0.2172
# Estimator 367/2000, Train metric: 0.2129, Validation metric: 0.2171
# Estimator 368/2000, Train metric: 0.2128, Validation metric: 0.2170
# Estimator 369/2000, Train metric: 0.2128, Validation metric: 0.2169
# Estimator 370/2000, Train metric: 0.2127, Validation metric: 0.2169
# Estimator 371/2000, Train metric: 0.2127, Validation metric: 0.2168
# Estimator 372/2000, Train metric: 0.2126, Validation metric: 0.2168
# Estimator 373/2000, Train metric: 0.2126, Validation metric: 0.2167
# Estimator 374/2000, Train metric: 0.2125, Validation metric: 0.2166
# Estimator 375/2000, Train metric: 0.2125, Validation metric: 0.2166
# Estimator 376/2000, Train metric: 0.2124, Validation metric: 0.2165
# Estimator 377/2000, Train metric: 0.2124, Validation metric: 0.2165
# Estimator 378/2000, Train metric: 0.2123, Validation metric: 0.2164
# Estimator 379/2000, Train metric: 0.2123, Validation metric: 0.2164
# Estimator 380/2000, Train metric: 0.2122, Validation metric: 0.2163
# Estimator 381/2000, Train metric: 0.2122, Validation metric: 0.2163
# Estimator 382/2000, Train metric: 0.2120, Validation metric: 0.2161
# Estimator 383/2000, Train metric: 0.2120, Validation metric: 0.2160
# Estimator 384/2000, Train metric: 0.2119, Validation metric: 0.2159
# Estimator 385/2000, Train metric: 0.2118, Validation metric: 0.2159
# Estimator 386/2000, Train metric: 0.2118, Validation metric: 0.2159
# Estimator 387/2000, Train metric: 0.2118, Validation metric: 0.2158
# Estimator 388/2000, Train metric: 0.2117, Validation metric: 0.2158
# Estimator 389/2000, Train metric: 0.2117, Validation metric: 0.2157
# Estimator 390/2000, Train metric: 0.2115, Validation metric: 0.2155
# Estimator 391/2000, Train metric: 0.2115, Validation metric: 0.2154
# Estimator 392/2000, Train metric: 0.2114, Validation metric: 0.2154
# Estimator 393/2000, Train metric: 0.2114, Validation metric: 0.2153
# Estimator 394/2000, Train metric: 0.2113, Validation metric: 0.2152
# Estimator 395/2000, Train metric: 0.2112, Validation metric: 0.2152
# Estimator 396/2000, Train metric: 0.2112, Validation metric: 0.2151
# Estimator 397/2000, Train metric: 0.2111, Validation metric: 0.2150
# Estimator 398/2000, Train metric: 0.2111, Validation metric: 0.2150
# Estimator 399/2000, Train metric: 0.2110, Validation metric: 0.2150
# Estimator 400/2000, Train metric: 0.2109, Validation metric: 0.2149
# Estimator 401/2000, Train metric: 0.2109, Validation metric: 0.2149
# Estimator 402/2000, Train metric: 0.2109, Validation metric: 0.2149
# Estimator 403/2000, Train metric: 0.2108, Validation metric: 0.2148
# Estimator 404/2000, Train metric: 0.2108, Validation metric: 0.2147
# Estimator 405/2000, Train metric: 0.2107, Validation metric: 0.2147
# Estimator 406/2000, Train metric: 0.2106, Validation metric: 0.2146
# Estimator 407/2000, Train metric: 0.2105, Validation metric: 0.2144
# Estimator 408/2000, Train metric: 0.2104, Validation metric: 0.2143
# Estimator 409/2000, Train metric: 0.2104, Validation metric: 0.2142
# Estimator 410/2000, Train metric: 0.2103, Validation metric: 0.2142
# Estimator 411/2000, Train metric: 0.2102, Validation metric: 0.2140
# Estimator 412/2000, Train metric: 0.2102, Validation metric: 0.2140
# Estimator 413/2000, Train metric: 0.2101, Validation metric: 0.2139
# Estimator 414/2000, Train metric: 0.2100, Validation metric: 0.2138
# Estimator 415/2000, Train metric: 0.2100, Validation metric: 0.2137
# Estimator 416/2000, Train metric: 0.2099, Validation metric: 0.2136
# Estimator 417/2000, Train metric: 0.2099, Validation metric: 0.2136
# Estimator 418/2000, Train metric: 0.2099, Validation metric: 0.2136
# Estimator 419/2000, Train metric: 0.2098, Validation metric: 0.2135
# Estimator 420/2000, Train metric: 0.2097, Validation metric: 0.2134
# Estimator 421/2000, Train metric: 0.2097, Validation metric: 0.2134
# Estimator 422/2000, Train metric: 0.2097, Validation metric: 0.2133
# Estimator 423/2000, Train metric: 0.2096, Validation metric: 0.2133
# Estimator 424/2000, Train metric: 0.2096, Validation metric: 0.2133
# Estimator 425/2000, Train metric: 0.2095, Validation metric: 0.2132
# Estimator 426/2000, Train metric: 0.2095, Validation metric: 0.2132
# Estimator 427/2000, Train metric: 0.2094, Validation metric: 0.2131
# Estimator 428/2000, Train metric: 0.2093, Validation metric: 0.2130
# Estimator 429/2000, Train metric: 0.2093, Validation metric: 0.2129
# Estimator 430/2000, Train metric: 0.2092, Validation metric: 0.2129
# Estimator 431/2000, Train metric: 0.2092, Validation metric: 0.2128
# Estimator 432/2000, Train metric: 0.2092, Validation metric: 0.2128
# Estimator 433/2000, Train metric: 0.2091, Validation metric: 0.2127
# Estimator 434/2000, Train metric: 0.2090, Validation metric: 0.2127
# Estimator 435/2000, Train metric: 0.2090, Validation metric: 0.2126
# Estimator 436/2000, Train metric: 0.2090, Validation metric: 0.2126
# Estimator 437/2000, Train metric: 0.2089, Validation metric: 0.2125
# Estimator 438/2000, Train metric: 0.2089, Validation metric: 0.2125
# Estimator 439/2000, Train metric: 0.2088, Validation metric: 0.2124
# Estimator 440/2000, Train metric: 0.2087, Validation metric: 0.2122
# Estimator 441/2000, Train metric: 0.2086, Validation metric: 0.2122
# Estimator 442/2000, Train metric: 0.2086, Validation metric: 0.2121
# Estimator 443/2000, Train metric: 0.2085, Validation metric: 0.2121
# Estimator 444/2000, Train metric: 0.2085, Validation metric: 0.2120
# Estimator 445/2000, Train metric: 0.2084, Validation metric: 0.2119
# Estimator 446/2000, Train metric: 0.2083, Validation metric: 0.2118
# Estimator 447/2000, Train metric: 0.2082, Validation metric: 0.2117
# Estimator 448/2000, Train metric: 0.2082, Validation metric: 0.2116
# Estimator 449/2000, Train metric: 0.2081, Validation metric: 0.2116
# Estimator 450/2000, Train metric: 0.2081, Validation metric: 0.2116
# Estimator 451/2000, Train metric: 0.2080, Validation metric: 0.2115
# Estimator 452/2000, Train metric: 0.2080, Validation metric: 0.2114
# Estimator 453/2000, Train metric: 0.2079, Validation metric: 0.2113
# Estimator 454/2000, Train metric: 0.2078, Validation metric: 0.2113
# Estimator 455/2000, Train metric: 0.2078, Validation metric: 0.2112
# Estimator 456/2000, Train metric: 0.2077, Validation metric: 0.2112
# Estimator 457/2000, Train metric: 0.2077, Validation metric: 0.2112
# Estimator 458/2000, Train metric: 0.2077, Validation metric: 0.2111
# Estimator 459/2000, Train metric: 0.2076, Validation metric: 0.2111
# Estimator 460/2000, Train metric: 0.2076, Validation metric: 0.2110
# Estimator 461/2000, Train metric: 0.2075, Validation metric: 0.2110
# Estimator 462/2000, Train metric: 0.2075, Validation metric: 0.2110
# Estimator 463/2000, Train metric: 0.2074, Validation metric: 0.2109
# Estimator 464/2000, Train metric: 0.2073, Validation metric: 0.2108
# Estimator 465/2000, Train metric: 0.2072, Validation metric: 0.2107
# Estimator 466/2000, Train metric: 0.2072, Validation metric: 0.2106
# Estimator 467/2000, Train metric: 0.2071, Validation metric: 0.2106
# Estimator 468/2000, Train metric: 0.2071, Validation metric: 0.2106
# Estimator 469/2000, Train metric: 0.2070, Validation metric: 0.2105
# Estimator 470/2000, Train metric: 0.2070, Validation metric: 0.2105
# Estimator 471/2000, Train metric: 0.2069, Validation metric: 0.2104
# Estimator 472/2000, Train metric: 0.2068, Validation metric: 0.2103
# Estimator 473/2000, Train metric: 0.2068, Validation metric: 0.2102
# Estimator 474/2000, Train metric: 0.2067, Validation metric: 0.2102
# Estimator 475/2000, Train metric: 0.2066, Validation metric: 0.2101
# Estimator 476/2000, Train metric: 0.2066, Validation metric: 0.2100
# Estimator 477/2000, Train metric: 0.2065, Validation metric: 0.2100
# Estimator 478/2000, Train metric: 0.2065, Validation metric: 0.2099
# Estimator 479/2000, Train metric: 0.2064, Validation metric: 0.2099
# Estimator 480/2000, Train metric: 0.2064, Validation metric: 0.2098
# Estimator 481/2000, Train metric: 0.2063, Validation metric: 0.2098
# Estimator 482/2000, Train metric: 0.2063, Validation metric: 0.2097
# Estimator 483/2000, Train metric: 0.2063, Validation metric: 0.2097
# Estimator 484/2000, Train metric: 0.2062, Validation metric: 0.2096
# Estimator 485/2000, Train metric: 0.2061, Validation metric: 0.2095
# Estimator 486/2000, Train metric: 0.2061, Validation metric: 0.2094
# Estimator 487/2000, Train metric: 0.2060, Validation metric: 0.2093
# Estimator 488/2000, Train metric: 0.2060, Validation metric: 0.2093
# Estimator 489/2000, Train metric: 0.2059, Validation metric: 0.2092
# Estimator 490/2000, Train metric: 0.2059, Validation metric: 0.2092
# Estimator 491/2000, Train metric: 0.2058, Validation metric: 0.2092
# Estimator 492/2000, Train metric: 0.2058, Validation metric: 0.2091
# Estimator 493/2000, Train metric: 0.2057, Validation metric: 0.2091
# Estimator 494/2000, Train metric: 0.2057, Validation metric: 0.2090
# Estimator 495/2000, Train metric: 0.2056, Validation metric: 0.2090
# Estimator 496/2000, Train metric: 0.2055, Validation metric: 0.2088
# Estimator 497/2000, Train metric: 0.2054, Validation metric: 0.2086
# Estimator 498/2000, Train metric: 0.2054, Validation metric: 0.2086
# Estimator 499/2000, Train metric: 0.2053, Validation metric: 0.2085
# Estimator 500/2000, Train metric: 0.2052, Validation metric: 0.2084
# Estimator 501/2000, Train metric: 0.2052, Validation metric: 0.2084
# Estimator 502/2000, Train metric: 0.2051, Validation metric: 0.2083
# Estimator 503/2000, Train metric: 0.2051, Validation metric: 0.2083
# Estimator 504/2000, Train metric: 0.2051, Validation metric: 0.2083
# Estimator 505/2000, Train metric: 0.2050, Validation metric: 0.2082
# Estimator 506/2000, Train metric: 0.2049, Validation metric: 0.2081
# Estimator 507/2000, Train metric: 0.2049, Validation metric: 0.2080
# Estimator 508/2000, Train metric: 0.2049, Validation metric: 0.2080
# Estimator 509/2000, Train metric: 0.2048, Validation metric: 0.2079
# Estimator 510/2000, Train metric: 0.2048, Validation metric: 0.2079
# Estimator 511/2000, Train metric: 0.2047, Validation metric: 0.2079
# Estimator 512/2000, Train metric: 0.2047, Validation metric: 0.2078
# Estimator 513/2000, Train metric: 0.2047, Validation metric: 0.2078
# Estimator 514/2000, Train metric: 0.2046, Validation metric: 0.2077
# Estimator 515/2000, Train metric: 0.2046, Validation metric: 0.2077
# Estimator 516/2000, Train metric: 0.2046, Validation metric: 0.2076
# Estimator 517/2000, Train metric: 0.2045, Validation metric: 0.2076
# Estimator 518/2000, Train metric: 0.2045, Validation metric: 0.2075
# Estimator 519/2000, Train metric: 0.2044, Validation metric: 0.2075
# Estimator 520/2000, Train metric: 0.2044, Validation metric: 0.2075
# Estimator 521/2000, Train metric: 0.2044, Validation metric: 0.2074
# Estimator 522/2000, Train metric: 0.2043, Validation metric: 0.2074
# Estimator 523/2000, Train metric: 0.2043, Validation metric: 0.2073
# Estimator 524/2000, Train metric: 0.2043, Validation metric: 0.2073
# Estimator 525/2000, Train metric: 0.2042, Validation metric: 0.2073
# Estimator 526/2000, Train metric: 0.2042, Validation metric: 0.2072
# Estimator 527/2000, Train metric: 0.2041, Validation metric: 0.2072
# Estimator 528/2000, Train metric: 0.2041, Validation metric: 0.2071
# Estimator 529/2000, Train metric: 0.2040, Validation metric: 0.2071
# Estimator 530/2000, Train metric: 0.2040, Validation metric: 0.2070
# Estimator 531/2000, Train metric: 0.2039, Validation metric: 0.2070
# Estimator 532/2000, Train metric: 0.2039, Validation metric: 0.2070
# Estimator 533/2000, Train metric: 0.2038, Validation metric: 0.2069
# Estimator 534/2000, Train metric: 0.2038, Validation metric: 0.2069
# Estimator 535/2000, Train metric: 0.2038, Validation metric: 0.2068
# Estimator 536/2000, Train metric: 0.2037, Validation metric: 0.2068
# Estimator 537/2000, Train metric: 0.2037, Validation metric: 0.2068
# Estimator 538/2000, Train metric: 0.2036, Validation metric: 0.2067
# Estimator 539/2000, Train metric: 0.2036, Validation metric: 0.2066
# Estimator 540/2000, Train metric: 0.2035, Validation metric: 0.2066
# Estimator 541/2000, Train metric: 0.2035, Validation metric: 0.2065
# Estimator 542/2000, Train metric: 0.2034, Validation metric: 0.2065
# Estimator 543/2000, Train metric: 0.2034, Validation metric: 0.2064
# Estimator 544/2000, Train metric: 0.2033, Validation metric: 0.2064
# Estimator 545/2000, Train metric: 0.2033, Validation metric: 0.2063
# Estimator 546/2000, Train metric: 0.2033, Validation metric: 0.2063
# Estimator 547/2000, Train metric: 0.2032, Validation metric: 0.2063
# Estimator 548/2000, Train metric: 0.2032, Validation metric: 0.2062
# Estimator 549/2000, Train metric: 0.2032, Validation metric: 0.2062
# Estimator 550/2000, Train metric: 0.2031, Validation metric: 0.2061
# Estimator 551/2000, Train metric: 0.2030, Validation metric: 0.2061
# Estimator 552/2000, Train metric: 0.2030, Validation metric: 0.2060
# Estimator 553/2000, Train metric: 0.2029, Validation metric: 0.2060
# Estimator 554/2000, Train metric: 0.2029, Validation metric: 0.2059
# Estimator 555/2000, Train metric: 0.2028, Validation metric: 0.2059
# Estimator 556/2000, Train metric: 0.2028, Validation metric: 0.2057
# Estimator 557/2000, Train metric: 0.2027, Validation metric: 0.2056
# Estimator 558/2000, Train metric: 0.2027, Validation metric: 0.2056
# Estimator 559/2000, Train metric: 0.2026, Validation metric: 0.2055
# Estimator 560/2000, Train metric: 0.2025, Validation metric: 0.2054
# Estimator 561/2000, Train metric: 0.2025, Validation metric: 0.2053
# Estimator 562/2000, Train metric: 0.2024, Validation metric: 0.2052
# Estimator 563/2000, Train metric: 0.2023, Validation metric: 0.2052
# Estimator 564/2000, Train metric: 0.2023, Validation metric: 0.2051
# Estimator 565/2000, Train metric: 0.2022, Validation metric: 0.2050
# Estimator 566/2000, Train metric: 0.2022, Validation metric: 0.2050
# Estimator 567/2000, Train metric: 0.2021, Validation metric: 0.2049
# Estimator 568/2000, Train metric: 0.2021, Validation metric: 0.2049
# Estimator 569/2000, Train metric: 0.2021, Validation metric: 0.2049
# Estimator 570/2000, Train metric: 0.2020, Validation metric: 0.2048
# Estimator 571/2000, Train metric: 0.2020, Validation metric: 0.2047
# Estimator 572/2000, Train metric: 0.2019, Validation metric: 0.2047
# Estimator 573/2000, Train metric: 0.2019, Validation metric: 0.2047
# Estimator 574/2000, Train metric: 0.2018, Validation metric: 0.2046
# Estimator 575/2000, Train metric: 0.2018, Validation metric: 0.2045
# Estimator 576/2000, Train metric: 0.2017, Validation metric: 0.2044
# Estimator 577/2000, Train metric: 0.2017, Validation metric: 0.2044
# Estimator 578/2000, Train metric: 0.2016, Validation metric: 0.2043
# Estimator 579/2000, Train metric: 0.2016, Validation metric: 0.2042
# Estimator 580/2000, Train metric: 0.2015, Validation metric: 0.2042
# Estimator 581/2000, Train metric: 0.2015, Validation metric: 0.2042
# Estimator 582/2000, Train metric: 0.2015, Validation metric: 0.2041
# Estimator 583/2000, Train metric: 0.2014, Validation metric: 0.2041
# Estimator 584/2000, Train metric: 0.2014, Validation metric: 0.2040
# Estimator 585/2000, Train metric: 0.2013, Validation metric: 0.2040
# Estimator 586/2000, Train metric: 0.2013, Validation metric: 0.2040
# Estimator 587/2000, Train metric: 0.2012, Validation metric: 0.2039
# Estimator 588/2000, Train metric: 0.2011, Validation metric: 0.2038
# Estimator 589/2000, Train metric: 0.2011, Validation metric: 0.2037
# Estimator 590/2000, Train metric: 0.2011, Validation metric: 0.2037
# Estimator 591/2000, Train metric: 0.2010, Validation metric: 0.2037
# Estimator 592/2000, Train metric: 0.2010, Validation metric: 0.2036
# Estimator 593/2000, Train metric: 0.2009, Validation metric: 0.2036
# Estimator 594/2000, Train metric: 0.2009, Validation metric: 0.2036
# Estimator 595/2000, Train metric: 0.2008, Validation metric: 0.2035
# Estimator 596/2000, Train metric: 0.2007, Validation metric: 0.2034
# Estimator 597/2000, Train metric: 0.2007, Validation metric: 0.2034
# Estimator 598/2000, Train metric: 0.2006, Validation metric: 0.2033
# Estimator 599/2000, Train metric: 0.2006, Validation metric: 0.2033
# Estimator 600/2000, Train metric: 0.2005, Validation metric: 0.2032
# Estimator 601/2000, Train metric: 0.2005, Validation metric: 0.2031
# Estimator 602/2000, Train metric: 0.2004, Validation metric: 0.2031
# Estimator 603/2000, Train metric: 0.2004, Validation metric: 0.2030
# Estimator 604/2000, Train metric: 0.2004, Validation metric: 0.2030
# Estimator 605/2000, Train metric: 0.2004, Validation metric: 0.2030
# Estimator 606/2000, Train metric: 0.2003, Validation metric: 0.2030
# Estimator 607/2000, Train metric: 0.2003, Validation metric: 0.2029
# Estimator 608/2000, Train metric: 0.2002, Validation metric: 0.2029
# Estimator 609/2000, Train metric: 0.2002, Validation metric: 0.2028
# Estimator 610/2000, Train metric: 0.2001, Validation metric: 0.2028
# Estimator 611/2000, Train metric: 0.2001, Validation metric: 0.2028
# Estimator 612/2000, Train metric: 0.2000, Validation metric: 0.2028
# Estimator 613/2000, Train metric: 0.2000, Validation metric: 0.2027
# Estimator 614/2000, Train metric: 0.1999, Validation metric: 0.2027
# Estimator 615/2000, Train metric: 0.1999, Validation metric: 0.2026
# Estimator 616/2000, Train metric: 0.1998, Validation metric: 0.2026
# Estimator 617/2000, Train metric: 0.1998, Validation metric: 0.2025
# Estimator 618/2000, Train metric: 0.1998, Validation metric: 0.2025
# Estimator 619/2000, Train metric: 0.1997, Validation metric: 0.2024
# Estimator 620/2000, Train metric: 0.1997, Validation metric: 0.2024
# Estimator 621/2000, Train metric: 0.1996, Validation metric: 0.2023
# Estimator 622/2000, Train metric: 0.1995, Validation metric: 0.2023
# Estimator 623/2000, Train metric: 0.1995, Validation metric: 0.2023
# Estimator 624/2000, Train metric: 0.1995, Validation metric: 0.2022
# Estimator 625/2000, Train metric: 0.1994, Validation metric: 0.2022
# Estimator 626/2000, Train metric: 0.1994, Validation metric: 0.2021
# Estimator 627/2000, Train metric: 0.1993, Validation metric: 0.2021
# Estimator 628/2000, Train metric: 0.1993, Validation metric: 0.2021
# Estimator 629/2000, Train metric: 0.1993, Validation metric: 0.2021
# Estimator 630/2000, Train metric: 0.1992, Validation metric: 0.2021
# Estimator 631/2000, Train metric: 0.1992, Validation metric: 0.2020
# Estimator 632/2000, Train metric: 0.1992, Validation metric: 0.2020
# Estimator 633/2000, Train metric: 0.1991, Validation metric: 0.2020
# Estimator 634/2000, Train metric: 0.1991, Validation metric: 0.2020
# Estimator 635/2000, Train metric: 0.1990, Validation metric: 0.2019
# Estimator 636/2000, Train metric: 0.1990, Validation metric: 0.2019
# Estimator 637/2000, Train metric: 0.1990, Validation metric: 0.2018
# Estimator 638/2000, Train metric: 0.1990, Validation metric: 0.2018
# Estimator 639/2000, Train metric: 0.1990, Validation metric: 0.2018
# Estimator 640/2000, Train metric: 0.1989, Validation metric: 0.2017
# Estimator 641/2000, Train metric: 0.1989, Validation metric: 0.2017
# Estimator 642/2000, Train metric: 0.1988, Validation metric: 0.2017
# Estimator 643/2000, Train metric: 0.1988, Validation metric: 0.2016
# Estimator 644/2000, Train metric: 0.1987, Validation metric: 0.2016
# Estimator 645/2000, Train metric: 0.1987, Validation metric: 0.2015
# Estimator 646/2000, Train metric: 0.1987, Validation metric: 0.2015
# Estimator 647/2000, Train metric: 0.1987, Validation metric: 0.2015
# Estimator 648/2000, Train metric: 0.1986, Validation metric: 0.2014
# Estimator 649/2000, Train metric: 0.1986, Validation metric: 0.2014
# Estimator 650/2000, Train metric: 0.1985, Validation metric: 0.2013
# Estimator 651/2000, Train metric: 0.1985, Validation metric: 0.2013
# Estimator 652/2000, Train metric: 0.1985, Validation metric: 0.2013
# Estimator 653/2000, Train metric: 0.1985, Validation metric: 0.2013
# Estimator 654/2000, Train metric: 0.1984, Validation metric: 0.2013
# Estimator 655/2000, Train metric: 0.1984, Validation metric: 0.2012
# Estimator 656/2000, Train metric: 0.1983, Validation metric: 0.2012
# Estimator 657/2000, Train metric: 0.1983, Validation metric: 0.2011
# Estimator 658/2000, Train metric: 0.1983, Validation metric: 0.2011
# Estimator 659/2000, Train metric: 0.1982, Validation metric: 0.2010
# Estimator 660/2000, Train metric: 0.1982, Validation metric: 0.2010
# Estimator 661/2000, Train metric: 0.1981, Validation metric: 0.2009
# Estimator 662/2000, Train metric: 0.1981, Validation metric: 0.2009
# Estimator 663/2000, Train metric: 0.1981, Validation metric: 0.2008
# Estimator 664/2000, Train metric: 0.1980, Validation metric: 0.2007
# Estimator 665/2000, Train metric: 0.1980, Validation metric: 0.2007
# Estimator 666/2000, Train metric: 0.1980, Validation metric: 0.2007
# Estimator 667/2000, Train metric: 0.1979, Validation metric: 0.2006
# Estimator 668/2000, Train metric: 0.1979, Validation metric: 0.2006
# Estimator 669/2000, Train metric: 0.1979, Validation metric: 0.2006
# Estimator 670/2000, Train metric: 0.1979, Validation metric: 0.2006
# Estimator 671/2000, Train metric: 0.1978, Validation metric: 0.2004
# Estimator 672/2000, Train metric: 0.1978, Validation metric: 0.2004
# Estimator 673/2000, Train metric: 0.1977, Validation metric: 0.2003
# Estimator 674/2000, Train metric: 0.1977, Validation metric: 0.2003
# Estimator 675/2000, Train metric: 0.1976, Validation metric: 0.2002
# Estimator 676/2000, Train metric: 0.1976, Validation metric: 0.2002
# Estimator 677/2000, Train metric: 0.1976, Validation metric: 0.2002
# Estimator 678/2000, Train metric: 0.1975, Validation metric: 0.2001
# Estimator 679/2000, Train metric: 0.1975, Validation metric: 0.2001
# Estimator 680/2000, Train metric: 0.1975, Validation metric: 0.2000
# Estimator 681/2000, Train metric: 0.1975, Validation metric: 0.2000
# Estimator 682/2000, Train metric: 0.1974, Validation metric: 0.2000
# Estimator 683/2000, Train metric: 0.1974, Validation metric: 0.2000
# Estimator 684/2000, Train metric: 0.1973, Validation metric: 0.1999
# Estimator 685/2000, Train metric: 0.1973, Validation metric: 0.1999
# Estimator 686/2000, Train metric: 0.1973, Validation metric: 0.1999
# Estimator 687/2000, Train metric: 0.1972, Validation metric: 0.1998
# Estimator 688/2000, Train metric: 0.1972, Validation metric: 0.1998
# Estimator 689/2000, Train metric: 0.1972, Validation metric: 0.1998
# Estimator 690/2000, Train metric: 0.1972, Validation metric: 0.1998
# Estimator 691/2000, Train metric: 0.1971, Validation metric: 0.1997
# Estimator 692/2000, Train metric: 0.1971, Validation metric: 0.1997
# Estimator 693/2000, Train metric: 0.1971, Validation metric: 0.1997
# Estimator 694/2000, Train metric: 0.1971, Validation metric: 0.1997
# Estimator 695/2000, Train metric: 0.1970, Validation metric: 0.1996
# Estimator 696/2000, Train metric: 0.1970, Validation metric: 0.1996
# Estimator 697/2000, Train metric: 0.1970, Validation metric: 0.1996
# Estimator 698/2000, Train metric: 0.1969, Validation metric: 0.1996
# Estimator 699/2000, Train metric: 0.1969, Validation metric: 0.1995
# Estimator 700/2000, Train metric: 0.1969, Validation metric: 0.1995
# Estimator 701/2000, Train metric: 0.1968, Validation metric: 0.1995
# Estimator 702/2000, Train metric: 0.1968, Validation metric: 0.1995
# Estimator 703/2000, Train metric: 0.1968, Validation metric: 0.1995
# Estimator 704/2000, Train metric: 0.1968, Validation metric: 0.1994
# Estimator 705/2000, Train metric: 0.1967, Validation metric: 0.1994
# Estimator 706/2000, Train metric: 0.1967, Validation metric: 0.1993
# ...
# Estimator 1769/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1770/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1771/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1772/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1773/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1774/2000, Train metric: 0.1711, Validation metric: 0.1726
# Estimator 1775/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1776/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1777/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1778/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1779/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1780/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1781/2000, Train metric: 0.1710, Validation metric: 0.1725
# Estimator 1782/2000, Train metric: 0.1709, Validation metric: 0.1725
# Estimator 1783/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1784/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1785/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1786/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1787/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1788/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1789/2000, Train metric: 0.1709, Validation metric: 0.1724
# Estimator 1790/2000, Train metric: 0.1708, Validation metric: 0.1724
# Estimator 1791/2000, Train metric: 0.1708, Validation metric: 0.1723
# Estimator 1792/2000, Train metric: 0.1708, Validation metric: 0.1723
# Estimator 1793/2000, Train metric: 0.1708, Validation metric: 0.1723
# Estimator 1794/2000, Train metric: 0.1708, Validation metric: 0.1723
# Estimator 1795/2000, Train metric: 0.1708, Validation metric: 0.1723
# Estimator 1796/2000, Train metric: 0.1707, Validation metric: 0.1723
# Estimator 1797/2000, Train metric: 0.1707, Validation metric: 0.1723
# Estimator 1798/2000, Train metric: 0.1707, Validation metric: 0.1723
# Estimator 1799/2000, Train metric: 0.1707, Validation metric: 0.1722
# Estimator 1800/2000, Train metric: 0.1707, Validation metric: 0.1722
# Estimator 1801/2000, Train metric: 0.1707, Validation metric: 0.1722
# Estimator 1802/2000, Train metric: 0.1707, Validation metric: 0.1722
# Estimator 1803/2000, Train metric: 0.1707, Validation metric: 0.1722
# Estimator 1804/2000, Train metric: 0.1706, Validation metric: 0.1722
# Estimator 1805/2000, Train metric: 0.1706, Validation metric: 0.1722
# Estimator 1806/2000, Train metric: 0.1706, Validation metric: 0.1722
# Estimator 1807/2000, Train metric: 0.1706, Validation metric: 0.1721
# Estimator 1808/2000, Train metric: 0.1706, Validation metric: 0.1721
# Estimator 1809/2000, Train metric: 0.1705, Validation metric: 0.1721
# Estimator 1810/2000, Train metric: 0.1705, Validation metric: 0.1721
# Estimator 1811/2000, Train metric: 0.1705, Validation metric: 0.1721
# Estimator 1812/2000, Train metric: 0.1705, Validation metric: 0.1721
# Estimator 1813/2000, Train metric: 0.1705, Validation metric: 0.1721
# Estimator 1814/2000, Train metric: 0.1705, Validation metric: 0.1720
# Estimator 1815/2000, Train metric: 0.1705, Validation metric: 0.1720
# Estimator 1816/2000, Train metric: 0.1705, Validation metric: 0.1720
# Estimator 1817/2000, Train metric: 0.1704, Validation metric: 0.1720
# Estimator 1818/2000, Train metric: 0.1704, Validation metric: 0.1720
# Estimator 1819/2000, Train metric: 0.1704, Validation metric: 0.1720
# Estimator 1820/2000, Train metric: 0.1704, Validation metric: 0.1720
# Estimator 1821/2000, Train metric: 0.1704, Validation metric: 0.1719
# Estimator 1822/2000, Train metric: 0.1703, Validation metric: 0.1719
# Estimator 1823/2000, Train metric: 0.1703, Validation metric: 0.1719
# Estimator 1824/2000, Train metric: 0.1703, Validation metric: 0.1719
# Estimator 1825/2000, Train metric: 0.1703, Validation metric: 0.1719
# Estimator 1826/2000, Train metric: 0.1703, Validation metric: 0.1718
# Estimator 1827/2000, Train metric: 0.1703, Validation metric: 0.1718
# Estimator 1828/2000, Train metric: 0.1702, Validation metric: 0.1718
# Estimator 1829/2000, Train metric: 0.1702, Validation metric: 0.1718
# Estimator 1830/2000, Train metric: 0.1702, Validation metric: 0.1718
# Estimator 1831/2000, Train metric: 0.1702, Validation metric: 0.1717
# Estimator 1832/2000, Train metric: 0.1701, Validation metric: 0.1717
# Estimator 1833/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1834/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1835/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1836/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1837/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1838/2000, Train metric: 0.1701, Validation metric: 0.1716
# Estimator 1839/2000, Train metric: 0.1700, Validation metric: 0.1716
# Estimator 1840/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1841/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1842/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1843/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1844/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1845/2000, Train metric: 0.1700, Validation metric: 0.1715
# Estimator 1846/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1847/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1848/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1849/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1850/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1851/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1852/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1853/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1854/2000, Train metric: 0.1699, Validation metric: 0.1714
# Estimator 1855/2000, Train metric: 0.1698, Validation metric: 0.1714
# Estimator 1856/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1857/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1858/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1859/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1860/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1861/2000, Train metric: 0.1698, Validation metric: 0.1713
# Estimator 1862/2000, Train metric: 0.1697, Validation metric: 0.1712
# Estimator 1863/2000, Train metric: 0.1697, Validation metric: 0.1712
# Estimator 1864/2000, Train metric: 0.1697, Validation metric: 0.1712
# Estimator 1865/2000, Train metric: 0.1697, Validation metric: 0.1712
# Estimator 1866/2000, Train metric: 0.1697, Validation metric: 0.1712
# Estimator 1867/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1868/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1869/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1870/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1871/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1872/2000, Train metric: 0.1696, Validation metric: 0.1711
# Estimator 1873/2000, Train metric: 0.1696, Validation metric: 0.1710
# Estimator 1874/2000, Train metric: 0.1695, Validation metric: 0.1710
# Estimator 1875/2000, Train metric: 0.1695, Validation metric: 0.1710
# Estimator 1876/2000, Train metric: 0.1695, Validation metric: 0.1710
# Estimator 1877/2000, Train metric: 0.1695, Validation metric: 0.1710
# Estimator 1878/2000, Train metric: 0.1695, Validation metric: 0.1710
# Estimator 1879/2000, Train metric: 0.1695, Validation metric: 0.1709
# Estimator 1880/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1881/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1882/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1883/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1884/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1885/2000, Train metric: 0.1694, Validation metric: 0.1709
# Estimator 1886/2000, Train metric: 0.1694, Validation metric: 0.1708
# Estimator 1887/2000, Train metric: 0.1693, Validation metric: 0.1708
# Estimator 1888/2000, Train metric: 0.1693, Validation metric: 0.1708
# Estimator 1889/2000, Train metric: 0.1693, Validation metric: 0.1708
# Estimator 1890/2000, Train metric: 0.1693, Validation metric: 0.1708
# Estimator 1891/2000, Train metric: 0.1693, Validation metric: 0.1708
# Estimator 1892/2000, Train metric: 0.1693, Validation metric: 0.1707
# Estimator 1893/2000, Train metric: 0.1693, Validation metric: 0.1707
# Estimator 1894/2000, Train metric: 0.1692, Validation metric: 0.1707
# Estimator 1895/2000, Train metric: 0.1692, Validation metric: 0.1707
# Estimator 1896/2000, Train metric: 0.1692, Validation metric: 0.1706
# Estimator 1897/2000, Train metric: 0.1692, Validation metric: 0.1706
# Estimator 1898/2000, Train metric: 0.1691, Validation metric: 0.1706
# Estimator 1899/2000, Train metric: 0.1691, Validation metric: 0.1706
# Estimator 1900/2000, Train metric: 0.1691, Validation metric: 0.1705
# Estimator 1901/2000, Train metric: 0.1691, Validation metric: 0.1705
# Estimator 1902/2000, Train metric: 0.1691, Validation metric: 0.1705
# Estimator 1903/2000, Train metric: 0.1691, Validation metric: 0.1705
# Estimator 1904/2000, Train metric: 0.1690, Validation metric: 0.1705
# Estimator 1905/2000, Train metric: 0.1690, Validation metric: 0.1704
# Estimator 1906/2000, Train metric: 0.1690, Validation metric: 0.1704
# Estimator 1907/2000, Train metric: 0.1690, Validation metric: 0.1704
# Estimator 1908/2000, Train metric: 0.1690, Validation metric: 0.1704
# Estimator 1909/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1910/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1911/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1912/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1913/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1914/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1915/2000, Train metric: 0.1689, Validation metric: 0.1703
# Estimator 1916/2000, Train metric: 0.1688, Validation metric: 0.1702
# Estimator 1917/2000, Train metric: 0.1688, Validation metric: 0.1702
# Estimator 1918/2000, Train metric: 0.1688, Validation metric: 0.1702
# Estimator 1919/2000, Train metric: 0.1688, Validation metric: 0.1702
# Estimator 1920/2000, Train metric: 0.1688, Validation metric: 0.1701
# Estimator 1921/2000, Train metric: 0.1688, Validation metric: 0.1701
# Estimator 1922/2000, Train metric: 0.1687, Validation metric: 0.1701
# Estimator 1923/2000, Train metric: 0.1687, Validation metric: 0.1701
# Estimator 1924/2000, Train metric: 0.1687, Validation metric: 0.1700
# Estimator 1925/2000, Train metric: 0.1687, Validation metric: 0.1700
# Estimator 1926/2000, Train metric: 0.1687, Validation metric: 0.1700
# Estimator 1927/2000, Train metric: 0.1687, Validation metric: 0.1700
# Estimator 1928/2000, Train metric: 0.1686, Validation metric: 0.1700
# Estimator 1929/2000, Train metric: 0.1686, Validation metric: 0.1700
# Estimator 1930/2000, Train metric: 0.1686, Validation metric: 0.1700
# Estimator 1931/2000, Train metric: 0.1686, Validation metric: 0.1700
# Estimator 1932/2000, Train metric: 0.1686, Validation metric: 0.1699
# Estimator 1933/2000, Train metric: 0.1686, Validation metric: 0.1699
# Estimator 1934/2000, Train metric: 0.1686, Validation metric: 0.1699
# Estimator 1935/2000, Train metric: 0.1685, Validation metric: 0.1699
# Estimator 1936/2000, Train metric: 0.1685, Validation metric: 0.1699
# Estimator 1937/2000, Train metric: 0.1685, Validation metric: 0.1699
# Estimator 1938/2000, Train metric: 0.1685, Validation metric: 0.1699
# Estimator 1939/2000, Train metric: 0.1685, Validation metric: 0.1698
# Estimator 1940/2000, Train metric: 0.1685, Validation metric: 0.1698
# Estimator 1941/2000, Train metric: 0.1684, Validation metric: 0.1698
# Estimator 1942/2000, Train metric: 0.1684, Validation metric: 0.1698
# Estimator 1943/2000, Train metric: 0.1684, Validation metric: 0.1698
# Estimator 1944/2000, Train metric: 0.1684, Validation metric: 0.1698
# Estimator 1945/2000, Train metric: 0.1684, Validation metric: 0.1698
# Estimator 1946/2000, Train metric: 0.1684, Validation metric: 0.1697
# Estimator 1947/2000, Train metric: 0.1683, Validation metric: 0.1697
# Estimator 1948/2000, Train metric: 0.1683, Validation metric: 0.1697
# Estimator 1949/2000, Train metric: 0.1683, Validation metric: 0.1697
# Estimator 1950/2000, Train metric: 0.1683, Validation metric: 0.1697
# Estimator 1951/2000, Train metric: 0.1683, Validation metric: 0.1697
# Estimator 1952/2000, Train metric: 0.1683, Validation metric: 0.1696
# Estimator 1953/2000, Train metric: 0.1683, Validation metric: 0.1696
# Estimator 1954/2000, Train metric: 0.1682, Validation metric: 0.1696
# Estimator 1955/2000, Train metric: 0.1682, Validation metric: 0.1696
# Estimator 1956/2000, Train metric: 0.1682, Validation metric: 0.1696
# Estimator 1957/2000, Train metric: 0.1682, Validation metric: 0.1696
# Estimator 1958/2000, Train metric: 0.1682, Validation metric: 0.1695
# Estimator 1959/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1960/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1961/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1962/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1963/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1964/2000, Train metric: 0.1681, Validation metric: 0.1695
# Estimator 1965/2000, Train metric: 0.1680, Validation metric: 0.1694
# Estimator 1966/2000, Train metric: 0.1680, Validation metric: 0.1694
# Estimator 1967/2000, Train metric: 0.1680, Validation metric: 0.1694
# Estimator 1968/2000, Train metric: 0.1680, Validation metric: 0.1694
# Estimator 1969/2000, Train metric: 0.1680, Validation metric: 0.1693
# Estimator 1970/2000, Train metric: 0.1680, Validation metric: 0.1693
# Estimator 1971/2000, Train metric: 0.1679, Validation metric: 0.1693
# Estimator 1972/2000, Train metric: 0.1679, Validation metric: 0.1693
# Estimator 1973/2000, Train metric: 0.1679, Validation metric: 0.1693
# Estimator 1974/2000, Train metric: 0.1679, Validation metric: 0.1693
# Estimator 1975/2000, Train metric: 0.1679, Validation metric: 0.1692
# Estimator 1976/2000, Train metric: 0.1679, Validation metric: 0.1692
# Estimator 1977/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1978/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1979/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1980/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1981/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1982/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1983/2000, Train metric: 0.1678, Validation metric: 0.1692
# Estimator 1984/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1985/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1986/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1987/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1988/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1989/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1990/2000, Train metric: 0.1677, Validation metric: 0.1691
# Estimator 1991/2000, Train metric: 0.1677, Validation metric: 0.1690
# Estimator 1992/2000, Train metric: 0.1677, Validation metric: 0.1690
# Estimator 1993/2000, Train metric: 0.1677, Validation metric: 0.1690
# Estimator 1994/2000, Train metric: 0.1676, Validation metric: 0.1690
# Estimator 1995/2000, Train metric: 0.1676, Validation metric: 0.1690
# Estimator 1996/2000, Train metric: 0.1676, Validation metric: 0.1690
# Estimator 1997/2000, Train metric: 0.1676, Validation metric: 0.1690
# Estimator 1998/2000, Train metric: 0.1676, Validation metric: 0.1690
# Estimator 1999/2000, Train metric: 0.1676, Validation metric: 0.1689

# %%
model.optimize_distribution(x_val.values, y_val.values.reshape(-1))
# Out:
# CRPS: 0.22 (Distribution: normal, Tree correlation: 0.000)
# CRPS: 0.17 (Distribution: normal, Tree correlation: 0.010)
# CRPS: 0.13 (Distribution: normal, Tree correlation: 0.020)
# CRPS: 0.11 (Distribution: normal, Tree correlation: 0.030)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.070)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.080)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.140)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.150)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.160)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.170)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: normal, Tree correlation: 0.190)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.000)
# CRPS: 0.13 (Distribution: studentt, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.020)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.030)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.070)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.080)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: studentt, Tree correlation: 0.140)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.150)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.160)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.170)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.190)
# CRPS: 0.18 (Distribution: laplace, Tree correlation: 0.000)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: laplace, Tree correlation: 0.020)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.030)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.070)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.080)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.140)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.150)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.160)
# CRPS: 0.11 (Distribution: laplace, Tree correlation: 0.170)
# CRPS: 0.11 (Distribution: laplace, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: laplace, Tree correlation: 0.190)
# CRPS: 0.21 (Distribution: logistic, Tree correlation: 0.000)
# CRPS: 0.16 (Distribution: logistic, Tree correlation: 0.010)
# CRPS: 0.12 (Distribution: logistic, Tree correlation: 0.020)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.030)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.070)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.080)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.140)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.150)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.160)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.170)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: logistic, Tree correlation: 0.190)
# CRPS: 0.22 (Distribution: gamma, Tree correlation: 0.000)
# CRPS: 0.17 (Distribution: gamma, Tree correlation: 0.010)
# CRPS: 0.13 (Distribution: gamma, Tree correlation: 0.020)
# CRPS: 0.11 (Distribution: gamma, Tree correlation: 0.030)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.070)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.080)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.140)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.150)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.160)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.170)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: gamma, Tree correlation: 0.190)
# CRPS: 0.22 (Distribution: gumbel, Tree correlation: 0.000)
# CRPS: 0.17 (Distribution: gumbel, Tree correlation: 0.010)
# CRPS: 0.13 (Distribution: gumbel, Tree correlation: 0.020)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.030)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.040)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.050)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.060)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.070)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.080)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.090)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.100)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.110)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.120)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.130)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.140)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.150)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.160)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.170)
# CRPS: 0.11 (Distribution: gumbel, Tree correlation: 0.180)
# CRPS: 0.11 (Distribution: gumbel, Tree correlation: 0.190)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.000)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.010)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.020)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.030)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.040)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.050)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.060)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.070)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.080)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.090)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.100)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.110)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.120)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.130)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.140)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.150)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.160)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.170)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.180)
# CRPS: 0.32 (Distribution: poisson, Tree correlation: 0.190)
# Lowest CRPS: 0.0915 (Distribution: studentt, Tree correlation: 0.040)
# ('studentt', 0.04)

# %%
y_train_dist = model.predict_dist(x_train.values, n_forecasts=1000)
y_val_dist = model.predict_dist(x_val.values, n_forecasts=1000)
y_test_dist = model.predict_dist(x_test.values, n_forecasts=1000)

# %%
print(model.crps_ensemble(y_train_dist, y_train.values.reshape(-1)).mean())
print(model.crps_ensemble(y_val_dist, y_val.values.reshape(-1)).mean())
print(model.crps_ensemble(y_test_dist, y_test.values.reshape(-1)).mean())
# Out:
# 0.08975179917251275
# 0.09082991893713253
# 0.10305392201337968
