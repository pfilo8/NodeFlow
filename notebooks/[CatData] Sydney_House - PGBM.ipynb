# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/sydney_house/SydneyHousePrices.csv')

# %%
x = df.drop(columns = ['Date', 'Id', 'sellPrice'])
x = pd.get_dummies(x)
y = np.log10(df[['sellPrice']])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((159603, 697), (39901, 697))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 0.2415, Validation metric: 0.2413
# Estimator 1/2000, Train metric: 0.2330, Validation metric: 0.2329
# Estimator 2/2000, Train metric: 0.2258, Validation metric: 0.2257
# Estimator 3/2000, Train metric: 0.2196, Validation metric: 0.2196
# Estimator 4/2000, Train metric: 0.2143, Validation metric: 0.2143
# Estimator 5/2000, Train metric: 0.2096, Validation metric: 0.2097
# Estimator 6/2000, Train metric: 0.2058, Validation metric: 0.2059
# Estimator 7/2000, Train metric: 0.2024, Validation metric: 0.2025
# Estimator 8/2000, Train metric: 0.1995, Validation metric: 0.1996
# Estimator 9/2000, Train metric: 0.1970, Validation metric: 0.1972
# Estimator 10/2000, Train metric: 0.1949, Validation metric: 0.1951
# Estimator 11/2000, Train metric: 0.1930, Validation metric: 0.1932
# Estimator 12/2000, Train metric: 0.1913, Validation metric: 0.1916
# Estimator 13/2000, Train metric: 0.1899, Validation metric: 0.1901
# Estimator 14/2000, Train metric: 0.1885, Validation metric: 0.1888
# Estimator 15/2000, Train metric: 0.1870, Validation metric: 0.1873
# Estimator 16/2000, Train metric: 0.1860, Validation metric: 0.1863
# Estimator 17/2000, Train metric: 0.1851, Validation metric: 0.1854
# Estimator 18/2000, Train metric: 0.1841, Validation metric: 0.1845
# Estimator 19/2000, Train metric: 0.1833, Validation metric: 0.1836
# Estimator 20/2000, Train metric: 0.1826, Validation metric: 0.1829
# Estimator 21/2000, Train metric: 0.1819, Validation metric: 0.1823
# Estimator 22/2000, Train metric: 0.1811, Validation metric: 0.1815
# Estimator 23/2000, Train metric: 0.1806, Validation metric: 0.1810
# Estimator 24/2000, Train metric: 0.1800, Validation metric: 0.1803
# Estimator 25/2000, Train metric: 0.1795, Validation metric: 0.1799
# Estimator 26/2000, Train metric: 0.1788, Validation metric: 0.1792
# Estimator 27/2000, Train metric: 0.1780, Validation metric: 0.1785
# Estimator 28/2000, Train metric: 0.1776, Validation metric: 0.1780
# Estimator 29/2000, Train metric: 0.1773, Validation metric: 0.1777
# Estimator 30/2000, Train metric: 0.1768, Validation metric: 0.1773
# Estimator 31/2000, Train metric: 0.1765, Validation metric: 0.1769
# Estimator 32/2000, Train metric: 0.1762, Validation metric: 0.1767
# Estimator 33/2000, Train metric: 0.1759, Validation metric: 0.1764
# Estimator 34/2000, Train metric: 0.1756, Validation metric: 0.1761
# Estimator 35/2000, Train metric: 0.1753, Validation metric: 0.1758
# Estimator 36/2000, Train metric: 0.1751, Validation metric: 0.1756
# Estimator 37/2000, Train metric: 0.1748, Validation metric: 0.1754
# Estimator 38/2000, Train metric: 0.1746, Validation metric: 0.1752
# Estimator 39/2000, Train metric: 0.1744, Validation metric: 0.1749
# Estimator 40/2000, Train metric: 0.1738, Validation metric: 0.1744
# Estimator 41/2000, Train metric: 0.1737, Validation metric: 0.1743
# Estimator 42/2000, Train metric: 0.1735, Validation metric: 0.1741
# Estimator 43/2000, Train metric: 0.1734, Validation metric: 0.1740
# Estimator 44/2000, Train metric: 0.1733, Validation metric: 0.1739
# Estimator 45/2000, Train metric: 0.1732, Validation metric: 0.1737
# Estimator 46/2000, Train metric: 0.1730, Validation metric: 0.1736
# Estimator 47/2000, Train metric: 0.1729, Validation metric: 0.1735
# Estimator 48/2000, Train metric: 0.1728, Validation metric: 0.1734
# Estimator 49/2000, Train metric: 0.1727, Validation metric: 0.1733
# Estimator 50/2000, Train metric: 0.1726, Validation metric: 0.1732
# Estimator 51/2000, Train metric: 0.1724, Validation metric: 0.1731
# Estimator 52/2000, Train metric: 0.1723, Validation metric: 0.1730
# Estimator 53/2000, Train metric: 0.1722, Validation metric: 0.1729
# Estimator 54/2000, Train metric: 0.1720, Validation metric: 0.1727
# Estimator 55/2000, Train metric: 0.1720, Validation metric: 0.1726
# Estimator 56/2000, Train metric: 0.1719, Validation metric: 0.1726
# Estimator 57/2000, Train metric: 0.1718, Validation metric: 0.1725
# Estimator 58/2000, Train metric: 0.1717, Validation metric: 0.1724
# Estimator 59/2000, Train metric: 0.1716, Validation metric: 0.1723
# Estimator 60/2000, Train metric: 0.1716, Validation metric: 0.1723
# Estimator 61/2000, Train metric: 0.1715, Validation metric: 0.1722
# Estimator 62/2000, Train metric: 0.1713, Validation metric: 0.1720
# Estimator 63/2000, Train metric: 0.1712, Validation metric: 0.1719
# Estimator 64/2000, Train metric: 0.1711, Validation metric: 0.1719
# Estimator 65/2000, Train metric: 0.1711, Validation metric: 0.1718
# Estimator 66/2000, Train metric: 0.1710, Validation metric: 0.1717
# Estimator 67/2000, Train metric: 0.1709, Validation metric: 0.1716
# Estimator 68/2000, Train metric: 0.1708, Validation metric: 0.1716
# Estimator 69/2000, Train metric: 0.1708, Validation metric: 0.1715
# Estimator 70/2000, Train metric: 0.1707, Validation metric: 0.1715
# Estimator 71/2000, Train metric: 0.1707, Validation metric: 0.1714
# Estimator 72/2000, Train metric: 0.1706, Validation metric: 0.1713
# Estimator 73/2000, Train metric: 0.1705, Validation metric: 0.1712
# Estimator 74/2000, Train metric: 0.1704, Validation metric: 0.1711
# Estimator 75/2000, Train metric: 0.1703, Validation metric: 0.1711
# Estimator 76/2000, Train metric: 0.1703, Validation metric: 0.1710
# Estimator 77/2000, Train metric: 0.1702, Validation metric: 0.1709
# Estimator 78/2000, Train metric: 0.1701, Validation metric: 0.1709
# Estimator 79/2000, Train metric: 0.1701, Validation metric: 0.1708
# Estimator 80/2000, Train metric: 0.1700, Validation metric: 0.1708
# Estimator 81/2000, Train metric: 0.1698, Validation metric: 0.1706
# Estimator 82/2000, Train metric: 0.1698, Validation metric: 0.1705
# Estimator 83/2000, Train metric: 0.1697, Validation metric: 0.1705
# Estimator 84/2000, Train metric: 0.1697, Validation metric: 0.1704
# Estimator 85/2000, Train metric: 0.1696, Validation metric: 0.1704
# Estimator 86/2000, Train metric: 0.1696, Validation metric: 0.1703
# Estimator 87/2000, Train metric: 0.1695, Validation metric: 0.1703
# Estimator 88/2000, Train metric: 0.1695, Validation metric: 0.1702
# Estimator 89/2000, Train metric: 0.1694, Validation metric: 0.1702
# Estimator 90/2000, Train metric: 0.1694, Validation metric: 0.1701
# Estimator 91/2000, Train metric: 0.1693, Validation metric: 0.1701
# Estimator 92/2000, Train metric: 0.1693, Validation metric: 0.1700
# Estimator 93/2000, Train metric: 0.1692, Validation metric: 0.1700
# Estimator 94/2000, Train metric: 0.1691, Validation metric: 0.1699
# Estimator 95/2000, Train metric: 0.1691, Validation metric: 0.1698
# Estimator 96/2000, Train metric: 0.1690, Validation metric: 0.1698
# Estimator 97/2000, Train metric: 0.1690, Validation metric: 0.1697
# Estimator 98/2000, Train metric: 0.1689, Validation metric: 0.1697
# Estimator 99/2000, Train metric: 0.1689, Validation metric: 0.1696
# Estimator 100/2000, Train metric: 0.1687, Validation metric: 0.1695
# Estimator 101/2000, Train metric: 0.1687, Validation metric: 0.1694
# Estimator 102/2000, Train metric: 0.1686, Validation metric: 0.1694
# Estimator 103/2000, Train metric: 0.1686, Validation metric: 0.1693
# Estimator 104/2000, Train metric: 0.1685, Validation metric: 0.1693
# Estimator 105/2000, Train metric: 0.1685, Validation metric: 0.1692
# Estimator 106/2000, Train metric: 0.1685, Validation metric: 0.1692
# Estimator 107/2000, Train metric: 0.1684, Validation metric: 0.1692
# Estimator 108/2000, Train metric: 0.1684, Validation metric: 0.1691
# Estimator 109/2000, Train metric: 0.1684, Validation metric: 0.1691
# Estimator 110/2000, Train metric: 0.1683, Validation metric: 0.1690
# Estimator 111/2000, Train metric: 0.1682, Validation metric: 0.1689
# Estimator 112/2000, Train metric: 0.1682, Validation metric: 0.1689
# Estimator 113/2000, Train metric: 0.1681, Validation metric: 0.1689
# Estimator 114/2000, Train metric: 0.1681, Validation metric: 0.1688
# Estimator 115/2000, Train metric: 0.1681, Validation metric: 0.1688
# Estimator 116/2000, Train metric: 0.1680, Validation metric: 0.1687
# Estimator 117/2000, Train metric: 0.1680, Validation metric: 0.1687
# Estimator 118/2000, Train metric: 0.1680, Validation metric: 0.1687
# Estimator 119/2000, Train metric: 0.1679, Validation metric: 0.1686
# Estimator 120/2000, Train metric: 0.1679, Validation metric: 0.1686
# Estimator 121/2000, Train metric: 0.1679, Validation metric: 0.1686
# Estimator 122/2000, Train metric: 0.1678, Validation metric: 0.1685
# Estimator 123/2000, Train metric: 0.1678, Validation metric: 0.1685
# Estimator 124/2000, Train metric: 0.1677, Validation metric: 0.1685
# Estimator 125/2000, Train metric: 0.1677, Validation metric: 0.1684
# Estimator 126/2000, Train metric: 0.1677, Validation metric: 0.1684
# Estimator 127/2000, Train metric: 0.1677, Validation metric: 0.1684
# Estimator 128/2000, Train metric: 0.1676, Validation metric: 0.1683
# Estimator 129/2000, Train metric: 0.1676, Validation metric: 0.1683
# Estimator 130/2000, Train metric: 0.1676, Validation metric: 0.1683
# Estimator 131/2000, Train metric: 0.1675, Validation metric: 0.1682
# Estimator 132/2000, Train metric: 0.1675, Validation metric: 0.1682
# Estimator 133/2000, Train metric: 0.1675, Validation metric: 0.1682
# Estimator 134/2000, Train metric: 0.1674, Validation metric: 0.1682
# Estimator 135/2000, Train metric: 0.1674, Validation metric: 0.1681
# Estimator 136/2000, Train metric: 0.1674, Validation metric: 0.1681
# Estimator 137/2000, Train metric: 0.1674, Validation metric: 0.1681
# Estimator 138/2000, Train metric: 0.1673, Validation metric: 0.1680
# Estimator 139/2000, Train metric: 0.1673, Validation metric: 0.1680
# Estimator 140/2000, Train metric: 0.1673, Validation metric: 0.1680
# Estimator 141/2000, Train metric: 0.1672, Validation metric: 0.1679
# Estimator 142/2000, Train metric: 0.1672, Validation metric: 0.1679
# Estimator 143/2000, Train metric: 0.1672, Validation metric: 0.1679
# Estimator 144/2000, Train metric: 0.1672, Validation metric: 0.1679
# Estimator 145/2000, Train metric: 0.1672, Validation metric: 0.1679
# Estimator 146/2000, Train metric: 0.1671, Validation metric: 0.1678
# Estimator 147/2000, Train metric: 0.1671, Validation metric: 0.1678
# Estimator 148/2000, Train metric: 0.1671, Validation metric: 0.1678
# Estimator 149/2000, Train metric: 0.1671, Validation metric: 0.1678
# Estimator 150/2000, Train metric: 0.1670, Validation metric: 0.1677
# Estimator 151/2000, Train metric: 0.1670, Validation metric: 0.1677
# Estimator 152/2000, Train metric: 0.1670, Validation metric: 0.1677
# Estimator 153/2000, Train metric: 0.1670, Validation metric: 0.1677
# Estimator 154/2000, Train metric: 0.1669, Validation metric: 0.1676
# Estimator 155/2000, Train metric: 0.1669, Validation metric: 0.1676
# Estimator 156/2000, Train metric: 0.1669, Validation metric: 0.1676
# Estimator 157/2000, Train metric: 0.1668, Validation metric: 0.1676
# Estimator 158/2000, Train metric: 0.1668, Validation metric: 0.1675
# Estimator 159/2000, Train metric: 0.1668, Validation metric: 0.1675
# Estimator 160/2000, Train metric: 0.1668, Validation metric: 0.1675
# Estimator 161/2000, Train metric: 0.1667, Validation metric: 0.1675
# Estimator 162/2000, Train metric: 0.1667, Validation metric: 0.1674
# Estimator 163/2000, Train metric: 0.1667, Validation metric: 0.1674
# Estimator 164/2000, Train metric: 0.1667, Validation metric: 0.1674
# Estimator 165/2000, Train metric: 0.1667, Validation metric: 0.1674
# Estimator 166/2000, Train metric: 0.1666, Validation metric: 0.1673
# Estimator 167/2000, Train metric: 0.1666, Validation metric: 0.1673
# Estimator 168/2000, Train metric: 0.1666, Validation metric: 0.1673
# Estimator 169/2000, Train metric: 0.1665, Validation metric: 0.1673
# Estimator 170/2000, Train metric: 0.1665, Validation metric: 0.1672
# Estimator 171/2000, Train metric: 0.1665, Validation metric: 0.1672
# Estimator 172/2000, Train metric: 0.1665, Validation metric: 0.1672
# Estimator 173/2000, Train metric: 0.1665, Validation metric: 0.1672
# Estimator 174/2000, Train metric: 0.1664, Validation metric: 0.1671
# Estimator 175/2000, Train metric: 0.1664, Validation metric: 0.1671
# Estimator 176/2000, Train metric: 0.1663, Validation metric: 0.1670
# Estimator 177/2000, Train metric: 0.1663, Validation metric: 0.1670
# Estimator 178/2000, Train metric: 0.1663, Validation metric: 0.1670
# Estimator 179/2000, Train metric: 0.1663, Validation metric: 0.1670
# Estimator 180/2000, Train metric: 0.1662, Validation metric: 0.1669
# Estimator 181/2000, Train metric: 0.1662, Validation metric: 0.1669
# Estimator 182/2000, Train metric: 0.1662, Validation metric: 0.1669
# Estimator 183/2000, Train metric: 0.1662, Validation metric: 0.1669
# Estimator 184/2000, Train metric: 0.1662, Validation metric: 0.1669
# Estimator 185/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 186/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 187/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 188/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 189/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 190/2000, Train metric: 0.1661, Validation metric: 0.1668
# Estimator 191/2000, Train metric: 0.1660, Validation metric: 0.1667
# Estimator 192/2000, Train metric: 0.1660, Validation metric: 0.1667
# Estimator 193/2000, Train metric: 0.1660, Validation metric: 0.1667
# Estimator 194/2000, Train metric: 0.1660, Validation metric: 0.1667
# Estimator 195/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 196/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 197/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 198/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 199/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 200/2000, Train metric: 0.1659, Validation metric: 0.1666
# Estimator 201/2000, Train metric: 0.1658, Validation metric: 0.1665
# Estimator 202/2000, Train metric: 0.1658, Validation metric: 0.1665
# Estimator 203/2000, Train metric: 0.1658, Validation metric: 0.1665
# Estimator 204/2000, Train metric: 0.1658, Validation metric: 0.1665
# Estimator 205/2000, Train metric: 0.1658, Validation metric: 0.1665
# Estimator 206/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 207/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 208/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 209/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 210/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 211/2000, Train metric: 0.1657, Validation metric: 0.1664
# Estimator 212/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 213/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 214/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 215/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 216/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 217/2000, Train metric: 0.1656, Validation metric: 0.1663
# Estimator 218/2000, Train metric: 0.1655, Validation metric: 0.1662
# Estimator 219/2000, Train metric: 0.1655, Validation metric: 0.1662
# Estimator 220/2000, Train metric: 0.1655, Validation metric: 0.1662
# Estimator 221/2000, Train metric: 0.1655, Validation metric: 0.1662
# Estimator 222/2000, Train metric: 0.1655, Validation metric: 0.1662
# Estimator 223/2000, Train metric: 0.1654, Validation metric: 0.1661
# Estimator 224/2000, Train metric: 0.1654, Validation metric: 0.1661
# Estimator 225/2000, Train metric: 0.1654, Validation metric: 0.1661
# Estimator 226/2000, Train metric: 0.1654, Validation metric: 0.1661
# Estimator 227/2000, Train metric: 0.1653, Validation metric: 0.1661
# Estimator 228/2000, Train metric: 0.1653, Validation metric: 0.1660
# Estimator 229/2000, Train metric: 0.1651, Validation metric: 0.1659
# Estimator 230/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 231/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 232/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 233/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 234/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 235/2000, Train metric: 0.1651, Validation metric: 0.1658
# Estimator 236/2000, Train metric: 0.1650, Validation metric: 0.1658
# Estimator 237/2000, Train metric: 0.1650, Validation metric: 0.1658
# Estimator 238/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 239/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 240/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 241/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 242/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 243/2000, Train metric: 0.1650, Validation metric: 0.1657
# Estimator 244/2000, Train metric: 0.1649, Validation metric: 0.1657
# Estimator 245/2000, Train metric: 0.1649, Validation metric: 0.1656
# Estimator 246/2000, Train metric: 0.1648, Validation metric: 0.1655
# Estimator 247/2000, Train metric: 0.1647, Validation metric: 0.1655
# Estimator 248/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 249/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 250/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 251/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 252/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 253/2000, Train metric: 0.1647, Validation metric: 0.1654
# Estimator 254/2000, Train metric: 0.1646, Validation metric: 0.1654
# Estimator 255/2000, Train metric: 0.1646, Validation metric: 0.1654
# Estimator 256/2000, Train metric: 0.1645, Validation metric: 0.1652
# Estimator 257/2000, Train metric: 0.1644, Validation metric: 0.1652
# Estimator 258/2000, Train metric: 0.1644, Validation metric: 0.1651
# Estimator 259/2000, Train metric: 0.1644, Validation metric: 0.1651
# Estimator 260/2000, Train metric: 0.1643, Validation metric: 0.1651
# Estimator 261/2000, Train metric: 0.1643, Validation metric: 0.1651
# Estimator 262/2000, Train metric: 0.1643, Validation metric: 0.1650
# Estimator 263/2000, Train metric: 0.1643, Validation metric: 0.1650
# Estimator 264/2000, Train metric: 0.1643, Validation metric: 0.1650
# Estimator 265/2000, Train metric: 0.1643, Validation metric: 0.1650
# Estimator 266/2000, Train metric: 0.1642, Validation metric: 0.1650
# Estimator 267/2000, Train metric: 0.1642, Validation metric: 0.1650
# Estimator 268/2000, Train metric: 0.1642, Validation metric: 0.1649
# Estimator 269/2000, Train metric: 0.1642, Validation metric: 0.1649
# Estimator 270/2000, Train metric: 0.1642, Validation metric: 0.1649
# Estimator 271/2000, Train metric: 0.1642, Validation metric: 0.1649
# Estimator 272/2000, Train metric: 0.1641, Validation metric: 0.1649
# Estimator 273/2000, Train metric: 0.1641, Validation metric: 0.1648
# Estimator 274/2000, Train metric: 0.1641, Validation metric: 0.1648
# Estimator 275/2000, Train metric: 0.1641, Validation metric: 0.1648
# Estimator 276/2000, Train metric: 0.1641, Validation metric: 0.1648
# Estimator 277/2000, Train metric: 0.1641, Validation metric: 0.1648
# Estimator 278/2000, Train metric: 0.1640, Validation metric: 0.1648
# Estimator 279/2000, Train metric: 0.1640, Validation metric: 0.1648
# Estimator 280/2000, Train metric: 0.1640, Validation metric: 0.1648
# Estimator 281/2000, Train metric: 0.1640, Validation metric: 0.1648
# Estimator 282/2000, Train metric: 0.1640, Validation metric: 0.1647
# Estimator 283/2000, Train metric: 0.1640, Validation metric: 0.1647
# Estimator 284/2000, Train metric: 0.1640, Validation metric: 0.1647
# Estimator 285/2000, Train metric: 0.1640, Validation metric: 0.1647
# Estimator 286/2000, Train metric: 0.1640, Validation metric: 0.1647
# Estimator 287/2000, Train metric: 0.1639, Validation metric: 0.1647
# Estimator 288/2000, Train metric: 0.1639, Validation metric: 0.1647
# Estimator 289/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 290/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 291/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 292/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 293/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 294/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 295/2000, Train metric: 0.1639, Validation metric: 0.1646
# Estimator 296/2000, Train metric: 0.1638, Validation metric: 0.1646
# Estimator 297/2000, Train metric: 0.1638, Validation metric: 0.1646
# Estimator 298/2000, Train metric: 0.1638, Validation metric: 0.1646
# Estimator 299/2000, Train metric: 0.1638, Validation metric: 0.1646
# Estimator 300/2000, Train metric: 0.1638, Validation metric: 0.1645
# Estimator 301/2000, Train metric: 0.1638, Validation metric: 0.1645
# Estimator 302/2000, Train metric: 0.1636, Validation metric: 0.1644
# Estimator 303/2000, Train metric: 0.1636, Validation metric: 0.1644
# Estimator 304/2000, Train metric: 0.1636, Validation metric: 0.1644
# Estimator 305/2000, Train metric: 0.1636, Validation metric: 0.1644
# Estimator 306/2000, Train metric: 0.1636, Validation metric: 0.1644
# Estimator 307/2000, Train metric: 0.1636, Validation metric: 0.1643
# Estimator 308/2000, Train metric: 0.1636, Validation metric: 0.1643
# Estimator 309/2000, Train metric: 0.1636, Validation metric: 0.1643
# Estimator 310/2000, Train metric: 0.1636, Validation metric: 0.1643
# Estimator 311/2000, Train metric: 0.1636, Validation metric: 0.1643
# Estimator 312/2000, Train metric: 0.1635, Validation metric: 0.1643
# Estimator 313/2000, Train metric: 0.1635, Validation metric: 0.1643
# Estimator 314/2000, Train metric: 0.1635, Validation metric: 0.1642
# Estimator 315/2000, Train metric: 0.1634, Validation metric: 0.1641
# Estimator 316/2000, Train metric: 0.1634, Validation metric: 0.1641
# Estimator 317/2000, Train metric: 0.1633, Validation metric: 0.1640
# Estimator 318/2000, Train metric: 0.1633, Validation metric: 0.1640
# Estimator 319/2000, Train metric: 0.1632, Validation metric: 0.1640
# Estimator 320/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 321/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 322/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 323/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 324/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 325/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 326/2000, Train metric: 0.1631, Validation metric: 0.1639
# Estimator 327/2000, Train metric: 0.1631, Validation metric: 0.1638
# Estimator 328/2000, Train metric: 0.1631, Validation metric: 0.1638
# Estimator 329/2000, Train metric: 0.1631, Validation metric: 0.1638
# Estimator 330/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 331/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 332/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 333/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 334/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 335/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 336/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 337/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 338/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 339/2000, Train metric: 0.1630, Validation metric: 0.1638
# Estimator 340/2000, Train metric: 0.1630, Validation metric: 0.1637
# Estimator 341/2000, Train metric: 0.1630, Validation metric: 0.1637
# Estimator 342/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 343/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 344/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 345/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 346/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 347/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 348/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 349/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 350/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 351/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 352/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 353/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 354/2000, Train metric: 0.1629, Validation metric: 0.1637
# Estimator 355/2000, Train metric: 0.1628, Validation metric: 0.1637
# Estimator 356/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 357/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 358/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 359/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 360/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 361/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 362/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 363/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 364/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 365/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 366/2000, Train metric: 0.1628, Validation metric: 0.1636
# Estimator 367/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 368/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 369/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 370/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 371/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 372/2000, Train metric: 0.1627, Validation metric: 0.1635
# Estimator 373/2000, Train metric: 0.1626, Validation metric: 0.1635
# Estimator 374/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 375/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 376/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 377/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 378/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 379/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 380/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 381/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 382/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 383/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 384/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 385/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 386/2000, Train metric: 0.1626, Validation metric: 0.1634
# Estimator 387/2000, Train metric: 0.1625, Validation metric: 0.1634
# Estimator 388/2000, Train metric: 0.1625, Validation metric: 0.1633
# Estimator 389/2000, Train metric: 0.1625, Validation metric: 0.1633
# Estimator 390/2000, Train metric: 0.1625, Validation metric: 0.1633
# Estimator 391/2000, Train metric: 0.1625, Validation metric: 0.1633
# Estimator 392/2000, Train metric: 0.1625, Validation metric: 0.1633
# Estimator 393/2000, Train metric: 0.1624, Validation metric: 0.1632
# Estimator 394/2000, Train metric: 0.1624, Validation metric: 0.1632
# Estimator 395/2000, Train metric: 0.1623, Validation metric: 0.1632
# Estimator 396/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 397/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 398/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 399/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 400/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 401/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 402/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 403/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 404/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 405/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 406/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 407/2000, Train metric: 0.1623, Validation metric: 0.1631
# Estimator 408/2000, Train metric: 0.1622, Validation metric: 0.1631
# Estimator 409/2000, Train metric: 0.1622, Validation metric: 0.1631
# Estimator 410/2000, Train metric: 0.1622, Validation metric: 0.1631
# Estimator 411/2000, Train metric: 0.1622, Validation metric: 0.1631
# Estimator 412/2000, Train metric: 0.1622, Validation metric: 0.1630
# Estimator 413/2000, Train metric: 0.1622, Validation metric: 0.1630
# Estimator 414/2000, Train metric: 0.1622, Validation metric: 0.1630
# Estimator 415/2000, Train metric: 0.1622, Validation metric: 0.1630
# Estimator 416/2000, Train metric: 0.1621, Validation metric: 0.1630
# Estimator 417/2000, Train metric: 0.1621, Validation metric: 0.1630
# Estimator 418/2000, Train metric: 0.1621, Validation metric: 0.1630
# Estimator 419/2000, Train metric: 0.1621, Validation metric: 0.1629
# Estimator 420/2000, Train metric: 0.1621, Validation metric: 0.1629
# Estimator 421/2000, Train metric: 0.1621, Validation metric: 0.1629
# Estimator 422/2000, Train metric: 0.1621, Validation metric: 0.1629
# Estimator 423/2000, Train metric: 0.1620, Validation metric: 0.1629
# Estimator 424/2000, Train metric: 0.1620, Validation metric: 0.1629
# Estimator 425/2000, Train metric: 0.1620, Validation metric: 0.1629
# Estimator 426/2000, Train metric: 0.1620, Validation metric: 0.1628
# Estimator 427/2000, Train metric: 0.1620, Validation metric: 0.1628
# Estimator 428/2000, Train metric: 0.1620, Validation metric: 0.1628
# Estimator 429/2000, Train metric: 0.1619, Validation metric: 0.1627
# Estimator 430/2000, Train metric: 0.1619, Validation metric: 0.1627
# Estimator 431/2000, Train metric: 0.1619, Validation metric: 0.1627
# Estimator 432/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 433/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 434/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 435/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 436/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 437/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 438/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 439/2000, Train metric: 0.1618, Validation metric: 0.1627
# Estimator 440/2000, Train metric: 0.1618, Validation metric: 0.1626
# Estimator 441/2000, Train metric: 0.1618, Validation metric: 0.1626
# Estimator 442/2000, Train metric: 0.1617, Validation metric: 0.1626
# Estimator 443/2000, Train metric: 0.1617, Validation metric: 0.1626
# Estimator 444/2000, Train metric: 0.1617, Validation metric: 0.1626
# Estimator 445/2000, Train metric: 0.1617, Validation metric: 0.1626
# Estimator 446/2000, Train metric: 0.1617, Validation metric: 0.1625
# Estimator 447/2000, Train metric: 0.1617, Validation metric: 0.1625
# Estimator 448/2000, Train metric: 0.1617, Validation metric: 0.1625
# Estimator 449/2000, Train metric: 0.1617, Validation metric: 0.1625
# Estimator 450/2000, Train metric: 0.1617, Validation metric: 0.1625
# Estimator 451/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 452/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 453/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 454/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 455/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 456/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 457/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 458/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 459/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 460/2000, Train metric: 0.1616, Validation metric: 0.1625
# Estimator 461/2000, Train metric: 0.1616, Validation metric: 0.1624
# Estimator 462/2000, Train metric: 0.1616, Validation metric: 0.1624
# Estimator 463/2000, Train metric: 0.1616, Validation metric: 0.1624
# Estimator 464/2000, Train metric: 0.1616, Validation metric: 0.1624
# Estimator 465/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 466/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 467/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 468/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 469/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 470/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 471/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 472/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 473/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 474/2000, Train metric: 0.1615, Validation metric: 0.1624
# Estimator 475/2000, Train metric: 0.1615, Validation metric: 0.1623
# Estimator 476/2000, Train metric: 0.1615, Validation metric: 0.1623
# Estimator 477/2000, Train metric: 0.1615, Validation metric: 0.1623
# Estimator 478/2000, Train metric: 0.1615, Validation metric: 0.1623
# Estimator 479/2000, Train metric: 0.1615, Validation metric: 0.1623
# Estimator 480/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 481/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 482/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 483/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 484/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 485/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 486/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 487/2000, Train metric: 0.1614, Validation metric: 0.1623
# Estimator 488/2000, Train metric: 0.1614, Validation metric: 0.1622
# Estimator 489/2000, Train metric: 0.1614, Validation metric: 0.1622
# Estimator 490/2000, Train metric: 0.1614, Validation metric: 0.1622
# Estimator 491/2000, Train metric: 0.1613, Validation metric: 0.1622
# Estimator 492/2000, Train metric: 0.1613, Validation metric: 0.1622
# Estimator 493/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 494/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 495/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 496/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 497/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 498/2000, Train metric: 0.1613, Validation metric: 0.1621
# Estimator 499/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 500/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 501/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 502/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 503/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 504/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 505/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 506/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 507/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 508/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 509/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 510/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 511/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 512/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 513/2000, Train metric: 0.1612, Validation metric: 0.1621
# Estimator 514/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 515/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 516/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 517/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 518/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 519/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 520/2000, Train metric: 0.1612, Validation metric: 0.1620
# Estimator 521/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 522/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 523/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 524/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 525/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 526/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 527/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 528/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 529/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 530/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 531/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 532/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 533/2000, Train metric: 0.1611, Validation metric: 0.1620
# Estimator 534/2000, Train metric: 0.1611, Validation metric: 0.1619
# Estimator 535/2000, Train metric: 0.1611, Validation metric: 0.1619
# Estimator 536/2000, Train metric: 0.1611, Validation metric: 0.1619
# Estimator 537/2000, Train metric: 0.1611, Validation metric: 0.1619
# Estimator 538/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 539/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 540/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 541/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 542/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 543/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 544/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 545/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 546/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 547/2000, Train metric: 0.1610, Validation metric: 0.1619
# Estimator 548/2000, Train metric: 0.1610, Validation metric: 0.1618
# Estimator 549/2000, Train metric: 0.1610, Validation metric: 0.1618
# Estimator 550/2000, Train metric: 0.1610, Validation metric: 0.1618
# Estimator 551/2000, Train metric: 0.1610, Validation metric: 0.1618
# Estimator 552/2000, Train metric: 0.1610, Validation metric: 0.1618
# Estimator 553/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 554/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 555/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 556/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 557/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 558/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 559/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 560/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 561/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 562/2000, Train metric: 0.1609, Validation metric: 0.1618
# Estimator 563/2000, Train metric: 0.1609, Validation metric: 0.1617
# Estimator 564/2000, Train metric: 0.1609, Validation metric: 0.1617
# Estimator 565/2000, Train metric: 0.1609, Validation metric: 0.1617
# Estimator 566/2000, Train metric: 0.1608, Validation metric: 0.1617
# Estimator 567/2000, Train metric: 0.1608, Validation metric: 0.1617
# Estimator 568/2000, Train metric: 0.1608, Validation metric: 0.1617
# Estimator 569/2000, Train metric: 0.1608, Validation metric: 0.1617
# Estimator 570/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 571/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 572/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 573/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 574/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 575/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 576/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 577/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 578/2000, Train metric: 0.1608, Validation metric: 0.1616
# Estimator 579/2000, Train metric: 0.1607, Validation metric: 0.1616
# Estimator 580/2000, Train metric: 0.1607, Validation metric: 0.1616
# Estimator 581/2000, Train metric: 0.1607, Validation metric: 0.1616
# Estimator 582/2000, Train metric: 0.1607, Validation metric: 0.1616
# Estimator 583/2000, Train metric: 0.1607, Validation metric: 0.1616
# Estimator 584/2000, Train metric: 0.1607, Validation metric: 0.1615
# Estimator 585/2000, Train metric: 0.1607, Validation metric: 0.1615
# Estimator 586/2000, Train metric: 0.1607, Validation metric: 0.1615
# Estimator 587/2000, Train metric: 0.1607, Validation metric: 0.1615
# Estimator 588/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 589/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 590/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 591/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 592/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 593/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 594/2000, Train metric: 0.1606, Validation metric: 0.1615
# Estimator 595/2000, Train metric: 0.1606, Validation metric: 0.1614
# Estimator 596/2000, Train metric: 0.1606, Validation metric: 0.1614
# Estimator 597/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 598/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 599/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 600/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 601/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 602/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 603/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 604/2000, Train metric: 0.1605, Validation metric: 0.1614
# Estimator 605/2000, Train metric: 0.1605, Validation metric: 0.1613
# Estimator 606/2000, Train metric: 0.1605, Validation metric: 0.1613
# Estimator 607/2000, Train metric: 0.1605, Validation metric: 0.1613
# Estimator 608/2000, Train metric: 0.1605, Validation metric: 0.1613
# Estimator 609/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 610/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 611/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 612/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 613/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 614/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 615/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 616/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 617/2000, Train metric: 0.1604, Validation metric: 0.1613
# Estimator 618/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 619/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 620/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 621/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 622/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 623/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 624/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 625/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 626/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 627/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 628/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 629/2000, Train metric: 0.1604, Validation metric: 0.1612
# Estimator 630/2000, Train metric: 0.1603, Validation metric: 0.1612
# Estimator 631/2000, Train metric: 0.1603, Validation metric: 0.1612
# Estimator 632/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 633/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 634/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 635/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 636/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 637/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 638/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 639/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 640/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 641/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 642/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 643/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 644/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 645/2000, Train metric: 0.1603, Validation metric: 0.1611
# Estimator 646/2000, Train metric: 0.1602, Validation metric: 0.1611
# Estimator 647/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 648/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 649/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 650/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 651/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 652/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 653/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 654/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 655/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 656/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 657/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 658/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 659/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 660/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 661/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 662/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 663/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 664/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 665/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 666/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 667/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 668/2000, Train metric: 0.1602, Validation metric: 0.1610
# Estimator 669/2000, Train metric: 0.1602, Validation metric: 0.1609
# Estimator 670/2000, Train metric: 0.1602, Validation metric: 0.1609
# Estimator 671/2000, Train metric: 0.1602, Validation metric: 0.1609
# Estimator 672/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 673/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 674/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 675/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 676/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 677/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 678/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 679/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 680/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 681/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 682/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 683/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 684/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 685/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 686/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 687/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 688/2000, Train metric: 0.1601, Validation metric: 0.1609
# Estimator 689/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 690/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 691/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 692/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 693/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 694/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 695/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 696/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 697/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 698/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 699/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 700/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 701/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 702/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 703/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 704/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 705/2000, Train metric: 0.1600, Validation metric: 0.1608
# Estimator 706/2000, Train metric: 0.1599, Validation metric: 0.1608
# ...
# Estimator 1769/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1770/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1771/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1772/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1773/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1774/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1775/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1776/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1777/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1778/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1779/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1780/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1781/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1782/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1783/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1784/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1785/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1786/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1787/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1788/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1789/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1790/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1791/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1792/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1793/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1794/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1795/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1796/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1797/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1798/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1799/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1800/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1801/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1802/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1803/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1804/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1805/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1806/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1807/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1808/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1809/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1810/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1811/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1812/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1813/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1814/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1815/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1816/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1817/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1818/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1819/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1820/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1821/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1822/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1823/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1824/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1825/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1826/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1827/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1828/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1829/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1830/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1831/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1832/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1833/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1834/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1835/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1836/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1837/2000, Train metric: 0.1572, Validation metric: 0.1578
# Estimator 1838/2000, Train metric: 0.1572, Validation metric: 0.1577
# Estimator 1839/2000, Train metric: 0.1572, Validation metric: 0.1577
# Estimator 1840/2000, Train metric: 0.1572, Validation metric: 0.1577
# Estimator 1841/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1842/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1843/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1844/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1845/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1846/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1847/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1848/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1849/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1850/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1851/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1852/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1853/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1854/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1855/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1856/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1857/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1858/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1859/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1860/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1861/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1862/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1863/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1864/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1865/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1866/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1867/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1868/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1869/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1870/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1871/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1872/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1873/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1874/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1875/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1876/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1877/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1878/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1879/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1880/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1881/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1882/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1883/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1884/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1885/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1886/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1887/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1888/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1889/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1890/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1891/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1892/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1893/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1894/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1895/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1896/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1897/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1898/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1899/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1900/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1901/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1902/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1903/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1904/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1905/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1906/2000, Train metric: 0.1571, Validation metric: 0.1577
# Estimator 1907/2000, Train metric: 0.1571, Validation metric: 0.1576
# Estimator 1908/2000, Train metric: 0.1571, Validation metric: 0.1576
# Estimator 1909/2000, Train metric: 0.1571, Validation metric: 0.1576
# Estimator 1910/2000, Train metric: 0.1571, Validation metric: 0.1576
# Estimator 1911/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1912/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1913/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1914/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1915/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1916/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1917/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1918/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1919/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1920/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1921/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1922/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1923/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1924/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1925/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1926/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1927/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1928/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1929/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1930/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1931/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1932/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1933/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1934/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1935/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1936/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1937/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1938/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1939/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1940/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1941/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1942/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1943/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1944/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1945/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1946/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1947/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1948/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1949/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1950/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1951/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1952/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1953/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1954/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1955/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1956/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1957/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1958/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1959/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1960/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1961/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1962/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1963/2000, Train metric: 0.1570, Validation metric: 0.1576
# Estimator 1964/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1965/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1966/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1967/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1968/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1969/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1970/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1971/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1972/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1973/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1974/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1975/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1976/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1977/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1978/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1979/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1980/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1981/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1982/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1983/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1984/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1985/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1986/2000, Train metric: 0.1570, Validation metric: 0.1575
# Estimator 1987/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1988/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1989/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1990/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1991/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1992/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1993/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1994/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1995/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1996/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1997/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1998/2000, Train metric: 0.1569, Validation metric: 0.1575
# Estimator 1999/2000, Train metric: 0.1569, Validation metric: 0.1575

# %%
model.optimize_distribution(x_val.values, y_val.values.reshape(-1))
# Out:
# CRPS: 0.19 (Distribution: normal, Tree correlation: 0.000)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: normal, Tree correlation: 0.020)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.110)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.120)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.130)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.140)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.190)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.000)
# CRPS: 0.11 (Distribution: studentt, Tree correlation: 0.010)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.110)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.120)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.130)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.140)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.190)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.000)
# CRPS: 0.12 (Distribution: laplace, Tree correlation: 0.010)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.110)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.120)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.130)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.140)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: laplace, Tree correlation: 0.190)
# CRPS: 0.17 (Distribution: logistic, Tree correlation: 0.000)
# CRPS: 0.13 (Distribution: logistic, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: logistic, Tree correlation: 0.020)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.110)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.120)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.130)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.140)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.190)
# CRPS: 0.19 (Distribution: gamma, Tree correlation: 0.000)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: gamma, Tree correlation: 0.020)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.110)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.120)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.130)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.140)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.190)
# CRPS: 0.18 (Distribution: gumbel, Tree correlation: 0.000)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.010)
# CRPS: 0.11 (Distribution: gumbel, Tree correlation: 0.020)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.070)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.080)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.090)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.100)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.110)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.120)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.130)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.140)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.150)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.160)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.170)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.180)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.190)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.000)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.010)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.020)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.030)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.040)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.050)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.060)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.070)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.080)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.090)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.100)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.110)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.120)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.130)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.140)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.150)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.160)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.170)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.180)
# CRPS: 0.60 (Distribution: poisson, Tree correlation: 0.190)
# Lowest CRPS: 0.0769 (Distribution: logistic, Tree correlation: 0.060)
# ('logistic', 0.06)

# %%
y_train_dist = model.predict_dist(x_train.values, n_forecasts=1000)
y_val_dist = model.predict_dist(x_val.values, n_forecasts=1000)
y_test_dist = model.predict_dist(x_test.values, n_forecasts=1000)

# %%
print(model.crps_ensemble(y_train_dist, y_train.values.reshape(-1)).mean())
print(model.crps_ensemble(y_val_dist, y_val.values.reshape(-1)).mean())
print(model.crps_ensemble(y_test_dist, y_test.values.reshape(-1)).mean())
# Out:
# 0.07620389661486603
# 0.0762696452176025
# 0.07580891578187751
