# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/bigmart/bigmart.csv')
df['Outlet_Size'] = df['Outlet_Size'].fillna('')

# %%
x = df.drop(columns = ['Item_Identifier', 'Item_Outlet_Sales'])
x = pd.get_dummies(x)
y = np.log10(df[['Item_Outlet_Sales']])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((6818, 46), (1705, 46))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 0.4243, Validation metric: 0.4160
# Estimator 1/2000, Train metric: 0.4133, Validation metric: 0.4034
# Estimator 2/2000, Train metric: 0.4037, Validation metric: 0.3922
# Estimator 3/2000, Train metric: 0.3957, Validation metric: 0.3831
# Estimator 4/2000, Train metric: 0.3890, Validation metric: 0.3755
# Estimator 5/2000, Train metric: 0.3786, Validation metric: 0.3650
# Estimator 6/2000, Train metric: 0.3735, Validation metric: 0.3590
# Estimator 7/2000, Train metric: 0.3691, Validation metric: 0.3539
# Estimator 8/2000, Train metric: 0.3649, Validation metric: 0.3494
# Estimator 9/2000, Train metric: 0.3618, Validation metric: 0.3456
# Estimator 10/2000, Train metric: 0.3561, Validation metric: 0.3405
# Estimator 11/2000, Train metric: 0.3525, Validation metric: 0.3369
# Estimator 12/2000, Train metric: 0.3482, Validation metric: 0.3330
# Estimator 13/2000, Train metric: 0.3412, Validation metric: 0.3271
# Estimator 14/2000, Train metric: 0.3391, Validation metric: 0.3245
# Estimator 15/2000, Train metric: 0.3334, Validation metric: 0.3199
# Estimator 16/2000, Train metric: 0.3319, Validation metric: 0.3185
# Estimator 17/2000, Train metric: 0.3279, Validation metric: 0.3150
# Estimator 18/2000, Train metric: 0.3239, Validation metric: 0.3117
# Estimator 19/2000, Train metric: 0.3212, Validation metric: 0.3094
# Estimator 20/2000, Train metric: 0.3191, Validation metric: 0.3075
# Estimator 21/2000, Train metric: 0.3165, Validation metric: 0.3054
# Estimator 22/2000, Train metric: 0.3156, Validation metric: 0.3045
# Estimator 23/2000, Train metric: 0.3135, Validation metric: 0.3029
# Estimator 24/2000, Train metric: 0.3122, Validation metric: 0.3017
# Estimator 25/2000, Train metric: 0.3106, Validation metric: 0.3004
# Estimator 26/2000, Train metric: 0.3095, Validation metric: 0.2994
# Estimator 27/2000, Train metric: 0.3089, Validation metric: 0.2989
# Estimator 28/2000, Train metric: 0.3077, Validation metric: 0.2980
# Estimator 29/2000, Train metric: 0.3072, Validation metric: 0.2974
# Estimator 30/2000, Train metric: 0.3056, Validation metric: 0.2962
# Estimator 31/2000, Train metric: 0.3052, Validation metric: 0.2958
# Estimator 32/2000, Train metric: 0.3043, Validation metric: 0.2950
# Estimator 33/2000, Train metric: 0.3038, Validation metric: 0.2945
# Estimator 34/2000, Train metric: 0.3026, Validation metric: 0.2934
# Estimator 35/2000, Train metric: 0.3021, Validation metric: 0.2929
# Estimator 36/2000, Train metric: 0.3016, Validation metric: 0.2925
# Estimator 37/2000, Train metric: 0.3012, Validation metric: 0.2919
# Estimator 38/2000, Train metric: 0.3007, Validation metric: 0.2913
# Estimator 39/2000, Train metric: 0.3005, Validation metric: 0.2911
# Estimator 40/2000, Train metric: 0.3003, Validation metric: 0.2909
# Estimator 41/2000, Train metric: 0.3000, Validation metric: 0.2907
# Estimator 42/2000, Train metric: 0.2998, Validation metric: 0.2906
# Estimator 43/2000, Train metric: 0.2992, Validation metric: 0.2900
# Estimator 44/2000, Train metric: 0.2989, Validation metric: 0.2895
# Estimator 45/2000, Train metric: 0.2984, Validation metric: 0.2891
# Estimator 46/2000, Train metric: 0.2982, Validation metric: 0.2889
# Estimator 47/2000, Train metric: 0.2981, Validation metric: 0.2889
# Estimator 48/2000, Train metric: 0.2980, Validation metric: 0.2887
# Estimator 49/2000, Train metric: 0.2979, Validation metric: 0.2887
# Estimator 50/2000, Train metric: 0.2975, Validation metric: 0.2882
# Estimator 51/2000, Train metric: 0.2972, Validation metric: 0.2878
# Estimator 52/2000, Train metric: 0.2971, Validation metric: 0.2877
# Estimator 53/2000, Train metric: 0.2969, Validation metric: 0.2875
# Estimator 54/2000, Train metric: 0.2967, Validation metric: 0.2874
# Estimator 55/2000, Train metric: 0.2966, Validation metric: 0.2873
# Estimator 56/2000, Train metric: 0.2965, Validation metric: 0.2873
# Estimator 57/2000, Train metric: 0.2963, Validation metric: 0.2869
# Estimator 58/2000, Train metric: 0.2960, Validation metric: 0.2867
# Estimator 59/2000, Train metric: 0.2960, Validation metric: 0.2867
# Estimator 60/2000, Train metric: 0.2959, Validation metric: 0.2865
# Estimator 61/2000, Train metric: 0.2957, Validation metric: 0.2863
# Estimator 62/2000, Train metric: 0.2956, Validation metric: 0.2863
# Estimator 63/2000, Train metric: 0.2955, Validation metric: 0.2862
# Estimator 64/2000, Train metric: 0.2955, Validation metric: 0.2861
# Estimator 65/2000, Train metric: 0.2954, Validation metric: 0.2861
# Estimator 66/2000, Train metric: 0.2952, Validation metric: 0.2859
# Estimator 67/2000, Train metric: 0.2950, Validation metric: 0.2856
# Estimator 68/2000, Train metric: 0.2949, Validation metric: 0.2856
# Estimator 69/2000, Train metric: 0.2948, Validation metric: 0.2855
# Estimator 70/2000, Train metric: 0.2947, Validation metric: 0.2855
# Estimator 71/2000, Train metric: 0.2946, Validation metric: 0.2853
# Estimator 72/2000, Train metric: 0.2945, Validation metric: 0.2852
# Estimator 73/2000, Train metric: 0.2944, Validation metric: 0.2851
# Estimator 74/2000, Train metric: 0.2944, Validation metric: 0.2851
# Estimator 75/2000, Train metric: 0.2943, Validation metric: 0.2851
# Estimator 76/2000, Train metric: 0.2942, Validation metric: 0.2851
# Estimator 77/2000, Train metric: 0.2941, Validation metric: 0.2850
# Estimator 78/2000, Train metric: 0.2940, Validation metric: 0.2849
# Estimator 79/2000, Train metric: 0.2939, Validation metric: 0.2848
# Estimator 80/2000, Train metric: 0.2938, Validation metric: 0.2848
# Estimator 81/2000, Train metric: 0.2937, Validation metric: 0.2847
# Estimator 82/2000, Train metric: 0.2937, Validation metric: 0.2847
# Estimator 83/2000, Train metric: 0.2936, Validation metric: 0.2846
# Estimator 84/2000, Train metric: 0.2935, Validation metric: 0.2845
# Estimator 85/2000, Train metric: 0.2934, Validation metric: 0.2844
# Estimator 86/2000, Train metric: 0.2934, Validation metric: 0.2844
# Estimator 87/2000, Train metric: 0.2933, Validation metric: 0.2843
# Estimator 88/2000, Train metric: 0.2932, Validation metric: 0.2842
# Estimator 89/2000, Train metric: 0.2932, Validation metric: 0.2842
# Estimator 90/2000, Train metric: 0.2931, Validation metric: 0.2841
# Estimator 91/2000, Train metric: 0.2930, Validation metric: 0.2841
# Estimator 92/2000, Train metric: 0.2930, Validation metric: 0.2840
# Estimator 93/2000, Train metric: 0.2929, Validation metric: 0.2840
# Estimator 94/2000, Train metric: 0.2929, Validation metric: 0.2839
# Estimator 95/2000, Train metric: 0.2928, Validation metric: 0.2839
# Estimator 96/2000, Train metric: 0.2928, Validation metric: 0.2838
# Estimator 97/2000, Train metric: 0.2927, Validation metric: 0.2839
# Estimator 98/2000, Train metric: 0.2927, Validation metric: 0.2839
# Estimator 99/2000, Train metric: 0.2926, Validation metric: 0.2837
# Estimator 100/2000, Train metric: 0.2925, Validation metric: 0.2837
# Estimator 101/2000, Train metric: 0.2925, Validation metric: 0.2837
# Estimator 102/2000, Train metric: 0.2925, Validation metric: 0.2836
# Estimator 103/2000, Train metric: 0.2924, Validation metric: 0.2836
# Estimator 104/2000, Train metric: 0.2924, Validation metric: 0.2836
# Estimator 105/2000, Train metric: 0.2923, Validation metric: 0.2835
# Estimator 106/2000, Train metric: 0.2922, Validation metric: 0.2835
# Estimator 107/2000, Train metric: 0.2922, Validation metric: 0.2834
# Estimator 108/2000, Train metric: 0.2921, Validation metric: 0.2833
# Estimator 109/2000, Train metric: 0.2921, Validation metric: 0.2833
# Estimator 110/2000, Train metric: 0.2921, Validation metric: 0.2833
# Estimator 111/2000, Train metric: 0.2920, Validation metric: 0.2832
# Estimator 112/2000, Train metric: 0.2920, Validation metric: 0.2832
# Estimator 113/2000, Train metric: 0.2918, Validation metric: 0.2830
# Estimator 114/2000, Train metric: 0.2918, Validation metric: 0.2830
# Estimator 115/2000, Train metric: 0.2917, Validation metric: 0.2829
# Estimator 116/2000, Train metric: 0.2917, Validation metric: 0.2829
# Estimator 117/2000, Train metric: 0.2916, Validation metric: 0.2829
# Estimator 118/2000, Train metric: 0.2916, Validation metric: 0.2829
# Estimator 119/2000, Train metric: 0.2915, Validation metric: 0.2828
# Estimator 120/2000, Train metric: 0.2914, Validation metric: 0.2827
# Estimator 121/2000, Train metric: 0.2914, Validation metric: 0.2827
# Estimator 122/2000, Train metric: 0.2913, Validation metric: 0.2826
# Estimator 123/2000, Train metric: 0.2913, Validation metric: 0.2826
# Estimator 124/2000, Train metric: 0.2912, Validation metric: 0.2825
# Estimator 125/2000, Train metric: 0.2912, Validation metric: 0.2825
# Estimator 126/2000, Train metric: 0.2911, Validation metric: 0.2824
# Estimator 127/2000, Train metric: 0.2911, Validation metric: 0.2824
# Estimator 128/2000, Train metric: 0.2910, Validation metric: 0.2823
# Estimator 129/2000, Train metric: 0.2910, Validation metric: 0.2823
# Estimator 130/2000, Train metric: 0.2910, Validation metric: 0.2823
# Estimator 131/2000, Train metric: 0.2909, Validation metric: 0.2823
# Estimator 132/2000, Train metric: 0.2909, Validation metric: 0.2821
# Estimator 133/2000, Train metric: 0.2908, Validation metric: 0.2821
# Estimator 134/2000, Train metric: 0.2908, Validation metric: 0.2820
# Estimator 135/2000, Train metric: 0.2907, Validation metric: 0.2820
# Estimator 136/2000, Train metric: 0.2906, Validation metric: 0.2819
# Estimator 137/2000, Train metric: 0.2906, Validation metric: 0.2819
# Estimator 138/2000, Train metric: 0.2905, Validation metric: 0.2817
# Estimator 139/2000, Train metric: 0.2905, Validation metric: 0.2816
# Estimator 140/2000, Train metric: 0.2904, Validation metric: 0.2816
# Estimator 141/2000, Train metric: 0.2904, Validation metric: 0.2816
# Estimator 142/2000, Train metric: 0.2903, Validation metric: 0.2815
# Estimator 143/2000, Train metric: 0.2903, Validation metric: 0.2814
# Estimator 144/2000, Train metric: 0.2903, Validation metric: 0.2814
# Estimator 145/2000, Train metric: 0.2902, Validation metric: 0.2813
# Estimator 146/2000, Train metric: 0.2902, Validation metric: 0.2813
# Estimator 147/2000, Train metric: 0.2901, Validation metric: 0.2813
# Estimator 148/2000, Train metric: 0.2901, Validation metric: 0.2813
# Estimator 149/2000, Train metric: 0.2900, Validation metric: 0.2812
# Estimator 150/2000, Train metric: 0.2900, Validation metric: 0.2812
# Estimator 151/2000, Train metric: 0.2900, Validation metric: 0.2812
# Estimator 152/2000, Train metric: 0.2899, Validation metric: 0.2811
# Estimator 153/2000, Train metric: 0.2899, Validation metric: 0.2810
# Estimator 154/2000, Train metric: 0.2898, Validation metric: 0.2810
# Estimator 155/2000, Train metric: 0.2898, Validation metric: 0.2809
# Estimator 156/2000, Train metric: 0.2897, Validation metric: 0.2809
# Estimator 157/2000, Train metric: 0.2897, Validation metric: 0.2809
# Estimator 158/2000, Train metric: 0.2897, Validation metric: 0.2809
# Estimator 159/2000, Train metric: 0.2896, Validation metric: 0.2809
# Estimator 160/2000, Train metric: 0.2896, Validation metric: 0.2808
# Estimator 161/2000, Train metric: 0.2896, Validation metric: 0.2808
# Estimator 162/2000, Train metric: 0.2896, Validation metric: 0.2807
# Estimator 163/2000, Train metric: 0.2895, Validation metric: 0.2807
# Estimator 164/2000, Train metric: 0.2895, Validation metric: 0.2808
# Estimator 165/2000, Train metric: 0.2894, Validation metric: 0.2807
# Estimator 166/2000, Train metric: 0.2894, Validation metric: 0.2807
# Estimator 167/2000, Train metric: 0.2893, Validation metric: 0.2807
# Estimator 168/2000, Train metric: 0.2893, Validation metric: 0.2806
# Estimator 169/2000, Train metric: 0.2893, Validation metric: 0.2806
# Estimator 170/2000, Train metric: 0.2892, Validation metric: 0.2805
# Estimator 171/2000, Train metric: 0.2892, Validation metric: 0.2805
# Estimator 172/2000, Train metric: 0.2892, Validation metric: 0.2804
# Estimator 173/2000, Train metric: 0.2891, Validation metric: 0.2804
# Estimator 174/2000, Train metric: 0.2891, Validation metric: 0.2803
# Estimator 175/2000, Train metric: 0.2890, Validation metric: 0.2803
# Estimator 176/2000, Train metric: 0.2890, Validation metric: 0.2803
# Estimator 177/2000, Train metric: 0.2890, Validation metric: 0.2802
# Estimator 178/2000, Train metric: 0.2889, Validation metric: 0.2802
# Estimator 179/2000, Train metric: 0.2889, Validation metric: 0.2801
# Estimator 180/2000, Train metric: 0.2888, Validation metric: 0.2801
# Estimator 181/2000, Train metric: 0.2888, Validation metric: 0.2801
# Estimator 182/2000, Train metric: 0.2888, Validation metric: 0.2800
# Estimator 183/2000, Train metric: 0.2887, Validation metric: 0.2800
# Estimator 184/2000, Train metric: 0.2887, Validation metric: 0.2800
# Estimator 185/2000, Train metric: 0.2887, Validation metric: 0.2800
# Estimator 186/2000, Train metric: 0.2886, Validation metric: 0.2800
# Estimator 187/2000, Train metric: 0.2886, Validation metric: 0.2800
# Estimator 188/2000, Train metric: 0.2885, Validation metric: 0.2799
# Estimator 189/2000, Train metric: 0.2885, Validation metric: 0.2799
# Estimator 190/2000, Train metric: 0.2885, Validation metric: 0.2799
# Estimator 191/2000, Train metric: 0.2885, Validation metric: 0.2799
# Estimator 192/2000, Train metric: 0.2884, Validation metric: 0.2798
# Estimator 193/2000, Train metric: 0.2884, Validation metric: 0.2798
# Estimator 194/2000, Train metric: 0.2884, Validation metric: 0.2798
# Estimator 195/2000, Train metric: 0.2883, Validation metric: 0.2798
# Estimator 196/2000, Train metric: 0.2883, Validation metric: 0.2797
# Estimator 197/2000, Train metric: 0.2883, Validation metric: 0.2796
# Estimator 198/2000, Train metric: 0.2882, Validation metric: 0.2796
# Estimator 199/2000, Train metric: 0.2882, Validation metric: 0.2795
# Estimator 200/2000, Train metric: 0.2882, Validation metric: 0.2795
# Estimator 201/2000, Train metric: 0.2881, Validation metric: 0.2794
# Estimator 202/2000, Train metric: 0.2881, Validation metric: 0.2793
# Estimator 203/2000, Train metric: 0.2881, Validation metric: 0.2793
# Estimator 204/2000, Train metric: 0.2880, Validation metric: 0.2793
# Estimator 205/2000, Train metric: 0.2880, Validation metric: 0.2792
# Estimator 206/2000, Train metric: 0.2879, Validation metric: 0.2792
# Estimator 207/2000, Train metric: 0.2879, Validation metric: 0.2791
# Estimator 208/2000, Train metric: 0.2879, Validation metric: 0.2790
# Estimator 209/2000, Train metric: 0.2878, Validation metric: 0.2790
# Estimator 210/2000, Train metric: 0.2878, Validation metric: 0.2789
# Estimator 211/2000, Train metric: 0.2877, Validation metric: 0.2789
# Estimator 212/2000, Train metric: 0.2877, Validation metric: 0.2788
# Estimator 213/2000, Train metric: 0.2877, Validation metric: 0.2788
# Estimator 214/2000, Train metric: 0.2877, Validation metric: 0.2788
# Estimator 215/2000, Train metric: 0.2876, Validation metric: 0.2787
# Estimator 216/2000, Train metric: 0.2876, Validation metric: 0.2788
# Estimator 217/2000, Train metric: 0.2876, Validation metric: 0.2788
# Estimator 218/2000, Train metric: 0.2875, Validation metric: 0.2788
# Estimator 219/2000, Train metric: 0.2875, Validation metric: 0.2787
# Estimator 220/2000, Train metric: 0.2875, Validation metric: 0.2787
# Estimator 221/2000, Train metric: 0.2875, Validation metric: 0.2787
# Estimator 222/2000, Train metric: 0.2874, Validation metric: 0.2786
# Estimator 223/2000, Train metric: 0.2874, Validation metric: 0.2786
# Estimator 224/2000, Train metric: 0.2873, Validation metric: 0.2784
# Estimator 225/2000, Train metric: 0.2873, Validation metric: 0.2784
# Estimator 226/2000, Train metric: 0.2872, Validation metric: 0.2784
# Estimator 227/2000, Train metric: 0.2872, Validation metric: 0.2783
# Estimator 228/2000, Train metric: 0.2872, Validation metric: 0.2783
# Estimator 229/2000, Train metric: 0.2871, Validation metric: 0.2782
# Estimator 230/2000, Train metric: 0.2871, Validation metric: 0.2781
# Estimator 231/2000, Train metric: 0.2870, Validation metric: 0.2781
# Estimator 232/2000, Train metric: 0.2870, Validation metric: 0.2781
# Estimator 233/2000, Train metric: 0.2870, Validation metric: 0.2781
# Estimator 234/2000, Train metric: 0.2869, Validation metric: 0.2779
# Estimator 235/2000, Train metric: 0.2869, Validation metric: 0.2779
# Estimator 236/2000, Train metric: 0.2869, Validation metric: 0.2779
# Estimator 237/2000, Train metric: 0.2868, Validation metric: 0.2779
# Estimator 238/2000, Train metric: 0.2868, Validation metric: 0.2778
# Estimator 239/2000, Train metric: 0.2868, Validation metric: 0.2778
# Estimator 240/2000, Train metric: 0.2867, Validation metric: 0.2778
# Estimator 241/2000, Train metric: 0.2867, Validation metric: 0.2778
# Estimator 242/2000, Train metric: 0.2867, Validation metric: 0.2777
# Estimator 243/2000, Train metric: 0.2866, Validation metric: 0.2777
# Estimator 244/2000, Train metric: 0.2866, Validation metric: 0.2776
# Estimator 245/2000, Train metric: 0.2866, Validation metric: 0.2776
# Estimator 246/2000, Train metric: 0.2865, Validation metric: 0.2775
# Estimator 247/2000, Train metric: 0.2865, Validation metric: 0.2775
# Estimator 248/2000, Train metric: 0.2865, Validation metric: 0.2774
# Estimator 249/2000, Train metric: 0.2864, Validation metric: 0.2774
# Estimator 250/2000, Train metric: 0.2864, Validation metric: 0.2773
# Estimator 251/2000, Train metric: 0.2864, Validation metric: 0.2773
# Estimator 252/2000, Train metric: 0.2864, Validation metric: 0.2773
# Estimator 253/2000, Train metric: 0.2863, Validation metric: 0.2773
# Estimator 254/2000, Train metric: 0.2863, Validation metric: 0.2772
# Estimator 255/2000, Train metric: 0.2862, Validation metric: 0.2772
# Estimator 256/2000, Train metric: 0.2862, Validation metric: 0.2771
# Estimator 257/2000, Train metric: 0.2862, Validation metric: 0.2771
# Estimator 258/2000, Train metric: 0.2861, Validation metric: 0.2770
# Estimator 259/2000, Train metric: 0.2861, Validation metric: 0.2770
# Estimator 260/2000, Train metric: 0.2860, Validation metric: 0.2770
# Estimator 261/2000, Train metric: 0.2860, Validation metric: 0.2770
# Estimator 262/2000, Train metric: 0.2860, Validation metric: 0.2770
# Estimator 263/2000, Train metric: 0.2860, Validation metric: 0.2769
# Estimator 264/2000, Train metric: 0.2859, Validation metric: 0.2769
# Estimator 265/2000, Train metric: 0.2859, Validation metric: 0.2768
# Estimator 266/2000, Train metric: 0.2858, Validation metric: 0.2768
# Estimator 267/2000, Train metric: 0.2858, Validation metric: 0.2767
# Estimator 268/2000, Train metric: 0.2858, Validation metric: 0.2767
# Estimator 269/2000, Train metric: 0.2858, Validation metric: 0.2767
# Estimator 270/2000, Train metric: 0.2857, Validation metric: 0.2766
# Estimator 271/2000, Train metric: 0.2857, Validation metric: 0.2766
# Estimator 272/2000, Train metric: 0.2856, Validation metric: 0.2765
# Estimator 273/2000, Train metric: 0.2856, Validation metric: 0.2765
# Estimator 274/2000, Train metric: 0.2856, Validation metric: 0.2765
# Estimator 275/2000, Train metric: 0.2856, Validation metric: 0.2764
# Estimator 276/2000, Train metric: 0.2855, Validation metric: 0.2764
# Estimator 277/2000, Train metric: 0.2855, Validation metric: 0.2763
# Estimator 278/2000, Train metric: 0.2855, Validation metric: 0.2763
# Estimator 279/2000, Train metric: 0.2854, Validation metric: 0.2762
# Estimator 280/2000, Train metric: 0.2854, Validation metric: 0.2762
# Estimator 281/2000, Train metric: 0.2853, Validation metric: 0.2762
# Estimator 282/2000, Train metric: 0.2853, Validation metric: 0.2761
# Estimator 283/2000, Train metric: 0.2853, Validation metric: 0.2761
# Estimator 284/2000, Train metric: 0.2853, Validation metric: 0.2760
# Estimator 285/2000, Train metric: 0.2852, Validation metric: 0.2760
# Estimator 286/2000, Train metric: 0.2852, Validation metric: 0.2760
# Estimator 287/2000, Train metric: 0.2852, Validation metric: 0.2760
# Estimator 288/2000, Train metric: 0.2852, Validation metric: 0.2760
# Estimator 289/2000, Train metric: 0.2851, Validation metric: 0.2760
# Estimator 290/2000, Train metric: 0.2851, Validation metric: 0.2759
# Estimator 291/2000, Train metric: 0.2851, Validation metric: 0.2759
# Estimator 292/2000, Train metric: 0.2851, Validation metric: 0.2759
# Estimator 293/2000, Train metric: 0.2851, Validation metric: 0.2759
# Estimator 294/2000, Train metric: 0.2850, Validation metric: 0.2759
# Estimator 295/2000, Train metric: 0.2850, Validation metric: 0.2759
# Estimator 296/2000, Train metric: 0.2850, Validation metric: 0.2758
# Estimator 297/2000, Train metric: 0.2850, Validation metric: 0.2758
# Estimator 298/2000, Train metric: 0.2849, Validation metric: 0.2758
# Estimator 299/2000, Train metric: 0.2849, Validation metric: 0.2757
# Estimator 300/2000, Train metric: 0.2849, Validation metric: 0.2756
# Estimator 301/2000, Train metric: 0.2848, Validation metric: 0.2755
# Estimator 302/2000, Train metric: 0.2848, Validation metric: 0.2755
# Estimator 303/2000, Train metric: 0.2848, Validation metric: 0.2755
# Estimator 304/2000, Train metric: 0.2848, Validation metric: 0.2754
# Estimator 305/2000, Train metric: 0.2847, Validation metric: 0.2754
# Estimator 306/2000, Train metric: 0.2847, Validation metric: 0.2754
# Estimator 307/2000, Train metric: 0.2847, Validation metric: 0.2753
# Estimator 308/2000, Train metric: 0.2846, Validation metric: 0.2753
# Estimator 309/2000, Train metric: 0.2846, Validation metric: 0.2753
# Estimator 310/2000, Train metric: 0.2846, Validation metric: 0.2753
# Estimator 311/2000, Train metric: 0.2846, Validation metric: 0.2753
# Estimator 312/2000, Train metric: 0.2845, Validation metric: 0.2753
# Estimator 313/2000, Train metric: 0.2845, Validation metric: 0.2752
# Estimator 314/2000, Train metric: 0.2845, Validation metric: 0.2752
# Estimator 315/2000, Train metric: 0.2844, Validation metric: 0.2752
# Estimator 316/2000, Train metric: 0.2844, Validation metric: 0.2751
# Estimator 317/2000, Train metric: 0.2844, Validation metric: 0.2751
# Estimator 318/2000, Train metric: 0.2843, Validation metric: 0.2751
# Estimator 319/2000, Train metric: 0.2843, Validation metric: 0.2750
# Estimator 320/2000, Train metric: 0.2843, Validation metric: 0.2750
# Estimator 321/2000, Train metric: 0.2843, Validation metric: 0.2750
# Estimator 322/2000, Train metric: 0.2842, Validation metric: 0.2750
# Estimator 323/2000, Train metric: 0.2842, Validation metric: 0.2750
# Estimator 324/2000, Train metric: 0.2842, Validation metric: 0.2750
# Estimator 325/2000, Train metric: 0.2841, Validation metric: 0.2749
# Estimator 326/2000, Train metric: 0.2841, Validation metric: 0.2748
# Estimator 327/2000, Train metric: 0.2841, Validation metric: 0.2749
# Estimator 328/2000, Train metric: 0.2840, Validation metric: 0.2748
# Estimator 329/2000, Train metric: 0.2840, Validation metric: 0.2748
# Estimator 330/2000, Train metric: 0.2840, Validation metric: 0.2747
# Estimator 331/2000, Train metric: 0.2840, Validation metric: 0.2747
# Estimator 332/2000, Train metric: 0.2840, Validation metric: 0.2748
# Estimator 333/2000, Train metric: 0.2839, Validation metric: 0.2747
# Estimator 334/2000, Train metric: 0.2839, Validation metric: 0.2746
# Estimator 335/2000, Train metric: 0.2839, Validation metric: 0.2746
# Estimator 336/2000, Train metric: 0.2838, Validation metric: 0.2746
# Estimator 337/2000, Train metric: 0.2838, Validation metric: 0.2746
# Estimator 338/2000, Train metric: 0.2838, Validation metric: 0.2745
# Estimator 339/2000, Train metric: 0.2838, Validation metric: 0.2745
# Estimator 340/2000, Train metric: 0.2838, Validation metric: 0.2745
# Estimator 341/2000, Train metric: 0.2837, Validation metric: 0.2744
# Estimator 342/2000, Train metric: 0.2837, Validation metric: 0.2744
# Estimator 343/2000, Train metric: 0.2837, Validation metric: 0.2744
# Estimator 344/2000, Train metric: 0.2836, Validation metric: 0.2744
# Estimator 345/2000, Train metric: 0.2836, Validation metric: 0.2743
# Estimator 346/2000, Train metric: 0.2836, Validation metric: 0.2743
# Estimator 347/2000, Train metric: 0.2836, Validation metric: 0.2742
# Estimator 348/2000, Train metric: 0.2835, Validation metric: 0.2743
# Estimator 349/2000, Train metric: 0.2835, Validation metric: 0.2742
# Estimator 350/2000, Train metric: 0.2835, Validation metric: 0.2742
# Estimator 351/2000, Train metric: 0.2835, Validation metric: 0.2742
# Estimator 352/2000, Train metric: 0.2835, Validation metric: 0.2742
# Estimator 353/2000, Train metric: 0.2834, Validation metric: 0.2742
# Estimator 354/2000, Train metric: 0.2834, Validation metric: 0.2741
# Estimator 355/2000, Train metric: 0.2834, Validation metric: 0.2741
# Estimator 356/2000, Train metric: 0.2833, Validation metric: 0.2741
# Estimator 357/2000, Train metric: 0.2833, Validation metric: 0.2741
# Estimator 358/2000, Train metric: 0.2833, Validation metric: 0.2741
# Estimator 359/2000, Train metric: 0.2833, Validation metric: 0.2740
# Estimator 360/2000, Train metric: 0.2833, Validation metric: 0.2741
# Estimator 361/2000, Train metric: 0.2832, Validation metric: 0.2740
# Estimator 362/2000, Train metric: 0.2832, Validation metric: 0.2740
# Estimator 363/2000, Train metric: 0.2832, Validation metric: 0.2740
# Estimator 364/2000, Train metric: 0.2832, Validation metric: 0.2739
# Estimator 365/2000, Train metric: 0.2831, Validation metric: 0.2739
# Estimator 366/2000, Train metric: 0.2831, Validation metric: 0.2739
# Estimator 367/2000, Train metric: 0.2831, Validation metric: 0.2738
# Estimator 368/2000, Train metric: 0.2831, Validation metric: 0.2738
# Estimator 369/2000, Train metric: 0.2830, Validation metric: 0.2738
# Estimator 370/2000, Train metric: 0.2830, Validation metric: 0.2738
# Estimator 371/2000, Train metric: 0.2830, Validation metric: 0.2738
# Estimator 372/2000, Train metric: 0.2830, Validation metric: 0.2738
# Estimator 373/2000, Train metric: 0.2829, Validation metric: 0.2737
# Estimator 374/2000, Train metric: 0.2829, Validation metric: 0.2737
# Estimator 375/2000, Train metric: 0.2829, Validation metric: 0.2737
# Estimator 376/2000, Train metric: 0.2828, Validation metric: 0.2736
# Estimator 377/2000, Train metric: 0.2828, Validation metric: 0.2736
# Estimator 378/2000, Train metric: 0.2828, Validation metric: 0.2735
# Estimator 379/2000, Train metric: 0.2827, Validation metric: 0.2735
# Estimator 380/2000, Train metric: 0.2827, Validation metric: 0.2735
# Estimator 381/2000, Train metric: 0.2827, Validation metric: 0.2735
# Estimator 382/2000, Train metric: 0.2826, Validation metric: 0.2735
# Estimator 383/2000, Train metric: 0.2826, Validation metric: 0.2735
# Estimator 384/2000, Train metric: 0.2826, Validation metric: 0.2734
# Estimator 385/2000, Train metric: 0.2826, Validation metric: 0.2734
# Estimator 386/2000, Train metric: 0.2826, Validation metric: 0.2734
# Estimator 387/2000, Train metric: 0.2825, Validation metric: 0.2734
# Estimator 388/2000, Train metric: 0.2825, Validation metric: 0.2733
# Estimator 389/2000, Train metric: 0.2825, Validation metric: 0.2733
# Estimator 390/2000, Train metric: 0.2825, Validation metric: 0.2732
# Estimator 391/2000, Train metric: 0.2824, Validation metric: 0.2732
# Estimator 392/2000, Train metric: 0.2824, Validation metric: 0.2732
# Estimator 393/2000, Train metric: 0.2824, Validation metric: 0.2731
# Estimator 394/2000, Train metric: 0.2824, Validation metric: 0.2731
# Estimator 395/2000, Train metric: 0.2823, Validation metric: 0.2730
# Estimator 396/2000, Train metric: 0.2823, Validation metric: 0.2730
# Estimator 397/2000, Train metric: 0.2823, Validation metric: 0.2730
# Estimator 398/2000, Train metric: 0.2823, Validation metric: 0.2729
# Estimator 399/2000, Train metric: 0.2822, Validation metric: 0.2729
# Estimator 400/2000, Train metric: 0.2822, Validation metric: 0.2729
# Estimator 401/2000, Train metric: 0.2822, Validation metric: 0.2729
# Estimator 402/2000, Train metric: 0.2822, Validation metric: 0.2729
# Estimator 403/2000, Train metric: 0.2821, Validation metric: 0.2728
# Estimator 404/2000, Train metric: 0.2821, Validation metric: 0.2728
# Estimator 405/2000, Train metric: 0.2821, Validation metric: 0.2728
# Estimator 406/2000, Train metric: 0.2821, Validation metric: 0.2727
# Estimator 407/2000, Train metric: 0.2820, Validation metric: 0.2727
# Estimator 408/2000, Train metric: 0.2820, Validation metric: 0.2727
# Estimator 409/2000, Train metric: 0.2820, Validation metric: 0.2726
# Estimator 410/2000, Train metric: 0.2820, Validation metric: 0.2725
# Estimator 411/2000, Train metric: 0.2819, Validation metric: 0.2725
# Estimator 412/2000, Train metric: 0.2819, Validation metric: 0.2724
# Estimator 413/2000, Train metric: 0.2819, Validation metric: 0.2724
# Estimator 414/2000, Train metric: 0.2819, Validation metric: 0.2723
# Estimator 415/2000, Train metric: 0.2818, Validation metric: 0.2723
# Estimator 416/2000, Train metric: 0.2818, Validation metric: 0.2722
# Estimator 417/2000, Train metric: 0.2818, Validation metric: 0.2721
# Estimator 418/2000, Train metric: 0.2817, Validation metric: 0.2721
# Estimator 419/2000, Train metric: 0.2817, Validation metric: 0.2721
# Estimator 420/2000, Train metric: 0.2817, Validation metric: 0.2720
# Estimator 421/2000, Train metric: 0.2816, Validation metric: 0.2719
# Estimator 422/2000, Train metric: 0.2816, Validation metric: 0.2719
# Estimator 423/2000, Train metric: 0.2816, Validation metric: 0.2718
# Estimator 424/2000, Train metric: 0.2816, Validation metric: 0.2718
# Estimator 425/2000, Train metric: 0.2815, Validation metric: 0.2718
# Estimator 426/2000, Train metric: 0.2815, Validation metric: 0.2718
# Estimator 427/2000, Train metric: 0.2815, Validation metric: 0.2718
# Estimator 428/2000, Train metric: 0.2815, Validation metric: 0.2718
# Estimator 429/2000, Train metric: 0.2815, Validation metric: 0.2718
# Estimator 430/2000, Train metric: 0.2815, Validation metric: 0.2717
# Estimator 431/2000, Train metric: 0.2814, Validation metric: 0.2717
# Estimator 432/2000, Train metric: 0.2814, Validation metric: 0.2716
# Estimator 433/2000, Train metric: 0.2814, Validation metric: 0.2716
# Estimator 434/2000, Train metric: 0.2814, Validation metric: 0.2716
# Estimator 435/2000, Train metric: 0.2814, Validation metric: 0.2716
# Estimator 436/2000, Train metric: 0.2813, Validation metric: 0.2716
# Estimator 437/2000, Train metric: 0.2813, Validation metric: 0.2715
# Estimator 438/2000, Train metric: 0.2813, Validation metric: 0.2716
# Estimator 439/2000, Train metric: 0.2813, Validation metric: 0.2715
# Estimator 440/2000, Train metric: 0.2813, Validation metric: 0.2714
# Estimator 441/2000, Train metric: 0.2812, Validation metric: 0.2714
# Estimator 442/2000, Train metric: 0.2812, Validation metric: 0.2714
# Estimator 443/2000, Train metric: 0.2812, Validation metric: 0.2714
# Estimator 444/2000, Train metric: 0.2812, Validation metric: 0.2713
# Estimator 445/2000, Train metric: 0.2812, Validation metric: 0.2713
# Estimator 446/2000, Train metric: 0.2811, Validation metric: 0.2713
# Estimator 447/2000, Train metric: 0.2811, Validation metric: 0.2713
# Estimator 448/2000, Train metric: 0.2811, Validation metric: 0.2712
# Estimator 449/2000, Train metric: 0.2811, Validation metric: 0.2712
# Estimator 450/2000, Train metric: 0.2810, Validation metric: 0.2712
# Estimator 451/2000, Train metric: 0.2810, Validation metric: 0.2711
# Estimator 452/2000, Train metric: 0.2810, Validation metric: 0.2711
# Estimator 453/2000, Train metric: 0.2810, Validation metric: 0.2711
# Estimator 454/2000, Train metric: 0.2809, Validation metric: 0.2711
# Estimator 455/2000, Train metric: 0.2809, Validation metric: 0.2711
# Estimator 456/2000, Train metric: 0.2809, Validation metric: 0.2711
# Estimator 457/2000, Train metric: 0.2809, Validation metric: 0.2710
# Estimator 458/2000, Train metric: 0.2809, Validation metric: 0.2710
# Estimator 459/2000, Train metric: 0.2809, Validation metric: 0.2710
# Estimator 460/2000, Train metric: 0.2808, Validation metric: 0.2710
# Estimator 461/2000, Train metric: 0.2808, Validation metric: 0.2710
# Estimator 462/2000, Train metric: 0.2808, Validation metric: 0.2710
# Estimator 463/2000, Train metric: 0.2808, Validation metric: 0.2709
# Estimator 464/2000, Train metric: 0.2808, Validation metric: 0.2709
# Estimator 465/2000, Train metric: 0.2808, Validation metric: 0.2709
# Estimator 466/2000, Train metric: 0.2807, Validation metric: 0.2709
# Estimator 467/2000, Train metric: 0.2807, Validation metric: 0.2708
# Estimator 468/2000, Train metric: 0.2806, Validation metric: 0.2706
# Estimator 469/2000, Train metric: 0.2806, Validation metric: 0.2706
# Estimator 470/2000, Train metric: 0.2806, Validation metric: 0.2706
# Estimator 471/2000, Train metric: 0.2805, Validation metric: 0.2705
# Estimator 472/2000, Train metric: 0.2805, Validation metric: 0.2705
# Estimator 473/2000, Train metric: 0.2805, Validation metric: 0.2705
# Estimator 474/2000, Train metric: 0.2805, Validation metric: 0.2705
# Estimator 475/2000, Train metric: 0.2805, Validation metric: 0.2705
# Estimator 476/2000, Train metric: 0.2804, Validation metric: 0.2704
# Estimator 477/2000, Train metric: 0.2804, Validation metric: 0.2704
# Estimator 478/2000, Train metric: 0.2804, Validation metric: 0.2703
# Estimator 479/2000, Train metric: 0.2804, Validation metric: 0.2703
# Estimator 480/2000, Train metric: 0.2804, Validation metric: 0.2703
# Estimator 481/2000, Train metric: 0.2803, Validation metric: 0.2702
# Estimator 482/2000, Train metric: 0.2803, Validation metric: 0.2702
# Estimator 483/2000, Train metric: 0.2803, Validation metric: 0.2702
# Estimator 484/2000, Train metric: 0.2803, Validation metric: 0.2702
# Estimator 485/2000, Train metric: 0.2803, Validation metric: 0.2701
# Estimator 486/2000, Train metric: 0.2802, Validation metric: 0.2701
# Estimator 487/2000, Train metric: 0.2802, Validation metric: 0.2701
# Estimator 488/2000, Train metric: 0.2802, Validation metric: 0.2701
# Estimator 489/2000, Train metric: 0.2802, Validation metric: 0.2701
# Estimator 490/2000, Train metric: 0.2802, Validation metric: 0.2701
# Estimator 491/2000, Train metric: 0.2801, Validation metric: 0.2701
# Estimator 492/2000, Train metric: 0.2801, Validation metric: 0.2700
# Estimator 493/2000, Train metric: 0.2801, Validation metric: 0.2700
# Estimator 494/2000, Train metric: 0.2801, Validation metric: 0.2700
# Estimator 495/2000, Train metric: 0.2801, Validation metric: 0.2700
# Estimator 496/2000, Train metric: 0.2800, Validation metric: 0.2699
# Estimator 497/2000, Train metric: 0.2800, Validation metric: 0.2699
# Estimator 498/2000, Train metric: 0.2800, Validation metric: 0.2699
# Estimator 499/2000, Train metric: 0.2800, Validation metric: 0.2699
# Estimator 500/2000, Train metric: 0.2800, Validation metric: 0.2698
# Estimator 501/2000, Train metric: 0.2800, Validation metric: 0.2699
# Estimator 502/2000, Train metric: 0.2799, Validation metric: 0.2698
# Estimator 503/2000, Train metric: 0.2799, Validation metric: 0.2698
# Estimator 504/2000, Train metric: 0.2799, Validation metric: 0.2698
# Estimator 505/2000, Train metric: 0.2799, Validation metric: 0.2698
# Estimator 506/2000, Train metric: 0.2799, Validation metric: 0.2698
# Estimator 507/2000, Train metric: 0.2798, Validation metric: 0.2698
# Estimator 508/2000, Train metric: 0.2798, Validation metric: 0.2698
# Estimator 509/2000, Train metric: 0.2798, Validation metric: 0.2697
# Estimator 510/2000, Train metric: 0.2798, Validation metric: 0.2697
# Estimator 511/2000, Train metric: 0.2797, Validation metric: 0.2696
# Estimator 512/2000, Train metric: 0.2797, Validation metric: 0.2697
# Estimator 513/2000, Train metric: 0.2797, Validation metric: 0.2697
# Estimator 514/2000, Train metric: 0.2797, Validation metric: 0.2696
# Estimator 515/2000, Train metric: 0.2797, Validation metric: 0.2696
# Estimator 516/2000, Train metric: 0.2796, Validation metric: 0.2696
# Estimator 517/2000, Train metric: 0.2796, Validation metric: 0.2696
# Estimator 518/2000, Train metric: 0.2796, Validation metric: 0.2695
# Estimator 519/2000, Train metric: 0.2796, Validation metric: 0.2695
# Estimator 520/2000, Train metric: 0.2796, Validation metric: 0.2695
# Estimator 521/2000, Train metric: 0.2795, Validation metric: 0.2695
# Estimator 522/2000, Train metric: 0.2795, Validation metric: 0.2695
# Estimator 523/2000, Train metric: 0.2795, Validation metric: 0.2695
# Estimator 524/2000, Train metric: 0.2795, Validation metric: 0.2694
# Estimator 525/2000, Train metric: 0.2795, Validation metric: 0.2694
# Estimator 526/2000, Train metric: 0.2794, Validation metric: 0.2694
# Estimator 527/2000, Train metric: 0.2794, Validation metric: 0.2694
# Estimator 528/2000, Train metric: 0.2794, Validation metric: 0.2693
# Estimator 529/2000, Train metric: 0.2794, Validation metric: 0.2693
# Estimator 530/2000, Train metric: 0.2794, Validation metric: 0.2693
# Estimator 531/2000, Train metric: 0.2793, Validation metric: 0.2693
# Estimator 532/2000, Train metric: 0.2793, Validation metric: 0.2692
# Estimator 533/2000, Train metric: 0.2793, Validation metric: 0.2692
# Estimator 534/2000, Train metric: 0.2793, Validation metric: 0.2692
# Estimator 535/2000, Train metric: 0.2793, Validation metric: 0.2691
# Estimator 536/2000, Train metric: 0.2792, Validation metric: 0.2691
# Estimator 537/2000, Train metric: 0.2792, Validation metric: 0.2691
# Estimator 538/2000, Train metric: 0.2792, Validation metric: 0.2690
# Estimator 539/2000, Train metric: 0.2792, Validation metric: 0.2690
# Estimator 540/2000, Train metric: 0.2791, Validation metric: 0.2690
# Estimator 541/2000, Train metric: 0.2791, Validation metric: 0.2690
# Estimator 542/2000, Train metric: 0.2791, Validation metric: 0.2689
# Estimator 543/2000, Train metric: 0.2791, Validation metric: 0.2689
# Estimator 544/2000, Train metric: 0.2791, Validation metric: 0.2689
# Estimator 545/2000, Train metric: 0.2791, Validation metric: 0.2689
# Estimator 546/2000, Train metric: 0.2790, Validation metric: 0.2688
# Estimator 547/2000, Train metric: 0.2790, Validation metric: 0.2688
# Estimator 548/2000, Train metric: 0.2790, Validation metric: 0.2688
# Estimator 549/2000, Train metric: 0.2790, Validation metric: 0.2688
# Estimator 550/2000, Train metric: 0.2790, Validation metric: 0.2688
# Estimator 551/2000, Train metric: 0.2789, Validation metric: 0.2688
# Estimator 552/2000, Train metric: 0.2789, Validation metric: 0.2687
# Estimator 553/2000, Train metric: 0.2789, Validation metric: 0.2687
# Estimator 554/2000, Train metric: 0.2789, Validation metric: 0.2687
# Estimator 555/2000, Train metric: 0.2789, Validation metric: 0.2687
# Estimator 556/2000, Train metric: 0.2788, Validation metric: 0.2687
# Estimator 557/2000, Train metric: 0.2788, Validation metric: 0.2686
# Estimator 558/2000, Train metric: 0.2788, Validation metric: 0.2686
# Estimator 559/2000, Train metric: 0.2788, Validation metric: 0.2686
# Estimator 560/2000, Train metric: 0.2787, Validation metric: 0.2686
# Estimator 561/2000, Train metric: 0.2787, Validation metric: 0.2685
# Estimator 562/2000, Train metric: 0.2787, Validation metric: 0.2685
# Estimator 563/2000, Train metric: 0.2787, Validation metric: 0.2685
# Estimator 564/2000, Train metric: 0.2786, Validation metric: 0.2685
# Estimator 565/2000, Train metric: 0.2786, Validation metric: 0.2685
# Estimator 566/2000, Train metric: 0.2786, Validation metric: 0.2685
# Estimator 567/2000, Train metric: 0.2786, Validation metric: 0.2685
# Estimator 568/2000, Train metric: 0.2786, Validation metric: 0.2685
# Estimator 569/2000, Train metric: 0.2785, Validation metric: 0.2684
# Estimator 570/2000, Train metric: 0.2785, Validation metric: 0.2684
# Estimator 571/2000, Train metric: 0.2785, Validation metric: 0.2684
# Estimator 572/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 573/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 574/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 575/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 576/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 577/2000, Train metric: 0.2784, Validation metric: 0.2684
# Estimator 578/2000, Train metric: 0.2783, Validation metric: 0.2683
# Estimator 579/2000, Train metric: 0.2783, Validation metric: 0.2683
# Estimator 580/2000, Train metric: 0.2783, Validation metric: 0.2683
# Estimator 581/2000, Train metric: 0.2783, Validation metric: 0.2683
# Estimator 582/2000, Train metric: 0.2783, Validation metric: 0.2683
# Estimator 583/2000, Train metric: 0.2783, Validation metric: 0.2682
# Estimator 584/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 585/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 586/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 587/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 588/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 589/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 590/2000, Train metric: 0.2782, Validation metric: 0.2682
# Estimator 591/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 592/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 593/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 594/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 595/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 596/2000, Train metric: 0.2781, Validation metric: 0.2681
# Estimator 597/2000, Train metric: 0.2780, Validation metric: 0.2681
# Estimator 598/2000, Train metric: 0.2780, Validation metric: 0.2681
# Estimator 599/2000, Train metric: 0.2780, Validation metric: 0.2680
# Estimator 600/2000, Train metric: 0.2780, Validation metric: 0.2680
# Estimator 601/2000, Train metric: 0.2780, Validation metric: 0.2680
# Estimator 602/2000, Train metric: 0.2780, Validation metric: 0.2680
# Estimator 603/2000, Train metric: 0.2779, Validation metric: 0.2680
# Estimator 604/2000, Train metric: 0.2779, Validation metric: 0.2680
# Estimator 605/2000, Train metric: 0.2779, Validation metric: 0.2679
# Estimator 606/2000, Train metric: 0.2779, Validation metric: 0.2679
# Estimator 607/2000, Train metric: 0.2778, Validation metric: 0.2679
# Estimator 608/2000, Train metric: 0.2778, Validation metric: 0.2679
# Estimator 609/2000, Train metric: 0.2778, Validation metric: 0.2678
# Estimator 610/2000, Train metric: 0.2778, Validation metric: 0.2678
# Estimator 611/2000, Train metric: 0.2778, Validation metric: 0.2678
# Estimator 612/2000, Train metric: 0.2777, Validation metric: 0.2678
# Estimator 613/2000, Train metric: 0.2777, Validation metric: 0.2678
# Estimator 614/2000, Train metric: 0.2777, Validation metric: 0.2677
# Estimator 615/2000, Train metric: 0.2777, Validation metric: 0.2677
# Estimator 616/2000, Train metric: 0.2777, Validation metric: 0.2677
# Estimator 617/2000, Train metric: 0.2777, Validation metric: 0.2676
# Estimator 618/2000, Train metric: 0.2776, Validation metric: 0.2676
# Estimator 619/2000, Train metric: 0.2776, Validation metric: 0.2676
# Estimator 620/2000, Train metric: 0.2776, Validation metric: 0.2676
# Estimator 621/2000, Train metric: 0.2776, Validation metric: 0.2676
# Estimator 622/2000, Train metric: 0.2776, Validation metric: 0.2676
# Estimator 623/2000, Train metric: 0.2775, Validation metric: 0.2674
# Estimator 624/2000, Train metric: 0.2775, Validation metric: 0.2674
# Estimator 625/2000, Train metric: 0.2775, Validation metric: 0.2674
# Estimator 626/2000, Train metric: 0.2775, Validation metric: 0.2674
# Estimator 627/2000, Train metric: 0.2775, Validation metric: 0.2674
# Estimator 628/2000, Train metric: 0.2774, Validation metric: 0.2674
# Estimator 629/2000, Train metric: 0.2774, Validation metric: 0.2673
# Estimator 630/2000, Train metric: 0.2774, Validation metric: 0.2673
# Estimator 631/2000, Train metric: 0.2774, Validation metric: 0.2673
# Estimator 632/2000, Train metric: 0.2774, Validation metric: 0.2673
# Estimator 633/2000, Train metric: 0.2774, Validation metric: 0.2673
# Estimator 634/2000, Train metric: 0.2773, Validation metric: 0.2671
# Estimator 635/2000, Train metric: 0.2773, Validation metric: 0.2671
# Estimator 636/2000, Train metric: 0.2773, Validation metric: 0.2671
# Estimator 637/2000, Train metric: 0.2773, Validation metric: 0.2671
# Estimator 638/2000, Train metric: 0.2772, Validation metric: 0.2670
# Estimator 639/2000, Train metric: 0.2772, Validation metric: 0.2670
# Estimator 640/2000, Train metric: 0.2772, Validation metric: 0.2670
# Estimator 641/2000, Train metric: 0.2772, Validation metric: 0.2670
# Estimator 642/2000, Train metric: 0.2772, Validation metric: 0.2670
# Estimator 643/2000, Train metric: 0.2771, Validation metric: 0.2670
# Estimator 644/2000, Train metric: 0.2771, Validation metric: 0.2670
# Estimator 645/2000, Train metric: 0.2771, Validation metric: 0.2670
# Estimator 646/2000, Train metric: 0.2771, Validation metric: 0.2669
# Estimator 647/2000, Train metric: 0.2771, Validation metric: 0.2669
# Estimator 648/2000, Train metric: 0.2771, Validation metric: 0.2669
# Estimator 649/2000, Train metric: 0.2770, Validation metric: 0.2669
# Estimator 650/2000, Train metric: 0.2770, Validation metric: 0.2668
# Estimator 651/2000, Train metric: 0.2770, Validation metric: 0.2668
# Estimator 652/2000, Train metric: 0.2770, Validation metric: 0.2668
# Estimator 653/2000, Train metric: 0.2770, Validation metric: 0.2667
# Estimator 654/2000, Train metric: 0.2769, Validation metric: 0.2667
# Estimator 655/2000, Train metric: 0.2769, Validation metric: 0.2667
# Estimator 656/2000, Train metric: 0.2769, Validation metric: 0.2667
# Estimator 657/2000, Train metric: 0.2769, Validation metric: 0.2667
# Estimator 658/2000, Train metric: 0.2769, Validation metric: 0.2666
# Estimator 659/2000, Train metric: 0.2769, Validation metric: 0.2666
# Estimator 660/2000, Train metric: 0.2769, Validation metric: 0.2666
# Estimator 661/2000, Train metric: 0.2769, Validation metric: 0.2666
# Estimator 662/2000, Train metric: 0.2768, Validation metric: 0.2665
# Estimator 663/2000, Train metric: 0.2768, Validation metric: 0.2665
# Estimator 664/2000, Train metric: 0.2768, Validation metric: 0.2665
# Estimator 665/2000, Train metric: 0.2768, Validation metric: 0.2665
# Estimator 666/2000, Train metric: 0.2768, Validation metric: 0.2665
# Estimator 667/2000, Train metric: 0.2767, Validation metric: 0.2665
# Estimator 668/2000, Train metric: 0.2767, Validation metric: 0.2665
# Estimator 669/2000, Train metric: 0.2767, Validation metric: 0.2665
# Estimator 670/2000, Train metric: 0.2767, Validation metric: 0.2664
# Estimator 671/2000, Train metric: 0.2767, Validation metric: 0.2664
# Estimator 672/2000, Train metric: 0.2767, Validation metric: 0.2664
# Estimator 673/2000, Train metric: 0.2767, Validation metric: 0.2664
# Estimator 674/2000, Train metric: 0.2766, Validation metric: 0.2664
# Estimator 675/2000, Train metric: 0.2766, Validation metric: 0.2664
# Estimator 676/2000, Train metric: 0.2766, Validation metric: 0.2664
# Estimator 677/2000, Train metric: 0.2766, Validation metric: 0.2663
# Estimator 678/2000, Train metric: 0.2766, Validation metric: 0.2663
# Estimator 679/2000, Train metric: 0.2766, Validation metric: 0.2662
# Estimator 680/2000, Train metric: 0.2765, Validation metric: 0.2662
# Estimator 681/2000, Train metric: 0.2765, Validation metric: 0.2662
# Estimator 682/2000, Train metric: 0.2765, Validation metric: 0.2662
# Estimator 683/2000, Train metric: 0.2765, Validation metric: 0.2662
# Estimator 684/2000, Train metric: 0.2765, Validation metric: 0.2661
# Estimator 685/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 686/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 687/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 688/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 689/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 690/2000, Train metric: 0.2764, Validation metric: 0.2661
# Estimator 691/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 692/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 693/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 694/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 695/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 696/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 697/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 698/2000, Train metric: 0.2763, Validation metric: 0.2660
# Estimator 699/2000, Train metric: 0.2762, Validation metric: 0.2660
# Estimator 700/2000, Train metric: 0.2762, Validation metric: 0.2660
# Estimator 701/2000, Train metric: 0.2762, Validation metric: 0.2660
# Estimator 702/2000, Train metric: 0.2762, Validation metric: 0.2660
# Estimator 703/2000, Train metric: 0.2762, Validation metric: 0.2659
# Estimator 704/2000, Train metric: 0.2762, Validation metric: 0.2659
# Estimator 705/2000, Train metric: 0.2762, Validation metric: 0.2659
# Estimator 706/2000, Train metric: 0.2761, Validation metric: 0.2659
# ...
# Estimator 1769/2000, Train metric: 0.2634, Validation metric: 0.2549
# Estimator 1770/2000, Train metric: 0.2634, Validation metric: 0.2549
# Estimator 1771/2000, Train metric: 0.2634, Validation metric: 0.2549
# Estimator 1772/2000, Train metric: 0.2633, Validation metric: 0.2549
# Estimator 1773/2000, Train metric: 0.2633, Validation metric: 0.2549
# Estimator 1774/2000, Train metric: 0.2633, Validation metric: 0.2549
# Estimator 1775/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1776/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1777/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1778/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1779/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1780/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1781/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1782/2000, Train metric: 0.2633, Validation metric: 0.2548
# Estimator 1783/2000, Train metric: 0.2632, Validation metric: 0.2548
# Estimator 1784/2000, Train metric: 0.2632, Validation metric: 0.2548
# Estimator 1785/2000, Train metric: 0.2632, Validation metric: 0.2548
# Estimator 1786/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1787/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1788/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1789/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1790/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1791/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1792/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1793/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1794/2000, Train metric: 0.2632, Validation metric: 0.2547
# Estimator 1795/2000, Train metric: 0.2632, Validation metric: 0.2546
# Estimator 1796/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1797/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1798/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1799/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1800/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1801/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1802/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1803/2000, Train metric: 0.2631, Validation metric: 0.2546
# Estimator 1804/2000, Train metric: 0.2631, Validation metric: 0.2545
# Estimator 1805/2000, Train metric: 0.2631, Validation metric: 0.2545
# Estimator 1806/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1807/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1808/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1809/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1810/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1811/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1812/2000, Train metric: 0.2630, Validation metric: 0.2545
# Estimator 1813/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1814/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1815/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1816/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1817/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1818/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1819/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1820/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1821/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1822/2000, Train metric: 0.2630, Validation metric: 0.2544
# Estimator 1823/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1824/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1825/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1826/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1827/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1828/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1829/2000, Train metric: 0.2629, Validation metric: 0.2542
# Estimator 1830/2000, Train metric: 0.2629, Validation metric: 0.2542
# Estimator 1831/2000, Train metric: 0.2629, Validation metric: 0.2542
# Estimator 1832/2000, Train metric: 0.2629, Validation metric: 0.2542
# Estimator 1833/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1834/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1835/2000, Train metric: 0.2629, Validation metric: 0.2543
# Estimator 1836/2000, Train metric: 0.2628, Validation metric: 0.2543
# Estimator 1837/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1838/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1839/2000, Train metric: 0.2628, Validation metric: 0.2543
# Estimator 1840/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1841/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1842/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1843/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1844/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1845/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1846/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1847/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1848/2000, Train metric: 0.2628, Validation metric: 0.2542
# Estimator 1849/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1850/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1851/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1852/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1853/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1854/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1855/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1856/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1857/2000, Train metric: 0.2627, Validation metric: 0.2541
# Estimator 1858/2000, Train metric: 0.2627, Validation metric: 0.2540
# Estimator 1859/2000, Train metric: 0.2627, Validation metric: 0.2540
# Estimator 1860/2000, Train metric: 0.2627, Validation metric: 0.2540
# Estimator 1861/2000, Train metric: 0.2627, Validation metric: 0.2540
# Estimator 1862/2000, Train metric: 0.2626, Validation metric: 0.2540
# Estimator 1863/2000, Train metric: 0.2626, Validation metric: 0.2540
# Estimator 1864/2000, Train metric: 0.2626, Validation metric: 0.2540
# Estimator 1865/2000, Train metric: 0.2626, Validation metric: 0.2540
# Estimator 1866/2000, Train metric: 0.2626, Validation metric: 0.2540
# Estimator 1867/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1868/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1869/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1870/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1871/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1872/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1873/2000, Train metric: 0.2626, Validation metric: 0.2539
# Estimator 1874/2000, Train metric: 0.2626, Validation metric: 0.2538
# Estimator 1875/2000, Train metric: 0.2625, Validation metric: 0.2538
# Estimator 1876/2000, Train metric: 0.2625, Validation metric: 0.2538
# Estimator 1877/2000, Train metric: 0.2625, Validation metric: 0.2538
# Estimator 1878/2000, Train metric: 0.2625, Validation metric: 0.2538
# Estimator 1879/2000, Train metric: 0.2625, Validation metric: 0.2539
# Estimator 1880/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1881/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1882/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1883/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1884/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1885/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1886/2000, Train metric: 0.2624, Validation metric: 0.2539
# Estimator 1887/2000, Train metric: 0.2624, Validation metric: 0.2538
# Estimator 1888/2000, Train metric: 0.2624, Validation metric: 0.2538
# Estimator 1889/2000, Train metric: 0.2624, Validation metric: 0.2538
# Estimator 1890/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1891/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1892/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1893/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1894/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1895/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1896/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1897/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1898/2000, Train metric: 0.2623, Validation metric: 0.2538
# Estimator 1899/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1900/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1901/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1902/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1903/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1904/2000, Train metric: 0.2622, Validation metric: 0.2537
# Estimator 1905/2000, Train metric: 0.2622, Validation metric: 0.2537
# Estimator 1906/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1907/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1908/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1909/2000, Train metric: 0.2622, Validation metric: 0.2538
# Estimator 1910/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1911/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1912/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1913/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1914/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1915/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1916/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1917/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1918/2000, Train metric: 0.2621, Validation metric: 0.2537
# Estimator 1919/2000, Train metric: 0.2620, Validation metric: 0.2537
# Estimator 1920/2000, Train metric: 0.2620, Validation metric: 0.2537
# Estimator 1921/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1922/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1923/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1924/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1925/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1926/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1927/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1928/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1929/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1930/2000, Train metric: 0.2620, Validation metric: 0.2536
# Estimator 1931/2000, Train metric: 0.2620, Validation metric: 0.2535
# Estimator 1932/2000, Train metric: 0.2620, Validation metric: 0.2535
# Estimator 1933/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1934/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1935/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1936/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1937/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1938/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1939/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1940/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1941/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1942/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1943/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1944/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1945/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1946/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1947/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1948/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1949/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1950/2000, Train metric: 0.2619, Validation metric: 0.2535
# Estimator 1951/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1952/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1953/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1954/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1955/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1956/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1957/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1958/2000, Train metric: 0.2618, Validation metric: 0.2534
# Estimator 1959/2000, Train metric: 0.2618, Validation metric: 0.2533
# Estimator 1960/2000, Train metric: 0.2618, Validation metric: 0.2533
# Estimator 1961/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1962/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1963/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1964/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1965/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1966/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1967/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1968/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1969/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1970/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1971/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1972/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1973/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1974/2000, Train metric: 0.2617, Validation metric: 0.2533
# Estimator 1975/2000, Train metric: 0.2617, Validation metric: 0.2532
# Estimator 1976/2000, Train metric: 0.2617, Validation metric: 0.2532
# Estimator 1977/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1978/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1979/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1980/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1981/2000, Train metric: 0.2616, Validation metric: 0.2533
# Estimator 1982/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1983/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1984/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1985/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1986/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1987/2000, Train metric: 0.2616, Validation metric: 0.2532
# Estimator 1988/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1989/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1990/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1991/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1992/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1993/2000, Train metric: 0.2615, Validation metric: 0.2532
# Estimator 1994/2000, Train metric: 0.2615, Validation metric: 0.2531
# Estimator 1995/2000, Train metric: 0.2615, Validation metric: 0.2531
# Estimator 1996/2000, Train metric: 0.2615, Validation metric: 0.2531
# Estimator 1997/2000, Train metric: 0.2615, Validation metric: 0.2531
# Estimator 1998/2000, Train metric: 0.2615, Validation metric: 0.2531
# Estimator 1999/2000, Train metric: 0.2615, Validation metric: 0.2531

# %%
model.optimize_distribution(x_val.values, y_val.values.reshape(-1))
# Out:
# CRPS: 0.32 (Distribution: normal, Tree correlation: 0.000)
# CRPS: 0.25 (Distribution: normal, Tree correlation: 0.010)
# CRPS: 0.19 (Distribution: normal, Tree correlation: 0.020)
# CRPS: 0.16 (Distribution: normal, Tree correlation: 0.030)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.040)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.050)
# CRPS: 0.13 (Distribution: normal, Tree correlation: 0.060)
# CRPS: 0.13 (Distribution: normal, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.090)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.100)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.110)
# CRPS: 0.14 (Distribution: normal, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.150)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.160)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.170)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.180)
# CRPS: 0.15 (Distribution: normal, Tree correlation: 0.190)
# CRPS: 0.23 (Distribution: studentt, Tree correlation: 0.000)
# CRPS: 0.19 (Distribution: studentt, Tree correlation: 0.010)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.020)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.030)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.040)
# CRPS: 0.13 (Distribution: studentt, Tree correlation: 0.050)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.060)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: studentt, Tree correlation: 0.090)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.100)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.110)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: studentt, Tree correlation: 0.150)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.160)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.170)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.180)
# CRPS: 0.16 (Distribution: studentt, Tree correlation: 0.190)
# CRPS: 0.26 (Distribution: laplace, Tree correlation: 0.000)
# CRPS: 0.21 (Distribution: laplace, Tree correlation: 0.010)
# CRPS: 0.17 (Distribution: laplace, Tree correlation: 0.020)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.030)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.040)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.050)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.060)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.090)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.100)
# CRPS: 0.14 (Distribution: laplace, Tree correlation: 0.110)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.150)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.160)
# CRPS: 0.15 (Distribution: laplace, Tree correlation: 0.170)
# CRPS: 0.16 (Distribution: laplace, Tree correlation: 0.180)
# CRPS: 0.16 (Distribution: laplace, Tree correlation: 0.190)
# CRPS: 0.30 (Distribution: logistic, Tree correlation: 0.000)
# CRPS: 0.23 (Distribution: logistic, Tree correlation: 0.010)
# CRPS: 0.18 (Distribution: logistic, Tree correlation: 0.020)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.030)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.040)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.050)
# CRPS: 0.13 (Distribution: logistic, Tree correlation: 0.060)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.090)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.100)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.110)
# CRPS: 0.14 (Distribution: logistic, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.150)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.160)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.170)
# CRPS: 0.15 (Distribution: logistic, Tree correlation: 0.180)
# CRPS: 0.16 (Distribution: logistic, Tree correlation: 0.190)
# CRPS: 0.32 (Distribution: gamma, Tree correlation: 0.000)
# CRPS: 0.25 (Distribution: gamma, Tree correlation: 0.010)
# CRPS: 0.19 (Distribution: gamma, Tree correlation: 0.020)
# CRPS: 0.16 (Distribution: gamma, Tree correlation: 0.030)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.040)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.050)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.060)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.090)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.100)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.110)
# CRPS: 0.14 (Distribution: gamma, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.150)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.160)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.170)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.180)
# CRPS: 0.15 (Distribution: gamma, Tree correlation: 0.190)
# CRPS: 0.31 (Distribution: gumbel, Tree correlation: 0.000)
# CRPS: 0.24 (Distribution: gumbel, Tree correlation: 0.010)
# CRPS: 0.19 (Distribution: gumbel, Tree correlation: 0.020)
# CRPS: 0.16 (Distribution: gumbel, Tree correlation: 0.030)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.040)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.050)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.060)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.070)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.080)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.090)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.100)
# CRPS: 0.14 (Distribution: gumbel, Tree correlation: 0.110)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.120)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.130)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.140)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.150)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.160)
# CRPS: 0.15 (Distribution: gumbel, Tree correlation: 0.170)
# CRPS: 0.16 (Distribution: gumbel, Tree correlation: 0.180)
# CRPS: 0.16 (Distribution: gumbel, Tree correlation: 0.190)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.000)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.010)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.020)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.030)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.040)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.050)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.060)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.070)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.080)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.090)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.100)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.110)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.120)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.130)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.140)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.150)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.160)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.170)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.180)
# CRPS: 0.47 (Distribution: poisson, Tree correlation: 0.190)
# Lowest CRPS: 0.1337 (Distribution: normal, Tree correlation: 0.060)
# ('normal', 0.06)

# %%
y_train_dist = model.predict_dist(x_train.values, n_forecasts=1000)
y_val_dist = model.predict_dist(x_val.values, n_forecasts=1000)
y_test_dist = model.predict_dist(x_test.values, n_forecasts=1000)

# %%
print(model.crps_ensemble(y_train_dist, y_train.values.reshape(-1)).mean())
print(model.crps_ensemble(y_val_dist, y_val.values.reshape(-1)).mean())
print(model.crps_ensemble(y_test_dist, y_test.values.reshape(-1)).mean())
# Out:
# 0.13844459484006263
# 0.1332963826146124
# 0.17524738122587635
