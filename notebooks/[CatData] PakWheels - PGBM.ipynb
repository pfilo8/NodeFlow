# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/pak-wheels/PakWheelsDataSet.csv', index_col=0)

# %%
x = df.drop(columns = ['Name', 'Price'])
x = pd.get_dummies(x)
y = np.log10(df[['Price']])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((61352, 402), (15338, 402))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 0.3130, Validation metric: 0.3104
# Estimator 1/2000, Train metric: 0.2916, Validation metric: 0.2893
# Estimator 2/2000, Train metric: 0.2726, Validation metric: 0.2706
# Estimator 3/2000, Train metric: 0.2543, Validation metric: 0.2525
# Estimator 4/2000, Train metric: 0.2384, Validation metric: 0.2368
# Estimator 5/2000, Train metric: 0.2248, Validation metric: 0.2236
# Estimator 6/2000, Train metric: 0.2119, Validation metric: 0.2111
# Estimator 7/2000, Train metric: 0.2010, Validation metric: 0.2005
# Estimator 8/2000, Train metric: 0.1906, Validation metric: 0.1902
# Estimator 9/2000, Train metric: 0.1814, Validation metric: 0.1814
# Estimator 10/2000, Train metric: 0.1739, Validation metric: 0.1740
# Estimator 11/2000, Train metric: 0.1665, Validation metric: 0.1669
# Estimator 12/2000, Train metric: 0.1603, Validation metric: 0.1608
# Estimator 13/2000, Train metric: 0.1545, Validation metric: 0.1553
# Estimator 14/2000, Train metric: 0.1494, Validation metric: 0.1502
# Estimator 15/2000, Train metric: 0.1452, Validation metric: 0.1463
# Estimator 16/2000, Train metric: 0.1408, Validation metric: 0.1421
# Estimator 17/2000, Train metric: 0.1372, Validation metric: 0.1386
# Estimator 18/2000, Train metric: 0.1336, Validation metric: 0.1351
# Estimator 19/2000, Train metric: 0.1304, Validation metric: 0.1321
# Estimator 20/2000, Train metric: 0.1277, Validation metric: 0.1295
# Estimator 21/2000, Train metric: 0.1252, Validation metric: 0.1271
# Estimator 22/2000, Train metric: 0.1229, Validation metric: 0.1250
# Estimator 23/2000, Train metric: 0.1209, Validation metric: 0.1231
# Estimator 24/2000, Train metric: 0.1193, Validation metric: 0.1215
# Estimator 25/2000, Train metric: 0.1175, Validation metric: 0.1198
# Estimator 26/2000, Train metric: 0.1160, Validation metric: 0.1184
# Estimator 27/2000, Train metric: 0.1144, Validation metric: 0.1169
# Estimator 28/2000, Train metric: 0.1129, Validation metric: 0.1154
# Estimator 29/2000, Train metric: 0.1117, Validation metric: 0.1144
# Estimator 30/2000, Train metric: 0.1106, Validation metric: 0.1133
# Estimator 31/2000, Train metric: 0.1095, Validation metric: 0.1122
# Estimator 32/2000, Train metric: 0.1088, Validation metric: 0.1115
# Estimator 33/2000, Train metric: 0.1077, Validation metric: 0.1105
# Estimator 34/2000, Train metric: 0.1069, Validation metric: 0.1097
# Estimator 35/2000, Train metric: 0.1062, Validation metric: 0.1090
# Estimator 36/2000, Train metric: 0.1053, Validation metric: 0.1083
# Estimator 37/2000, Train metric: 0.1046, Validation metric: 0.1076
# Estimator 38/2000, Train metric: 0.1040, Validation metric: 0.1070
# Estimator 39/2000, Train metric: 0.1033, Validation metric: 0.1063
# Estimator 40/2000, Train metric: 0.1027, Validation metric: 0.1057
# Estimator 41/2000, Train metric: 0.1022, Validation metric: 0.1053
# Estimator 42/2000, Train metric: 0.1018, Validation metric: 0.1049
# Estimator 43/2000, Train metric: 0.1014, Validation metric: 0.1046
# Estimator 44/2000, Train metric: 0.1009, Validation metric: 0.1041
# Estimator 45/2000, Train metric: 0.1003, Validation metric: 0.1035
# Estimator 46/2000, Train metric: 0.1000, Validation metric: 0.1031
# Estimator 47/2000, Train metric: 0.0994, Validation metric: 0.1026
# Estimator 48/2000, Train metric: 0.0992, Validation metric: 0.1023
# Estimator 49/2000, Train metric: 0.0988, Validation metric: 0.1020
# Estimator 50/2000, Train metric: 0.0983, Validation metric: 0.1014
# Estimator 51/2000, Train metric: 0.0981, Validation metric: 0.1012
# Estimator 52/2000, Train metric: 0.0979, Validation metric: 0.1010
# Estimator 53/2000, Train metric: 0.0976, Validation metric: 0.1007
# Estimator 54/2000, Train metric: 0.0973, Validation metric: 0.1004
# Estimator 55/2000, Train metric: 0.0971, Validation metric: 0.1002
# Estimator 56/2000, Train metric: 0.0968, Validation metric: 0.0999
# Estimator 57/2000, Train metric: 0.0967, Validation metric: 0.0998
# Estimator 58/2000, Train metric: 0.0965, Validation metric: 0.0996
# Estimator 59/2000, Train metric: 0.0963, Validation metric: 0.0994
# Estimator 60/2000, Train metric: 0.0961, Validation metric: 0.0992
# Estimator 61/2000, Train metric: 0.0959, Validation metric: 0.0990
# Estimator 62/2000, Train metric: 0.0958, Validation metric: 0.0989
# Estimator 63/2000, Train metric: 0.0956, Validation metric: 0.0987
# Estimator 64/2000, Train metric: 0.0955, Validation metric: 0.0986
# Estimator 65/2000, Train metric: 0.0954, Validation metric: 0.0985
# Estimator 66/2000, Train metric: 0.0952, Validation metric: 0.0983
# Estimator 67/2000, Train metric: 0.0951, Validation metric: 0.0982
# Estimator 68/2000, Train metric: 0.0950, Validation metric: 0.0981
# Estimator 69/2000, Train metric: 0.0949, Validation metric: 0.0980
# Estimator 70/2000, Train metric: 0.0948, Validation metric: 0.0979
# Estimator 71/2000, Train metric: 0.0948, Validation metric: 0.0979
# Estimator 72/2000, Train metric: 0.0947, Validation metric: 0.0977
# Estimator 73/2000, Train metric: 0.0946, Validation metric: 0.0977
# Estimator 74/2000, Train metric: 0.0944, Validation metric: 0.0975
# Estimator 75/2000, Train metric: 0.0943, Validation metric: 0.0974
# Estimator 76/2000, Train metric: 0.0942, Validation metric: 0.0973
# Estimator 77/2000, Train metric: 0.0942, Validation metric: 0.0972
# Estimator 78/2000, Train metric: 0.0940, Validation metric: 0.0970
# Estimator 79/2000, Train metric: 0.0939, Validation metric: 0.0969
# Estimator 80/2000, Train metric: 0.0938, Validation metric: 0.0969
# Estimator 81/2000, Train metric: 0.0938, Validation metric: 0.0968
# Estimator 82/2000, Train metric: 0.0936, Validation metric: 0.0966
# Estimator 83/2000, Train metric: 0.0935, Validation metric: 0.0966
# Estimator 84/2000, Train metric: 0.0935, Validation metric: 0.0966
# Estimator 85/2000, Train metric: 0.0934, Validation metric: 0.0965
# Estimator 86/2000, Train metric: 0.0934, Validation metric: 0.0964
# Estimator 87/2000, Train metric: 0.0933, Validation metric: 0.0963
# Estimator 88/2000, Train metric: 0.0932, Validation metric: 0.0963
# Estimator 89/2000, Train metric: 0.0932, Validation metric: 0.0962
# Estimator 90/2000, Train metric: 0.0931, Validation metric: 0.0962
# Estimator 91/2000, Train metric: 0.0930, Validation metric: 0.0961
# Estimator 92/2000, Train metric: 0.0929, Validation metric: 0.0960
# Estimator 93/2000, Train metric: 0.0929, Validation metric: 0.0960
# Estimator 94/2000, Train metric: 0.0929, Validation metric: 0.0959
# Estimator 95/2000, Train metric: 0.0928, Validation metric: 0.0958
# Estimator 96/2000, Train metric: 0.0927, Validation metric: 0.0958
# Estimator 97/2000, Train metric: 0.0927, Validation metric: 0.0957
# Estimator 98/2000, Train metric: 0.0926, Validation metric: 0.0957
# Estimator 99/2000, Train metric: 0.0926, Validation metric: 0.0956
# Estimator 100/2000, Train metric: 0.0925, Validation metric: 0.0955
# Estimator 101/2000, Train metric: 0.0924, Validation metric: 0.0954
# Estimator 102/2000, Train metric: 0.0923, Validation metric: 0.0953
# Estimator 103/2000, Train metric: 0.0923, Validation metric: 0.0952
# Estimator 104/2000, Train metric: 0.0922, Validation metric: 0.0952
# Estimator 105/2000, Train metric: 0.0922, Validation metric: 0.0952
# Estimator 106/2000, Train metric: 0.0921, Validation metric: 0.0951
# Estimator 107/2000, Train metric: 0.0921, Validation metric: 0.0951
# Estimator 108/2000, Train metric: 0.0920, Validation metric: 0.0950
# Estimator 109/2000, Train metric: 0.0919, Validation metric: 0.0949
# Estimator 110/2000, Train metric: 0.0919, Validation metric: 0.0949
# Estimator 111/2000, Train metric: 0.0918, Validation metric: 0.0948
# Estimator 112/2000, Train metric: 0.0917, Validation metric: 0.0947
# Estimator 113/2000, Train metric: 0.0917, Validation metric: 0.0946
# Estimator 114/2000, Train metric: 0.0917, Validation metric: 0.0946
# Estimator 115/2000, Train metric: 0.0916, Validation metric: 0.0946
# Estimator 116/2000, Train metric: 0.0916, Validation metric: 0.0946
# Estimator 117/2000, Train metric: 0.0916, Validation metric: 0.0945
# Estimator 118/2000, Train metric: 0.0916, Validation metric: 0.0945
# Estimator 119/2000, Train metric: 0.0915, Validation metric: 0.0945
# Estimator 120/2000, Train metric: 0.0915, Validation metric: 0.0945
# Estimator 121/2000, Train metric: 0.0914, Validation metric: 0.0944
# Estimator 122/2000, Train metric: 0.0914, Validation metric: 0.0944
# Estimator 123/2000, Train metric: 0.0913, Validation metric: 0.0943
# Estimator 124/2000, Train metric: 0.0913, Validation metric: 0.0943
# Estimator 125/2000, Train metric: 0.0913, Validation metric: 0.0942
# Estimator 126/2000, Train metric: 0.0911, Validation metric: 0.0940
# Estimator 127/2000, Train metric: 0.0910, Validation metric: 0.0939
# Estimator 128/2000, Train metric: 0.0909, Validation metric: 0.0939
# Estimator 129/2000, Train metric: 0.0908, Validation metric: 0.0938
# Estimator 130/2000, Train metric: 0.0907, Validation metric: 0.0937
# Estimator 131/2000, Train metric: 0.0907, Validation metric: 0.0937
# Estimator 132/2000, Train metric: 0.0907, Validation metric: 0.0937
# Estimator 133/2000, Train metric: 0.0907, Validation metric: 0.0936
# Estimator 134/2000, Train metric: 0.0907, Validation metric: 0.0936
# Estimator 135/2000, Train metric: 0.0906, Validation metric: 0.0936
# Estimator 136/2000, Train metric: 0.0906, Validation metric: 0.0936
# Estimator 137/2000, Train metric: 0.0906, Validation metric: 0.0936
# Estimator 138/2000, Train metric: 0.0906, Validation metric: 0.0935
# Estimator 139/2000, Train metric: 0.0905, Validation metric: 0.0935
# Estimator 140/2000, Train metric: 0.0905, Validation metric: 0.0934
# Estimator 141/2000, Train metric: 0.0905, Validation metric: 0.0934
# Estimator 142/2000, Train metric: 0.0905, Validation metric: 0.0934
# Estimator 143/2000, Train metric: 0.0904, Validation metric: 0.0934
# Estimator 144/2000, Train metric: 0.0904, Validation metric: 0.0934
# Estimator 145/2000, Train metric: 0.0904, Validation metric: 0.0933
# Estimator 146/2000, Train metric: 0.0903, Validation metric: 0.0933
# Estimator 147/2000, Train metric: 0.0903, Validation metric: 0.0933
# Estimator 148/2000, Train metric: 0.0903, Validation metric: 0.0932
# Estimator 149/2000, Train metric: 0.0903, Validation metric: 0.0932
# Estimator 150/2000, Train metric: 0.0903, Validation metric: 0.0932
# Estimator 151/2000, Train metric: 0.0902, Validation metric: 0.0931
# Estimator 152/2000, Train metric: 0.0902, Validation metric: 0.0931
# Estimator 153/2000, Train metric: 0.0901, Validation metric: 0.0930
# Estimator 154/2000, Train metric: 0.0901, Validation metric: 0.0930
# Estimator 155/2000, Train metric: 0.0901, Validation metric: 0.0930
# Estimator 156/2000, Train metric: 0.0901, Validation metric: 0.0930
# Estimator 157/2000, Train metric: 0.0900, Validation metric: 0.0929
# Estimator 158/2000, Train metric: 0.0899, Validation metric: 0.0928
# Estimator 159/2000, Train metric: 0.0899, Validation metric: 0.0928
# Estimator 160/2000, Train metric: 0.0898, Validation metric: 0.0927
# Estimator 161/2000, Train metric: 0.0898, Validation metric: 0.0927
# Estimator 162/2000, Train metric: 0.0897, Validation metric: 0.0927
# Estimator 163/2000, Train metric: 0.0897, Validation metric: 0.0926
# Estimator 164/2000, Train metric: 0.0897, Validation metric: 0.0926
# Estimator 165/2000, Train metric: 0.0897, Validation metric: 0.0926
# Estimator 166/2000, Train metric: 0.0896, Validation metric: 0.0925
# Estimator 167/2000, Train metric: 0.0896, Validation metric: 0.0925
# Estimator 168/2000, Train metric: 0.0896, Validation metric: 0.0925
# Estimator 169/2000, Train metric: 0.0895, Validation metric: 0.0924
# Estimator 170/2000, Train metric: 0.0895, Validation metric: 0.0924
# Estimator 171/2000, Train metric: 0.0895, Validation metric: 0.0924
# Estimator 172/2000, Train metric: 0.0895, Validation metric: 0.0924
# Estimator 173/2000, Train metric: 0.0894, Validation metric: 0.0924
# Estimator 174/2000, Train metric: 0.0894, Validation metric: 0.0923
# Estimator 175/2000, Train metric: 0.0894, Validation metric: 0.0923
# Estimator 176/2000, Train metric: 0.0894, Validation metric: 0.0923
# Estimator 177/2000, Train metric: 0.0893, Validation metric: 0.0922
# Estimator 178/2000, Train metric: 0.0893, Validation metric: 0.0922
# Estimator 179/2000, Train metric: 0.0893, Validation metric: 0.0922
# Estimator 180/2000, Train metric: 0.0893, Validation metric: 0.0921
# Estimator 181/2000, Train metric: 0.0892, Validation metric: 0.0921
# Estimator 182/2000, Train metric: 0.0892, Validation metric: 0.0921
# Estimator 183/2000, Train metric: 0.0892, Validation metric: 0.0921
# Estimator 184/2000, Train metric: 0.0892, Validation metric: 0.0921
# Estimator 185/2000, Train metric: 0.0892, Validation metric: 0.0921
# Estimator 186/2000, Train metric: 0.0892, Validation metric: 0.0920
# Estimator 187/2000, Train metric: 0.0892, Validation metric: 0.0920
# Estimator 188/2000, Train metric: 0.0891, Validation metric: 0.0920
# Estimator 189/2000, Train metric: 0.0891, Validation metric: 0.0920
# Estimator 190/2000, Train metric: 0.0891, Validation metric: 0.0919
# Estimator 191/2000, Train metric: 0.0890, Validation metric: 0.0919
# Estimator 192/2000, Train metric: 0.0890, Validation metric: 0.0919
# Estimator 193/2000, Train metric: 0.0890, Validation metric: 0.0919
# Estimator 194/2000, Train metric: 0.0890, Validation metric: 0.0918
# Estimator 195/2000, Train metric: 0.0889, Validation metric: 0.0917
# Estimator 196/2000, Train metric: 0.0889, Validation metric: 0.0917
# Estimator 197/2000, Train metric: 0.0888, Validation metric: 0.0917
# Estimator 198/2000, Train metric: 0.0887, Validation metric: 0.0915
# Estimator 199/2000, Train metric: 0.0886, Validation metric: 0.0915
# Estimator 200/2000, Train metric: 0.0886, Validation metric: 0.0915
# Estimator 201/2000, Train metric: 0.0886, Validation metric: 0.0915
# Estimator 202/2000, Train metric: 0.0886, Validation metric: 0.0914
# Estimator 203/2000, Train metric: 0.0886, Validation metric: 0.0914
# Estimator 204/2000, Train metric: 0.0886, Validation metric: 0.0914
# Estimator 205/2000, Train metric: 0.0885, Validation metric: 0.0914
# Estimator 206/2000, Train metric: 0.0885, Validation metric: 0.0914
# Estimator 207/2000, Train metric: 0.0884, Validation metric: 0.0913
# Estimator 208/2000, Train metric: 0.0884, Validation metric: 0.0912
# Estimator 209/2000, Train metric: 0.0883, Validation metric: 0.0912
# Estimator 210/2000, Train metric: 0.0883, Validation metric: 0.0911
# Estimator 211/2000, Train metric: 0.0882, Validation metric: 0.0911
# Estimator 212/2000, Train metric: 0.0881, Validation metric: 0.0910
# Estimator 213/2000, Train metric: 0.0881, Validation metric: 0.0910
# Estimator 214/2000, Train metric: 0.0880, Validation metric: 0.0909
# Estimator 215/2000, Train metric: 0.0880, Validation metric: 0.0909
# Estimator 216/2000, Train metric: 0.0879, Validation metric: 0.0907
# Estimator 217/2000, Train metric: 0.0879, Validation metric: 0.0907
# Estimator 218/2000, Train metric: 0.0878, Validation metric: 0.0907
# Estimator 219/2000, Train metric: 0.0878, Validation metric: 0.0907
# Estimator 220/2000, Train metric: 0.0878, Validation metric: 0.0906
# Estimator 221/2000, Train metric: 0.0878, Validation metric: 0.0906
# Estimator 222/2000, Train metric: 0.0877, Validation metric: 0.0906
# Estimator 223/2000, Train metric: 0.0877, Validation metric: 0.0906
# Estimator 224/2000, Train metric: 0.0877, Validation metric: 0.0906
# Estimator 225/2000, Train metric: 0.0877, Validation metric: 0.0905
# Estimator 226/2000, Train metric: 0.0876, Validation metric: 0.0905
# Estimator 227/2000, Train metric: 0.0875, Validation metric: 0.0903
# Estimator 228/2000, Train metric: 0.0875, Validation metric: 0.0903
# Estimator 229/2000, Train metric: 0.0874, Validation metric: 0.0903
# Estimator 230/2000, Train metric: 0.0874, Validation metric: 0.0902
# Estimator 231/2000, Train metric: 0.0874, Validation metric: 0.0902
# Estimator 232/2000, Train metric: 0.0873, Validation metric: 0.0902
# Estimator 233/2000, Train metric: 0.0873, Validation metric: 0.0902
# Estimator 234/2000, Train metric: 0.0873, Validation metric: 0.0901
# Estimator 235/2000, Train metric: 0.0872, Validation metric: 0.0901
# Estimator 236/2000, Train metric: 0.0872, Validation metric: 0.0900
# Estimator 237/2000, Train metric: 0.0871, Validation metric: 0.0900
# Estimator 238/2000, Train metric: 0.0871, Validation metric: 0.0899
# Estimator 239/2000, Train metric: 0.0870, Validation metric: 0.0899
# Estimator 240/2000, Train metric: 0.0870, Validation metric: 0.0899
# Estimator 241/2000, Train metric: 0.0870, Validation metric: 0.0898
# Estimator 242/2000, Train metric: 0.0870, Validation metric: 0.0898
# Estimator 243/2000, Train metric: 0.0870, Validation metric: 0.0898
# Estimator 244/2000, Train metric: 0.0870, Validation metric: 0.0898
# Estimator 245/2000, Train metric: 0.0869, Validation metric: 0.0898
# Estimator 246/2000, Train metric: 0.0869, Validation metric: 0.0897
# Estimator 247/2000, Train metric: 0.0869, Validation metric: 0.0897
# Estimator 248/2000, Train metric: 0.0868, Validation metric: 0.0897
# Estimator 249/2000, Train metric: 0.0868, Validation metric: 0.0897
# Estimator 250/2000, Train metric: 0.0868, Validation metric: 0.0896
# Estimator 251/2000, Train metric: 0.0868, Validation metric: 0.0896
# Estimator 252/2000, Train metric: 0.0867, Validation metric: 0.0896
# Estimator 253/2000, Train metric: 0.0867, Validation metric: 0.0896
# Estimator 254/2000, Train metric: 0.0867, Validation metric: 0.0895
# Estimator 255/2000, Train metric: 0.0867, Validation metric: 0.0895
# Estimator 256/2000, Train metric: 0.0867, Validation metric: 0.0895
# Estimator 257/2000, Train metric: 0.0866, Validation metric: 0.0895
# Estimator 258/2000, Train metric: 0.0866, Validation metric: 0.0895
# Estimator 259/2000, Train metric: 0.0866, Validation metric: 0.0894
# Estimator 260/2000, Train metric: 0.0866, Validation metric: 0.0894
# Estimator 261/2000, Train metric: 0.0866, Validation metric: 0.0894
# Estimator 262/2000, Train metric: 0.0866, Validation metric: 0.0894
# Estimator 263/2000, Train metric: 0.0865, Validation metric: 0.0894
# Estimator 264/2000, Train metric: 0.0865, Validation metric: 0.0894
# Estimator 265/2000, Train metric: 0.0864, Validation metric: 0.0893
# Estimator 266/2000, Train metric: 0.0864, Validation metric: 0.0892
# Estimator 267/2000, Train metric: 0.0864, Validation metric: 0.0892
# Estimator 268/2000, Train metric: 0.0863, Validation metric: 0.0892
# Estimator 269/2000, Train metric: 0.0863, Validation metric: 0.0891
# Estimator 270/2000, Train metric: 0.0863, Validation metric: 0.0891
# Estimator 271/2000, Train metric: 0.0863, Validation metric: 0.0891
# Estimator 272/2000, Train metric: 0.0862, Validation metric: 0.0891
# Estimator 273/2000, Train metric: 0.0862, Validation metric: 0.0890
# Estimator 274/2000, Train metric: 0.0862, Validation metric: 0.0890
# Estimator 275/2000, Train metric: 0.0861, Validation metric: 0.0890
# Estimator 276/2000, Train metric: 0.0860, Validation metric: 0.0889
# Estimator 277/2000, Train metric: 0.0860, Validation metric: 0.0888
# Estimator 278/2000, Train metric: 0.0860, Validation metric: 0.0888
# Estimator 279/2000, Train metric: 0.0859, Validation metric: 0.0888
# Estimator 280/2000, Train metric: 0.0859, Validation metric: 0.0887
# Estimator 281/2000, Train metric: 0.0859, Validation metric: 0.0887
# Estimator 282/2000, Train metric: 0.0859, Validation metric: 0.0887
# Estimator 283/2000, Train metric: 0.0859, Validation metric: 0.0887
# Estimator 284/2000, Train metric: 0.0859, Validation metric: 0.0887
# Estimator 285/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 286/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 287/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 288/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 289/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 290/2000, Train metric: 0.0858, Validation metric: 0.0886
# Estimator 291/2000, Train metric: 0.0858, Validation metric: 0.0885
# Estimator 292/2000, Train metric: 0.0857, Validation metric: 0.0885
# Estimator 293/2000, Train metric: 0.0857, Validation metric: 0.0885
# Estimator 294/2000, Train metric: 0.0857, Validation metric: 0.0885
# Estimator 295/2000, Train metric: 0.0857, Validation metric: 0.0885
# Estimator 296/2000, Train metric: 0.0857, Validation metric: 0.0884
# Estimator 297/2000, Train metric: 0.0856, Validation metric: 0.0884
# Estimator 298/2000, Train metric: 0.0856, Validation metric: 0.0884
# Estimator 299/2000, Train metric: 0.0856, Validation metric: 0.0884
# Estimator 300/2000, Train metric: 0.0856, Validation metric: 0.0883
# Estimator 301/2000, Train metric: 0.0855, Validation metric: 0.0883
# Estimator 302/2000, Train metric: 0.0855, Validation metric: 0.0883
# Estimator 303/2000, Train metric: 0.0855, Validation metric: 0.0883
# Estimator 304/2000, Train metric: 0.0854, Validation metric: 0.0882
# Estimator 305/2000, Train metric: 0.0854, Validation metric: 0.0882
# Estimator 306/2000, Train metric: 0.0853, Validation metric: 0.0881
# Estimator 307/2000, Train metric: 0.0853, Validation metric: 0.0881
# Estimator 308/2000, Train metric: 0.0853, Validation metric: 0.0881
# Estimator 309/2000, Train metric: 0.0853, Validation metric: 0.0881
# Estimator 310/2000, Train metric: 0.0853, Validation metric: 0.0881
# Estimator 311/2000, Train metric: 0.0853, Validation metric: 0.0880
# Estimator 312/2000, Train metric: 0.0852, Validation metric: 0.0880
# Estimator 313/2000, Train metric: 0.0851, Validation metric: 0.0879
# Estimator 314/2000, Train metric: 0.0851, Validation metric: 0.0879
# Estimator 315/2000, Train metric: 0.0851, Validation metric: 0.0878
# Estimator 316/2000, Train metric: 0.0851, Validation metric: 0.0878
# Estimator 317/2000, Train metric: 0.0850, Validation metric: 0.0878
# Estimator 318/2000, Train metric: 0.0850, Validation metric: 0.0877
# Estimator 319/2000, Train metric: 0.0850, Validation metric: 0.0877
# Estimator 320/2000, Train metric: 0.0849, Validation metric: 0.0877
# Estimator 321/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 322/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 323/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 324/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 325/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 326/2000, Train metric: 0.0849, Validation metric: 0.0876
# Estimator 327/2000, Train metric: 0.0848, Validation metric: 0.0876
# Estimator 328/2000, Train metric: 0.0848, Validation metric: 0.0876
# Estimator 329/2000, Train metric: 0.0848, Validation metric: 0.0876
# Estimator 330/2000, Train metric: 0.0848, Validation metric: 0.0876
# Estimator 331/2000, Train metric: 0.0848, Validation metric: 0.0876
# Estimator 332/2000, Train metric: 0.0848, Validation metric: 0.0875
# Estimator 333/2000, Train metric: 0.0847, Validation metric: 0.0874
# Estimator 334/2000, Train metric: 0.0847, Validation metric: 0.0874
# Estimator 335/2000, Train metric: 0.0847, Validation metric: 0.0874
# Estimator 336/2000, Train metric: 0.0846, Validation metric: 0.0874
# Estimator 337/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 338/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 339/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 340/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 341/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 342/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 343/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 344/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 345/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 346/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 347/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 348/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 349/2000, Train metric: 0.0846, Validation metric: 0.0873
# Estimator 350/2000, Train metric: 0.0845, Validation metric: 0.0872
# Estimator 351/2000, Train metric: 0.0845, Validation metric: 0.0872
# Estimator 352/2000, Train metric: 0.0845, Validation metric: 0.0872
# Estimator 353/2000, Train metric: 0.0844, Validation metric: 0.0871
# Estimator 354/2000, Train metric: 0.0844, Validation metric: 0.0871
# Estimator 355/2000, Train metric: 0.0843, Validation metric: 0.0871
# Estimator 356/2000, Train metric: 0.0843, Validation metric: 0.0870
# Estimator 357/2000, Train metric: 0.0843, Validation metric: 0.0870
# Estimator 358/2000, Train metric: 0.0842, Validation metric: 0.0869
# Estimator 359/2000, Train metric: 0.0841, Validation metric: 0.0869
# Estimator 360/2000, Train metric: 0.0841, Validation metric: 0.0868
# Estimator 361/2000, Train metric: 0.0841, Validation metric: 0.0868
# Estimator 362/2000, Train metric: 0.0841, Validation metric: 0.0868
# Estimator 363/2000, Train metric: 0.0841, Validation metric: 0.0868
# Estimator 364/2000, Train metric: 0.0840, Validation metric: 0.0868
# Estimator 365/2000, Train metric: 0.0840, Validation metric: 0.0867
# Estimator 366/2000, Train metric: 0.0840, Validation metric: 0.0867
# Estimator 367/2000, Train metric: 0.0840, Validation metric: 0.0867
# Estimator 368/2000, Train metric: 0.0840, Validation metric: 0.0867
# Estimator 369/2000, Train metric: 0.0840, Validation metric: 0.0867
# Estimator 370/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 371/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 372/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 373/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 374/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 375/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 376/2000, Train metric: 0.0839, Validation metric: 0.0866
# Estimator 377/2000, Train metric: 0.0838, Validation metric: 0.0865
# Estimator 378/2000, Train metric: 0.0838, Validation metric: 0.0865
# Estimator 379/2000, Train metric: 0.0838, Validation metric: 0.0865
# Estimator 380/2000, Train metric: 0.0837, Validation metric: 0.0865
# Estimator 381/2000, Train metric: 0.0837, Validation metric: 0.0864
# Estimator 382/2000, Train metric: 0.0837, Validation metric: 0.0864
# Estimator 383/2000, Train metric: 0.0836, Validation metric: 0.0863
# Estimator 384/2000, Train metric: 0.0836, Validation metric: 0.0863
# Estimator 385/2000, Train metric: 0.0836, Validation metric: 0.0863
# Estimator 386/2000, Train metric: 0.0836, Validation metric: 0.0863
# Estimator 387/2000, Train metric: 0.0836, Validation metric: 0.0863
# Estimator 388/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 389/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 390/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 391/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 392/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 393/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 394/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 395/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 396/2000, Train metric: 0.0835, Validation metric: 0.0862
# Estimator 397/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 398/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 399/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 400/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 401/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 402/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 403/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 404/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 405/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 406/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 407/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 408/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 409/2000, Train metric: 0.0834, Validation metric: 0.0861
# Estimator 410/2000, Train metric: 0.0834, Validation metric: 0.0860
# Estimator 411/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 412/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 413/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 414/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 415/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 416/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 417/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 418/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 419/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 420/2000, Train metric: 0.0833, Validation metric: 0.0860
# Estimator 421/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 422/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 423/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 424/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 425/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 426/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 427/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 428/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 429/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 430/2000, Train metric: 0.0832, Validation metric: 0.0859
# Estimator 431/2000, Train metric: 0.0831, Validation metric: 0.0858
# Estimator 432/2000, Train metric: 0.0831, Validation metric: 0.0858
# Estimator 433/2000, Train metric: 0.0831, Validation metric: 0.0858
# Estimator 434/2000, Train metric: 0.0831, Validation metric: 0.0858
# Estimator 435/2000, Train metric: 0.0831, Validation metric: 0.0858
# Estimator 436/2000, Train metric: 0.0831, Validation metric: 0.0857
# Estimator 437/2000, Train metric: 0.0831, Validation metric: 0.0857
# Estimator 438/2000, Train metric: 0.0830, Validation metric: 0.0857
# Estimator 439/2000, Train metric: 0.0830, Validation metric: 0.0857
# Estimator 440/2000, Train metric: 0.0830, Validation metric: 0.0857
# Estimator 441/2000, Train metric: 0.0830, Validation metric: 0.0857
# Estimator 442/2000, Train metric: 0.0830, Validation metric: 0.0857
# Estimator 443/2000, Train metric: 0.0830, Validation metric: 0.0856
# Estimator 444/2000, Train metric: 0.0829, Validation metric: 0.0856
# Estimator 445/2000, Train metric: 0.0829, Validation metric: 0.0856
# Estimator 446/2000, Train metric: 0.0829, Validation metric: 0.0856
# Estimator 447/2000, Train metric: 0.0829, Validation metric: 0.0855
# Estimator 448/2000, Train metric: 0.0829, Validation metric: 0.0855
# Estimator 449/2000, Train metric: 0.0829, Validation metric: 0.0855
# Estimator 450/2000, Train metric: 0.0829, Validation metric: 0.0855
# Estimator 451/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 452/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 453/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 454/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 455/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 456/2000, Train metric: 0.0828, Validation metric: 0.0855
# Estimator 457/2000, Train metric: 0.0828, Validation metric: 0.0854
# Estimator 458/2000, Train metric: 0.0828, Validation metric: 0.0854
# Estimator 459/2000, Train metric: 0.0827, Validation metric: 0.0854
# Estimator 460/2000, Train metric: 0.0827, Validation metric: 0.0854
# Estimator 461/2000, Train metric: 0.0827, Validation metric: 0.0854
# Estimator 462/2000, Train metric: 0.0827, Validation metric: 0.0853
# Estimator 463/2000, Train metric: 0.0827, Validation metric: 0.0853
# Estimator 464/2000, Train metric: 0.0826, Validation metric: 0.0853
# Estimator 465/2000, Train metric: 0.0826, Validation metric: 0.0853
# Estimator 466/2000, Train metric: 0.0826, Validation metric: 0.0853
# Estimator 467/2000, Train metric: 0.0826, Validation metric: 0.0853
# Estimator 468/2000, Train metric: 0.0826, Validation metric: 0.0852
# Estimator 469/2000, Train metric: 0.0826, Validation metric: 0.0852
# Estimator 470/2000, Train metric: 0.0826, Validation metric: 0.0852
# Estimator 471/2000, Train metric: 0.0825, Validation metric: 0.0852
# Estimator 472/2000, Train metric: 0.0825, Validation metric: 0.0852
# Estimator 473/2000, Train metric: 0.0825, Validation metric: 0.0852
# Estimator 474/2000, Train metric: 0.0825, Validation metric: 0.0852
# Estimator 475/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 476/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 477/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 478/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 479/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 480/2000, Train metric: 0.0825, Validation metric: 0.0851
# Estimator 481/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 482/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 483/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 484/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 485/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 486/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 487/2000, Train metric: 0.0824, Validation metric: 0.0851
# Estimator 488/2000, Train metric: 0.0824, Validation metric: 0.0850
# Estimator 489/2000, Train metric: 0.0824, Validation metric: 0.0850
# Estimator 490/2000, Train metric: 0.0823, Validation metric: 0.0850
# Estimator 491/2000, Train metric: 0.0823, Validation metric: 0.0850
# Estimator 492/2000, Train metric: 0.0822, Validation metric: 0.0849
# Estimator 493/2000, Train metric: 0.0822, Validation metric: 0.0849
# Estimator 494/2000, Train metric: 0.0822, Validation metric: 0.0849
# Estimator 495/2000, Train metric: 0.0822, Validation metric: 0.0849
# Estimator 496/2000, Train metric: 0.0822, Validation metric: 0.0848
# Estimator 497/2000, Train metric: 0.0822, Validation metric: 0.0848
# Estimator 498/2000, Train metric: 0.0821, Validation metric: 0.0848
# Estimator 499/2000, Train metric: 0.0821, Validation metric: 0.0848
# Estimator 500/2000, Train metric: 0.0821, Validation metric: 0.0848
# Estimator 501/2000, Train metric: 0.0821, Validation metric: 0.0847
# Estimator 502/2000, Train metric: 0.0821, Validation metric: 0.0847
# Estimator 503/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 504/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 505/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 506/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 507/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 508/2000, Train metric: 0.0820, Validation metric: 0.0847
# Estimator 509/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 510/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 511/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 512/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 513/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 514/2000, Train metric: 0.0819, Validation metric: 0.0846
# Estimator 515/2000, Train metric: 0.0819, Validation metric: 0.0845
# Estimator 516/2000, Train metric: 0.0819, Validation metric: 0.0845
# Estimator 517/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 518/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 519/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 520/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 521/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 522/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 523/2000, Train metric: 0.0818, Validation metric: 0.0845
# Estimator 524/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 525/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 526/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 527/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 528/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 529/2000, Train metric: 0.0817, Validation metric: 0.0844
# Estimator 530/2000, Train metric: 0.0817, Validation metric: 0.0843
# Estimator 531/2000, Train metric: 0.0817, Validation metric: 0.0843
# Estimator 532/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 533/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 534/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 535/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 536/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 537/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 538/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 539/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 540/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 541/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 542/2000, Train metric: 0.0816, Validation metric: 0.0843
# Estimator 543/2000, Train metric: 0.0816, Validation metric: 0.0842
# Estimator 544/2000, Train metric: 0.0815, Validation metric: 0.0842
# Estimator 545/2000, Train metric: 0.0815, Validation metric: 0.0842
# Estimator 546/2000, Train metric: 0.0815, Validation metric: 0.0842
# Estimator 547/2000, Train metric: 0.0815, Validation metric: 0.0842
# Estimator 548/2000, Train metric: 0.0815, Validation metric: 0.0842
# Estimator 549/2000, Train metric: 0.0815, Validation metric: 0.0841
# Estimator 550/2000, Train metric: 0.0815, Validation metric: 0.0841
# Estimator 551/2000, Train metric: 0.0815, Validation metric: 0.0841
# Estimator 552/2000, Train metric: 0.0815, Validation metric: 0.0841
# Estimator 553/2000, Train metric: 0.0814, Validation metric: 0.0841
# Estimator 554/2000, Train metric: 0.0814, Validation metric: 0.0841
# Estimator 555/2000, Train metric: 0.0814, Validation metric: 0.0841
# Estimator 556/2000, Train metric: 0.0813, Validation metric: 0.0840
# Estimator 557/2000, Train metric: 0.0813, Validation metric: 0.0840
# Estimator 558/2000, Train metric: 0.0812, Validation metric: 0.0840
# Estimator 559/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 560/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 561/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 562/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 563/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 564/2000, Train metric: 0.0812, Validation metric: 0.0839
# Estimator 565/2000, Train metric: 0.0811, Validation metric: 0.0839
# Estimator 566/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 567/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 568/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 569/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 570/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 571/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 572/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 573/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 574/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 575/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 576/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 577/2000, Train metric: 0.0811, Validation metric: 0.0838
# Estimator 578/2000, Train metric: 0.0810, Validation metric: 0.0838
# Estimator 579/2000, Train metric: 0.0810, Validation metric: 0.0838
# Estimator 580/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 581/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 582/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 583/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 584/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 585/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 586/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 587/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 588/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 589/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 590/2000, Train metric: 0.0810, Validation metric: 0.0837
# Estimator 591/2000, Train metric: 0.0809, Validation metric: 0.0837
# Estimator 592/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 593/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 594/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 595/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 596/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 597/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 598/2000, Train metric: 0.0809, Validation metric: 0.0836
# Estimator 599/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 600/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 601/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 602/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 603/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 604/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 605/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 606/2000, Train metric: 0.0808, Validation metric: 0.0835
# Estimator 607/2000, Train metric: 0.0807, Validation metric: 0.0834
# Estimator 608/2000, Train metric: 0.0807, Validation metric: 0.0834
# Estimator 609/2000, Train metric: 0.0807, Validation metric: 0.0834
# Estimator 610/2000, Train metric: 0.0807, Validation metric: 0.0834
# Estimator 611/2000, Train metric: 0.0806, Validation metric: 0.0834
# Estimator 612/2000, Train metric: 0.0806, Validation metric: 0.0833
# Estimator 613/2000, Train metric: 0.0806, Validation metric: 0.0833
# Estimator 614/2000, Train metric: 0.0806, Validation metric: 0.0833
# Estimator 615/2000, Train metric: 0.0806, Validation metric: 0.0833
# Estimator 616/2000, Train metric: 0.0805, Validation metric: 0.0833
# Estimator 617/2000, Train metric: 0.0805, Validation metric: 0.0832
# Estimator 618/2000, Train metric: 0.0805, Validation metric: 0.0832
# Estimator 619/2000, Train metric: 0.0805, Validation metric: 0.0832
# Estimator 620/2000, Train metric: 0.0805, Validation metric: 0.0832
# Estimator 621/2000, Train metric: 0.0805, Validation metric: 0.0832
# Estimator 622/2000, Train metric: 0.0804, Validation metric: 0.0832
# Estimator 623/2000, Train metric: 0.0804, Validation metric: 0.0832
# Estimator 624/2000, Train metric: 0.0804, Validation metric: 0.0832
# Estimator 625/2000, Train metric: 0.0804, Validation metric: 0.0832
# Estimator 626/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 627/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 628/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 629/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 630/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 631/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 632/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 633/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 634/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 635/2000, Train metric: 0.0804, Validation metric: 0.0831
# Estimator 636/2000, Train metric: 0.0803, Validation metric: 0.0831
# Estimator 637/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 638/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 639/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 640/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 641/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 642/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 643/2000, Train metric: 0.0803, Validation metric: 0.0830
# Estimator 644/2000, Train metric: 0.0802, Validation metric: 0.0830
# Estimator 645/2000, Train metric: 0.0802, Validation metric: 0.0830
# Estimator 646/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 647/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 648/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 649/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 650/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 651/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 652/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 653/2000, Train metric: 0.0802, Validation metric: 0.0829
# Estimator 654/2000, Train metric: 0.0801, Validation metric: 0.0829
# Estimator 655/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 656/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 657/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 658/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 659/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 660/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 661/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 662/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 663/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 664/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 665/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 666/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 667/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 668/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 669/2000, Train metric: 0.0801, Validation metric: 0.0828
# Estimator 670/2000, Train metric: 0.0800, Validation metric: 0.0828
# Estimator 671/2000, Train metric: 0.0800, Validation metric: 0.0827
# Estimator 672/2000, Train metric: 0.0800, Validation metric: 0.0827
# Estimator 673/2000, Train metric: 0.0800, Validation metric: 0.0827
# Estimator 674/2000, Train metric: 0.0800, Validation metric: 0.0827
# Estimator 675/2000, Train metric: 0.0800, Validation metric: 0.0827
# Estimator 676/2000, Train metric: 0.0799, Validation metric: 0.0827
# Estimator 677/2000, Train metric: 0.0799, Validation metric: 0.0827
# Estimator 678/2000, Train metric: 0.0799, Validation metric: 0.0827
# Estimator 679/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 680/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 681/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 682/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 683/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 684/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 685/2000, Train metric: 0.0799, Validation metric: 0.0826
# Estimator 686/2000, Train metric: 0.0798, Validation metric: 0.0826
# Estimator 687/2000, Train metric: 0.0798, Validation metric: 0.0826
# Estimator 688/2000, Train metric: 0.0798, Validation metric: 0.0826
# Estimator 689/2000, Train metric: 0.0798, Validation metric: 0.0826
# Estimator 690/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 691/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 692/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 693/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 694/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 695/2000, Train metric: 0.0798, Validation metric: 0.0825
# Estimator 696/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 697/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 698/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 699/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 700/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 701/2000, Train metric: 0.0797, Validation metric: 0.0825
# Estimator 702/2000, Train metric: 0.0797, Validation metric: 0.0824
# Estimator 703/2000, Train metric: 0.0797, Validation metric: 0.0824
# Estimator 704/2000, Train metric: 0.0797, Validation metric: 0.0824
# Estimator 705/2000, Train metric: 0.0797, Validation metric: 0.0824
# Estimator 706/2000, Train metric: 0.0797, Validation metric: 0.0824
# ...
# Estimator 1769/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1770/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1771/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1772/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1773/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1774/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1775/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1776/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1777/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1778/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1779/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1780/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1781/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1782/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1783/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1784/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1785/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1786/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1787/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1788/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1789/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1790/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1791/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1792/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1793/2000, Train metric: 0.0741, Validation metric: 0.0763
# Estimator 1794/2000, Train metric: 0.0741, Validation metric: 0.0762
# Estimator 1795/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1796/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1797/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1798/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1799/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1800/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1801/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1802/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1803/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1804/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1805/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1806/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1807/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1808/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1809/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1810/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1811/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1812/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1813/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1814/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1815/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1816/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1817/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1818/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1819/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1820/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1821/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1822/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1823/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1824/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1825/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1826/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1827/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1828/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1829/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1830/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1831/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1832/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1833/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1834/2000, Train metric: 0.0740, Validation metric: 0.0762
# Estimator 1835/2000, Train metric: 0.0740, Validation metric: 0.0761
# Estimator 1836/2000, Train metric: 0.0740, Validation metric: 0.0761
# Estimator 1837/2000, Train metric: 0.0740, Validation metric: 0.0761
# Estimator 1838/2000, Train metric: 0.0740, Validation metric: 0.0761
# Estimator 1839/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1840/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1841/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1842/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1843/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1844/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1845/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1846/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1847/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1848/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1849/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1850/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1851/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1852/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1853/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1854/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1855/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1856/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1857/2000, Train metric: 0.0739, Validation metric: 0.0761
# Estimator 1858/2000, Train metric: 0.0739, Validation metric: 0.0760
# Estimator 1859/2000, Train metric: 0.0739, Validation metric: 0.0760
# Estimator 1860/2000, Train metric: 0.0739, Validation metric: 0.0760
# Estimator 1861/2000, Train metric: 0.0739, Validation metric: 0.0760
# Estimator 1862/2000, Train metric: 0.0739, Validation metric: 0.0760
# Estimator 1863/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1864/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1865/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1866/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1867/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1868/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1869/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1870/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1871/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1872/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1873/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1874/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1875/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1876/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1877/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1878/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1879/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1880/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1881/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1882/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1883/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1884/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1885/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1886/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1887/2000, Train metric: 0.0738, Validation metric: 0.0760
# Estimator 1888/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1889/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1890/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1891/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1892/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1893/2000, Train metric: 0.0738, Validation metric: 0.0759
# Estimator 1894/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1895/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1896/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1897/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1898/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1899/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1900/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1901/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1902/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1903/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1904/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1905/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1906/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1907/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1908/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1909/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1910/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1911/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1912/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1913/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1914/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1915/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1916/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1917/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1918/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1919/2000, Train metric: 0.0737, Validation metric: 0.0759
# Estimator 1920/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1921/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1922/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1923/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1924/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1925/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1926/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1927/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1928/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1929/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1930/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1931/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1932/2000, Train metric: 0.0737, Validation metric: 0.0758
# Estimator 1933/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1934/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1935/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1936/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1937/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1938/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1939/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1940/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1941/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1942/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1943/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1944/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1945/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1946/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1947/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1948/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1949/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1950/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1951/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1952/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1953/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1954/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1955/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1956/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1957/2000, Train metric: 0.0736, Validation metric: 0.0758
# Estimator 1958/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1959/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1960/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1961/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1962/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1963/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1964/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1965/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1966/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1967/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1968/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1969/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1970/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1971/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1972/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1973/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1974/2000, Train metric: 0.0736, Validation metric: 0.0757
# Estimator 1975/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1976/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1977/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1978/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1979/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1980/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1981/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1982/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1983/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1984/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1985/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1986/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1987/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1988/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1989/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1990/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1991/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1992/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1993/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1994/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1995/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1996/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1997/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1998/2000, Train metric: 0.0735, Validation metric: 0.0757
# Estimator 1999/2000, Train metric: 0.0735, Validation metric: 0.0757

# %%
model.optimize_distribution(x_val.values, y_val.values.reshape(-1))
# Out:
# CRPS: 0.12 (Distribution: normal, Tree correlation: 0.000)
# CRPS: 0.10 (Distribution: normal, Tree correlation: 0.010)
# CRPS: 0.09 (Distribution: normal, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: normal, Tree correlation: 0.060)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.070)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.080)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.090)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.100)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.110)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.120)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.130)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.140)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.150)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.160)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.170)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.180)
# CRPS: 0.07 (Distribution: normal, Tree correlation: 0.190)
# CRPS: 0.09 (Distribution: studentt, Tree correlation: 0.000)
# CRPS: 0.08 (Distribution: studentt, Tree correlation: 0.010)
# CRPS: 0.07 (Distribution: studentt, Tree correlation: 0.020)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.030)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.040)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.050)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.060)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.070)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.080)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.090)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.100)
# CRPS: 0.06 (Distribution: studentt, Tree correlation: 0.110)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.120)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.130)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.140)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.150)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.160)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.170)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.180)
# CRPS: 0.05 (Distribution: studentt, Tree correlation: 0.190)
# CRPS: 0.10 (Distribution: laplace, Tree correlation: 0.000)
# CRPS: 0.08 (Distribution: laplace, Tree correlation: 0.010)
# CRPS: 0.07 (Distribution: laplace, Tree correlation: 0.020)
# CRPS: 0.07 (Distribution: laplace, Tree correlation: 0.030)
# CRPS: 0.07 (Distribution: laplace, Tree correlation: 0.040)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.050)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.060)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.070)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.080)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.090)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.100)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.110)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.120)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.130)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.140)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.150)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.160)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.170)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.180)
# CRPS: 0.06 (Distribution: laplace, Tree correlation: 0.190)
# CRPS: 0.11 (Distribution: logistic, Tree correlation: 0.000)
# CRPS: 0.10 (Distribution: logistic, Tree correlation: 0.010)
# CRPS: 0.09 (Distribution: logistic, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: logistic, Tree correlation: 0.040)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.050)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.060)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.070)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.080)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.090)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.100)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.110)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.120)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.130)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.140)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.150)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.160)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.170)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.180)
# CRPS: 0.07 (Distribution: logistic, Tree correlation: 0.190)
# CRPS: 0.12 (Distribution: gamma, Tree correlation: 0.000)
# CRPS: 0.10 (Distribution: gamma, Tree correlation: 0.010)
# CRPS: 0.09 (Distribution: gamma, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.050)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.060)
# CRPS: 0.08 (Distribution: gamma, Tree correlation: 0.070)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.080)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.090)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.100)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.110)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.120)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.130)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.140)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.150)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.160)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.170)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.180)
# CRPS: 0.07 (Distribution: gamma, Tree correlation: 0.190)
# CRPS: 0.12 (Distribution: gumbel, Tree correlation: 0.000)
# CRPS: 0.10 (Distribution: gumbel, Tree correlation: 0.010)
# CRPS: 0.09 (Distribution: gumbel, Tree correlation: 0.020)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.030)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.040)
# CRPS: 0.08 (Distribution: gumbel, Tree correlation: 0.050)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.060)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.070)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.080)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.090)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.100)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.110)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.120)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.130)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.140)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.150)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.160)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.170)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.180)
# CRPS: 0.07 (Distribution: gumbel, Tree correlation: 0.190)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.000)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.010)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.020)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.030)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.040)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.050)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.060)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.070)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.080)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.090)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.100)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.110)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.120)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.130)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.140)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.150)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.160)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.170)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.180)
# CRPS: 0.62 (Distribution: poisson, Tree correlation: 0.190)
# Lowest CRPS: 0.0539 (Distribution: studentt, Tree correlation: 0.190)
# ('studentt', 0.19)

# %%
y_train_dist = model.predict_dist(x_train.values, n_forecasts=1000)
y_val_dist = model.predict_dist(x_val.values, n_forecasts=1000)
y_test_dist = model.predict_dist(x_test.values, n_forecasts=1000)

# %%
print(model.crps_ensemble(y_train_dist, y_train.values.reshape(-1)).mean())
print(model.crps_ensemble(y_val_dist, y_val.values.reshape(-1)).mean())
print(model.crps_ensemble(y_test_dist, y_test.values.reshape(-1)).mean())
# Out:
# 0.05234536588713952
# 0.052828073031196104
# 0.053563489543455224
