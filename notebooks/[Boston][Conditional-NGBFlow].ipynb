# %%
import warnings

warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import ngflowboost as ngbf
import numpy as np
import pandas as pd
import torch

from models.flow import build_model
from utils.datasets import load_regression_dataset

# %%
X, y, index_train, index_test, n_splits = load_regression_dataset('bostonHousing')

# %%
flow = build_model(
    input_dim=1,
    hidden_dims=(40,),
    context_dim=13,
    conditional=True,
    time_length=1.0,
    batch_norm=True,
    layer_type="concatscale"
)

model = ngbf.NGBoost(verbose_eval=25, flow=flow)

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
model.fit(X, y)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# torch.Size([506, 13]) torch.Size([506])
#   0%|          | 0/100 [00:29<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6d10fe8973eb> in <module>
# ----> 1 model.fit(X, y)
#
# ~/PhD/Probabilistic-Flow-Boosting/ngflowboost/ngboost.py in fit(self, X, Y, X_val, Y_val, sample_weight, val_sample_weight, train_loss_monitor, val_loss_monitor, early_stopping_rounds)
#     326
#     327         loss_list = []
# --> 328         self.fit_init_params_to_marginal(X, Y, iters=self.flow_init_iters)
#     329
#     330         params = self.pred_param(X)
#
# ~/PhD/Probabilistic-Flow-Boosting/ngflowboost/ngboost.py in fit_init_params_to_marginal(self, X, Y, sample_weight, iters)
#     163                 zero = torch.zeros(Y_batch.shape[0], 1).to(self.DEVICE)
#     164
# ...
