# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/diamonds2/diamonds_dataset.csv')

# %%
x = df.drop(columns = ['id', 'url', 'price', 'date_fetched'])
x = pd.get_dummies(x)
y = np.log10(df[['price']])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((95445, 37), (23862, 37))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 0.3851, Validation metric: 0.3822
# Estimator 1/2000, Train metric: 0.3599, Validation metric: 0.3570
# Estimator 2/2000, Train metric: 0.3381, Validation metric: 0.3352
# Estimator 3/2000, Train metric: 0.3193, Validation metric: 0.3164
# Estimator 4/2000, Train metric: 0.3032, Validation metric: 0.3004
# Estimator 5/2000, Train metric: 0.2894, Validation metric: 0.2866
# Estimator 6/2000, Train metric: 0.2776, Validation metric: 0.2750
# Estimator 7/2000, Train metric: 0.2678, Validation metric: 0.2652
# Estimator 8/2000, Train metric: 0.2594, Validation metric: 0.2570
# Estimator 9/2000, Train metric: 0.2525, Validation metric: 0.2501
# Estimator 10/2000, Train metric: 0.2467, Validation metric: 0.2444
# Estimator 11/2000, Train metric: 0.2418, Validation metric: 0.2397
# Estimator 12/2000, Train metric: 0.2378, Validation metric: 0.2357
# Estimator 13/2000, Train metric: 0.2345, Validation metric: 0.2325
# Estimator 14/2000, Train metric: 0.2318, Validation metric: 0.2299
# Estimator 15/2000, Train metric: 0.2295, Validation metric: 0.2277
# Estimator 16/2000, Train metric: 0.2276, Validation metric: 0.2258
# Estimator 17/2000, Train metric: 0.2260, Validation metric: 0.2243
# Estimator 18/2000, Train metric: 0.2247, Validation metric: 0.2230
# Estimator 19/2000, Train metric: 0.2236, Validation metric: 0.2220
# Estimator 20/2000, Train metric: 0.2227, Validation metric: 0.2211
# Estimator 21/2000, Train metric: 0.2219, Validation metric: 0.2203
# Estimator 22/2000, Train metric: 0.2212, Validation metric: 0.2197
# Estimator 23/2000, Train metric: 0.2206, Validation metric: 0.2191
# Estimator 24/2000, Train metric: 0.2201, Validation metric: 0.2186
# Estimator 25/2000, Train metric: 0.2197, Validation metric: 0.2183
# Estimator 26/2000, Train metric: 0.2194, Validation metric: 0.2179
# Estimator 27/2000, Train metric: 0.2190, Validation metric: 0.2176
# Estimator 28/2000, Train metric: 0.2188, Validation metric: 0.2173
# Estimator 29/2000, Train metric: 0.2186, Validation metric: 0.2171
# Estimator 30/2000, Train metric: 0.2184, Validation metric: 0.2170
# Estimator 31/2000, Train metric: 0.2182, Validation metric: 0.2168
# Estimator 32/2000, Train metric: 0.2181, Validation metric: 0.2167
# Estimator 33/2000, Train metric: 0.2180, Validation metric: 0.2166
# Estimator 34/2000, Train metric: 0.2179, Validation metric: 0.2165
# Estimator 35/2000, Train metric: 0.2178, Validation metric: 0.2164
# Estimator 36/2000, Train metric: 0.2177, Validation metric: 0.2163
# Estimator 37/2000, Train metric: 0.2176, Validation metric: 0.2162
# Estimator 38/2000, Train metric: 0.2175, Validation metric: 0.2161
# Estimator 39/2000, Train metric: 0.2174, Validation metric: 0.2161
# Estimator 40/2000, Train metric: 0.2174, Validation metric: 0.2160
# Estimator 41/2000, Train metric: 0.2173, Validation metric: 0.2160
# Estimator 42/2000, Train metric: 0.2173, Validation metric: 0.2159
# Estimator 43/2000, Train metric: 0.2172, Validation metric: 0.2159
# Estimator 44/2000, Train metric: 0.2172, Validation metric: 0.2158
# Estimator 45/2000, Train metric: 0.2172, Validation metric: 0.2158
# Estimator 46/2000, Train metric: 0.2171, Validation metric: 0.2158
# Estimator 47/2000, Train metric: 0.2171, Validation metric: 0.2157
# Estimator 48/2000, Train metric: 0.2171, Validation metric: 0.2157
# Estimator 49/2000, Train metric: 0.2170, Validation metric: 0.2157
# Estimator 50/2000, Train metric: 0.2170, Validation metric: 0.2156
# Estimator 51/2000, Train metric: 0.2170, Validation metric: 0.2156
# Estimator 52/2000, Train metric: 0.2170, Validation metric: 0.2156
# Estimator 53/2000, Train metric: 0.2169, Validation metric: 0.2156
# Estimator 54/2000, Train metric: 0.2169, Validation metric: 0.2155
# Estimator 55/2000, Train metric: 0.2169, Validation metric: 0.2155
# Estimator 56/2000, Train metric: 0.2169, Validation metric: 0.2155
# Estimator 57/2000, Train metric: 0.2168, Validation metric: 0.2155
# Estimator 58/2000, Train metric: 0.2168, Validation metric: 0.2155
# Estimator 59/2000, Train metric: 0.2168, Validation metric: 0.2154
# Estimator 60/2000, Train metric: 0.2168, Validation metric: 0.2154
# Estimator 61/2000, Train metric: 0.2168, Validation metric: 0.2154
# Estimator 62/2000, Train metric: 0.2168, Validation metric: 0.2154
# Estimator 63/2000, Train metric: 0.2168, Validation metric: 0.2154
# Estimator 64/2000, Train metric: 0.2167, Validation metric: 0.2154
# Estimator 65/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 66/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 67/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 68/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 69/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 70/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 71/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 72/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 73/2000, Train metric: 0.2167, Validation metric: 0.2153
# Estimator 74/2000, Train metric: 0.2167, Validation metric: 0.2152
# Estimator 75/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 76/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 77/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 78/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 79/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 80/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 81/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 82/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 83/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 84/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 85/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 86/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 87/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 88/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 89/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 90/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 91/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 92/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 93/2000, Train metric: 0.2166, Validation metric: 0.2152
# Estimator 94/2000, Train metric: 0.2166, Validation metric: 0.2151
# Estimator 95/2000, Train metric: 0.2166, Validation metric: 0.2151
# Estimator 96/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 97/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 98/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 99/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 100/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 101/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 102/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator 103/2000, Train metric: 0.2165, Validation metric: 0.2151
# Estimator