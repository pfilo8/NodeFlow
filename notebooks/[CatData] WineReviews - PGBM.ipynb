# %%
import catboost
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pgbm_nb
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split

from src.probabilistic_flow_boosting.pipelines.modeling.utils import setup_random_seed

RANDOM_SEED = 1

setup_random_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/01_raw/CatData/wine_reviews/winemag-data_first150k.csv', index_col=0)
df['country'] = df['country'].fillna('')
df['province'] = df['province'].fillna('')
df = df.dropna(subset = ['price'])

# %%
x = df.drop(columns = ['description', 'price', 'designation', 'region_1', 'region_2', 'winery'])
x = pd.get_dummies(x)
y = df[['price']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=RANDOM_SEED)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=RANDOM_SEED)

# %%
x_train.shape, x_test.shape
# Out:
# ((109788, 1114), (27447, 1114))

# %%
def mseloss_objective(yhat, y, sample_weight=None):
    gradient = (yhat - y)
    hessian = np.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    loss = np.sqrt(np.mean(np.square(yhat - y)))
    return loss

# %%
model = pgbm_nb.PGBM()

params = {
    'min_split_gain':0,
    'min_data_in_leaf':2,
    'max_leaves':8,
    'max_bin':64,
    'learning_rate':0.1,
    'verbose':2,
    'early_stopping_rounds':200,
    'feature_fraction':1,
    'bagging_fraction':1,
    'seed':RANDOM_SEED,
    'reg_lambda':1,
    'device':'gpu',
    'gpu_device_id':0,
    'derivatives':'exact',
    'distribution':'normal',
    'n_estimators': 2000
}

# %%
model.train(
    train_set=(x_train.values, y_train.values), 
    objective=mseloss_objective, 
    metric=rmseloss_metric, 
    valid_set=(x_val.values, y_val.values),
    params=params
)
# Out:
# Estimator 0/2000, Train metric: 35.5933, Validation metric: 35.8299
# Estimator 1/2000, Train metric: 34.6437, Validation metric: 34.8117
# Estimator 2/2000, Train metric: 33.8359, Validation metric: 34.0112
# Estimator 3/2000, Train metric: 33.1471, Validation metric: 33.3208
# Estimator 4/2000, Train metric: 32.4774, Validation metric: 32.7104
# Estimator 5/2000, Train metric: 31.9447, Validation metric: 32.1193
# Estimator 6/2000, Train metric: 31.5099, Validation metric: 31.6324
# Estimator 7/2000, Train metric: 31.1139, Validation metric: 31.2217
# Estimator 8/2000, Train metric: 30.7894, Validation metric: 30.8906
# Estimator 9/2000, Train metric: 30.4739, Validation metric: 30.6510
# Estimator 10/2000, Train metric: 30.1860, Validation metric: 30.4219
# Estimator 11/2000, Train metric: 29.9003, Validation metric: 29.9455
# Estimator 12/2000, Train metric: 29.7013, Validation metric: 29.7166
# Estimator 13/2000, Train metric: 29.4922, Validation metric: 29.4775
# Estimator 14/2000, Train metric: 29.3376, Validation metric: 29.3186
# Estimator 15/2000, Train metric: 29.1580, Validation metric: 28.9716
# Estimator 16/2000, Train metric: 28.9948, Validation metric: 28.6751
# Estimator 17/2000, Train metric: 28.8442, Validation metric: 28.5815
# Estimator 18/2000, Train metric: 28.7340, Validation metric: 28.4126
# Estimator 19/2000, Train metric: 28.6392, Validation metric: 28.3293
# Estimator 20/2000, Train metric: 28.5157, Validation metric: 28.2565
# Estimator 21/2000, Train metric: 28.4281, Validation metric: 28.1617
# Estimator 22/2000, Train metric: 28.3060, Validation metric: 27.9530
# Estimator 23/2000, Train metric: 28.2134, Validation metric: 27.8944
# Estimator 24/2000, Train metric: 28.1129, Validation metric: 27.7043
# Estimator 25/2000, Train metric: 28.0416, Validation metric: 27.6616
# Estimator 26/2000, Train metric: 27.9323, Validation metric: 27.4783
# Estimator 27/2000, Train metric: 27.8663, Validation metric: 27.3933
# Estimator 28/2000, Train metric: 27.8010, Validation metric: 27.2430
# Estimator 29/2000, Train metric: 27.7362, Validation metric: 27.0817
# Estimator 30/2000, Train metric: 27.6861, Validation metric: 27.0163
# Estimator 31/2000, Train metric: 27.6344, Validation metric: 26.8566
# Estimator 32/2000, Train metric: 27.5919, Validation metric: 26.8245
# Estimator 33/2000, Train metric: 27.5476, Validation metric: 26.7161
# Estimator 34/2000, Train metric: 27.5030, Validation metric: 26.6365
# Estimator 35/2000, Train metric: 27.4673, Validation metric: 26.6096
# Estimator 36/2000, Train metric: 27.4242, Validation metric: 26.5326
# Estimator 37/2000, Train metric: 27.3801, Validation metric: 26.4219
# Estimator 38/2000, Train metric: 27.3591, Validation metric: 26.4014
# Estimator 39/2000, Train metric: 27.3250, Validation metric: 26.3563
# Estimator 40/2000, Train metric: 27.3019, Validation metric: 26.2707
# Estimator 41/2000, Train metric: 27.2883, Validation metric: 26.2569
# Estimator 42/2000, Train metric: 27.2591, Validation metric: 26.2298
# Estimator 43/2000, Train metric: 27.2266, Validation metric: 26.1944
# Estimator 44/2000, Train metric: 27.2009, Validation metric: 26.1732
# Estimator 45/2000, Train metric: 27.1853, Validation metric: 26.1585
# Estimator 46/2000, Train metric: 27.1681, Validation metric: 26.1381
# Estimator 47/2000, Train metric: 27.1422, Validation metric: 26.1155
# Estimator 48/2000, Train metric: 27.1298, Validation metric: 26.0949
# Estimator 49/2000, Train metric: 27.1071, Validation metric: 26.0766
# Estimator 50/2000, Train metric: 27.0869, Validation metric: 26.0638
# Estimator 51/2000, Train metric: 27.0767, Validation metric: 26.0539
# Estimator 52/2000, Train metric: 27.0637, Validation metric: 26.0366
# Estimator 53/2000, Train metric: 27.0217, Validation metric: 25.9401
# Estimator 54/2000, Train metric: 27.0094, Validation metric: 25.9314
# Estimator 55/2000, Train metric: 26.9906, Validation metric: 25.9164
# Estimator 56/2000, Train metric: 26.9761, Validation metric: 25.8946
# Estimator 57/2000, Train metric: 26.9572, Validation metric: 25.8820
# Estimator 58/2000, Train metric: 26.9490, Validation metric: 25.8741
# Estimator 59/2000, Train metric: 26.9395, Validation metric: 25.8684
# Estimator 60/2000, Train metric: 26.9325, Validation metric: 25.8612
# Estimator 61/2000, Train metric: 26.9212, Validation metric: 25.8525
# Estimator 62/2000, Train metric: 26.9029, Validation metric: 25.8266
# Estimator 63/2000, Train metric: 26.8842, Validation metric: 25.8029
# Estimator 64/2000, Train metric: 26.8684, Validation metric: 25.7925
# Estimator 65/2000, Train metric: 26.8618, Validation metric: 25.7858
# Estimator 66/2000, Train metric: 26.8495, Validation metric: 25.7590
# Estimator 67/2000, Train metric: 26.8398, Validation metric: 25.7551
# Estimator 68/2000, Train metric: 26.8265, Validation metric: 25.7451
# Estimator 69/2000, Train metric: 26.8196, Validation metric: 25.7376
# Estimator 70/2000, Train metric: 26.8140, Validation metric: 25.7314
# Estimator 71/2000, Train metric: 26.7996, Validation metric: 25.7172
# Estimator 72/2000, Train metric: 26.7909, Validation metric: 25.7076
# Estimator 73/2000, Train metric: 26.7794, Validation metric: 25.6752
# Estimator 74/2000, Train metric: 26.7743, Validation metric: 25.6702
# Estimator 75/2000, Train metric: 26.7631, Validation metric: 25.6626
# Estimator 76/2000, Train metric: 26.7520, Validation metric: 25.6543
# Estimator 77/2000, Train metric: 26.7448, Validation metric: 25.6516
# Estimator 78/2000, Train metric: 26.7357, Validation metric: 25.6411
# Estimator 79/2000, Train metric: 26.7298, Validation metric: 25.6348
# Estimator 80/2000, Train metric: 26.7232, Validation metric: 25.6295
# Estimator 81/2000, Train metric: 26.7178, Validation metric: 25.6242
# Estimator 82/2000, Train metric: 26.7114, Validation metric: 25.6183
# Estimator 83/2000, Train metric: 26.7052, Validation metric: 25.6141
# Estimator 84/2000, Train metric: 26.6876, Validation metric: 25.5727
# Estimator 85/2000, Train metric: 26.6782, Validation metric: 25.5574
# Estimator 86/2000, Train metric: 26.6740, Validation metric: 25.5528
# Estimator 87/2000, Train metric: 26.6685, Validation metric: 25.5492
# Estimator 88/2000, Train metric: 26.6547, Validation metric: 25.5413
# Estimator 89/2000, Train metric: 26.6483, Validation metric: 25.5390
# Estimator 90/2000, Train metric: 26.6438, Validation metric: 25.5348
# Estimator 91/2000, Train metric: 26.6397, Validation metric: 25.5300
# Estimator 92/2000, Train metric: 26.6339, Validation metric: 25.5208
# Estimator 93/2000, Train metric: 26.6212, Validation metric: 25.4602
# Estimator 94/2000, Train metric: 26.6109, Validation metric: 25.4452
# Estimator 95/2000, Train metric: 26.6066, Validation metric: 25.4397
# Estimator 96/2000, Train metric: 26.5946, Validation metric: 25.4224
# Estimator 97/2000, Train metric: 26.5905, Validation metric: 25.4215
# Estimator 98/2000, Train metric: 26.5842, Validation metric: 25.4163
# Estimator 99/2000, Train metric: 26.5708, Validation metric: 25.4002
# Estimator 100/2000, Train metric: 26.5520, Validation metric: 25.3689
# Estimator 101/2000, Train metric: 26.5432, Validation metric: 25.3604
# Estimator 102/2000, Train metric: 26.5387, Validation metric: 25.3561
# Estimator 103/2000, Train metric: 26.5229, Validation metric: 25.3427
# Estimator 104/2000, Train metric: 26.5160, Validation metric: 25.3406
# Estimator 105/2000, Train metric: 26.5123, Validation metric: 25.3363
# Estimator 106/2000, Train metric: 26.5057, Validation metric: 25.3272
# Estimator 107/2000, Train metric: 26.5019, Validation metric: 25.3226
# Estimator 108/2000, Train metric: 26.4979, Validation metric: 25.3198
# Estimator 109/2000, Train metric: 26.4945, Validation metric: 25.3154
# Estimator 110/2000, Train metric: 26.4876, Validation metric: 25.3071
# Estimator 111/2000, Train metric: 26.4847, Validation metric: 25.3039
# Estimator 112/2000, Train metric: 26.4787, Validation metric: 25.2987
# Estimator 113/2000, Train metric: 26.4737, Validation metric: 25.2941
# Estimator 114/2000, Train metric: 26.4581, Validation metric: 25.2740
# Estimator 115/2000, Train metric: 26.4555, Validation metric: 25.2713
# Estimator 116/2000, Train metric: 26.4510, Validation metric: 25.2698
# Estimator 117/2000, Train metric: 26.4451, Validation metric: 25.2628
# Estimator 118/2000, Train metric: 26.4385, Validation metric: 25.2551
# Estimator 119/2000, Train metric: 26.4302, Validation metric: 25.2494
# Estimator 120/2000, Train metric: 26.4276, Validation metric: 25.2467
# Estimator 121/2000, Train metric: 26.4232, Validation metric: 25.2429
# Estimator 122/2000, Train metric: 26.4200, Validation metric: 25.2400
# Estimator 123/2000, Train metric: 26.4155, Validation metric: 25.2366
# Estimator 124/2000, Train metric: 26.4122, Validation metric: 25.2332
# Estimator 125/2000, Train metric: 26.4100, Validation metric: 25.2315
# Estimator 126/2000, Train metric: 26.4078, Validation metric: 25.2290
# Estimator 127/2000, Train metric: 26.4037, Validation metric: 25.2255
# Estimator 128/2000, Train metric: 26.4012, Validation metric: 25.2224
# Estimator 129/2000, Train metric: 26.3932, Validation metric: 25.2140
# Estimator 130/2000, Train metric: 26.3832, Validation metric: 25.2046
# Estimator 131/2000, Train metric: 26.3743, Validation metric: 25.1984
# Estimator 132/2000, Train metric: 26.3695, Validation metric: 25.1971
# Estimator 133/2000, Train metric: 26.3667, Validation metric: 25.1945
# Estimator 134/2000, Train metric: 26.3563, Validation metric: 25.1713
# Estimator 135/2000, Train metric: 26.3441, Validation metric: 25.1567
# Estimator 136/2000, Train metric: 26.3415, Validation metric: 25.1534
# Estimator 137/2000, Train metric: 26.3393, Validation metric: 25.1517
# Estimator 138/2000, Train metric: 26.3376, Validation metric: 25.1498
# Estimator 139/2000, Train metric: 26.3350, Validation metric: 25.1481
# Estimator 140/2000, Train metric: 26.3288, Validation metric: 25.1424
# Estimator 141/2000, Train metric: 26.3251, Validation metric: 25.1386
# Estimator 142/2000, Train metric: 26.3231, Validation metric: 25.1364
# Estimator 143/2000, Train metric: 26.3210, Validation metric: 25.1342
# Estimator 144/2000, Train metric: 26.3187, Validation metric: 25.1337
# Estimator 145/2000, Train metric: 26.3164, Validation metric: 25.1311
# Estimator 146/2000, Train metric: 26.3129, Validation metric: 25.1269
# Estimator 147/2000, Train metric: 26.3092, Validation metric: 25.1244
# Estimator 148/2000, Train metric: 26.3060, Validation metric: 25.1217
# Estimator 149/2000, Train metric: 26.3036, Validation metric: 25.1191
# Estimator 150/2000, Train metric: 26.3006, Validation metric: 25.1168
# Estimator 151/2000, Train metric: 26.2989, Validation metric: 25.1151
# Estimator 152/2000, Train metric: 26.2835, Validation metric: 25.0876
# Estimator 153/2000, Train metric: 26.2819, Validation metric: 25.0865
# Estimator 154/2000, Train metric: 26.2797, Validation metric: 25.0856
# Estimator 155/2000, Train metric: 26.2779, Validation metric: 25.0839
# Estimator 156/2000, Train metric: 26.2753, Validation metric: 25.0807
# Estimator 157/2000, Train metric: 26.2724, Validation metric: 25.0776
# Estimator 158/2000, Train metric: 26.2703, Validation metric: 25.0757
# Estimator 159/2000, Train metric: 26.2683, Validation metric: 25.0742
# Estimator 160/2000, Train metric: 26.2631, Validation metric: 25.0618
# Estimator 161/2000, Train metric: 26.2613, Validation metric: 25.0601
# Estimator 162/2000, Train metric: 26.2594, Validation metric: 25.0585
# Estimator 163/2000, Train metric: 26.2579, Validation metric: 25.0575
# Estimator 164/2000, Train metric: 26.2551, Validation metric: 25.0562
# Estimator 165/2000, Train metric: 26.2536, Validation metric: 25.0545
# Estimator 166/2000, Train metric: 26.2492, Validation metric: 25.0507
# Estimator 167/2000, Train metric: 26.2422, Validation metric: 25.0424
# Estimator 168/2000, Train metric: 26.2358, Validation metric: 25.0371
# Estimator 169/2000, Train metric: 26.2303, Validation metric: 25.0296
# Estimator 170/2000, Train metric: 26.2268, Validation metric: 25.0256
# Estimator 171/2000, Train metric: 26.2237, Validation metric: 25.0246
# Estimator 172/2000, Train metric: 26.2212, Validation metric: 25.0243
# Estimator 173/2000, Train metric: 26.2199, Validation metric: 25.0232
# Estimator 174/2000, Train metric: 26.2172, Validation metric: 25.0197
# Estimator 175/2000, Train metric: 26.2156, Validation metric: 25.0181
# Estimator 176/2000, Train metric: 26.2139, Validation metric: 25.0171
# Estimator 177/2000, Train metric: 26.2126, Validation metric: 25.0155
# Estimator 178/2000, Train metric: 26.2099, Validation metric: 25.0122
# Estimator 179/2000, Train metric: 26.2075, Validation metric: 25.0094
# Estimator 180/2000, Train metric: 26.2061, Validation metric: 25.0077
# Estimator 181/2000, Train metric: 26.2031, Validation metric: 25.0043
# Estimator 182/2000, Train metric: 26.2010, Validation metric: 25.0021
# Estimator 183/2000, Train metric: 26.1984, Validation metric: 25.0006
# Estimator 184/2000, Train metric: 26.1966, Validation metric: 24.9973
# Estimator 185/2000, Train metric: 26.1921, Validation metric: 24.9933
# Estimator 186/2000, Train metric: 26.1905, Validation metric: 24.9923
# Estimator 187/2000, Train metric: 26.1878, Validation metric: 24.9902
# Estimator 188/2000, Train metric: 26.1850, Validation metric: 24.9891
# Estimator 189/2000, Train metric: 26.1837, Validation metric: 24.9878
# Estimator 190/2000, Train metric: 26.1795, Validation metric: 24.9870
# Estimator 191/2000, Train metric: 26.1784, Validation metric: 24.9860
# Estimator 192/2000, Train metric: 26.1764, Validation metric: 24.9830
# Estimator 193/2000, Train metric: 26.1747, Validation metric: 24.9801
# Estimator 194/2000, Train metric: 26.1736, Validation metric: 24.9793
# Estimator 195/2000, Train metric: 26.1715, Validation metric: 24.9789
# Estimator 196/2000, Train metric: 26.1702, Validation metric: 24.9778
# Estimator 197/2000, Train metric: 26.1681, Validation metric: 24.9765
# Estimator 198/2000, Train metric: 26.1614, Validation metric: 24.9564
# Estimator 199/2000, Train metric: 26.1596, Validation metric: 24.9538
# Estimator 200/2000, Train metric: 26.1559, Validation metric: 24.9486
# Estimator 201/2000, Train metric: 26.1531, Validation metric: 24.9459
# Estimator 202/2000, Train metric: 26.1513, Validation metric: 24.9436
# Estimator 203/2000, Train metric: 26.1498, Validation metric: 24.9420
# Estimator 204/2000, Train metric: 26.1484, Validation metric: 24.9404
# Estimator 205/2000, Train metric: 26.1465, Validation metric: 24.9388
# Estimator 206/2000, Train metric: 26.1449, Validation metric: 24.9369
# Estimator 207/2000, Train metric: 26.1399, Validation metric: 24.9367
# Estimator 208/2000, Train metric: 26.1360, Validation metric: 24.9261
# Estimator 209/2000, Train metric: 26.1347, Validation metric: 24.9246
# Estimator 210/2000, Train metric: 26.1334, Validation metric: 24.9244
# Estimator 211/2000, Train metric: 26.1321, Validation metric: 24.9232
# Estimator 212/2000, Train metric: 26.1311, Validation metric: 24.9224
# Estimator 213/2000, Train metric: 26.1293, Validation metric: 24.9195
# Estimator 214/2000, Train metric: 26.1249, Validation metric: 24.9170
# Estimator 215/2000, Train metric: 26.1235, Validation metric: 24.9153
# Estimator 216/2000, Train metric: 26.1218, Validation metric: 24.9135
# Estimator 217/2000, Train metric: 26.1186, Validation metric: 24.9123
# Estimator 218/2000, Train metric: 26.1121, Validation metric: 24.8989
# Estimator 219/2000, Train metric: 26.1107, Validation metric: 24.8972
# Estimator 220/2000, Train metric: 26.1098, Validation metric: 24.8961
# Estimator 221/2000, Train metric: 26.1082, Validation metric: 24.8948
# Estimator 222/2000, Train metric: 26.1071, Validation metric: 24.8932
# Estimator 223/2000, Train metric: 26.1055, Validation metric: 24.8911
# Estimator 224/2000, Train metric: 26.1026, Validation metric: 24.8900
# Estimator 225/2000, Train metric: 26.0994, Validation metric: 24.8870
# Estimator 226/2000, Train metric: 26.0974, Validation metric: 24.8858
# Estimator 227/2000, Train metric: 26.0963, Validation metric: 24.8848
# Estimator 228/2000, Train metric: 26.0944, Validation metric: 24.8833
# Estimator 229/2000, Train metric: 26.0924, Validation metric: 24.8825
# Estimator 230/2000, Train metric: 26.0891, Validation metric: 24.8822
# Estimator 231/2000, Train metric: 26.0880, Validation metric: 24.8809
# Estimator 232/2000, Train metric: 26.0871, Validation metric: 24.8798
# Estimator 233/2000, Train metric: 26.0858, Validation metric: 24.8792
# Estimator 234/2000, Train metric: 26.0845, Validation metric: 24.8780
# Estimator 235/2000, Train metric: 26.0830, Validation metric: 24.8766
# Estimator 236/2000, Train metric: 26.0817, Validation metric: 24.8751
# Estimator 237/2000, Train metric: 26.0731, Validation metric: 24.8650
# Estimator 238/2000, Train metric: 26.0682, Validation metric: 24.8613
# Estimator 239/2000, Train metric: 26.0613, Validation metric: 24.8502
# Estimator 240/2000, Train metric: 26.0599, Validation metric: 24.8486
# Estimator 241/2000, Train metric: 26.0586, Validation metric: 24.8479
# Estimator 242/2000, Train metric: 26.0567, Validation metric: 24.8473
# Estimator 243/2000, Train metric: 26.0559, Validation metric: 24.8467
# Estimator 244/2000, Train metric: 26.0543, Validation metric: 24.8454
# Estimator 245/2000, Train metric: 26.0423, Validation metric: 24.8336
# Estimator 246/2000, Train metric: 26.0412, Validation metric: 24.8318
# Estimator 247/2000, Train metric: 26.0403, Validation metric: 24.8312
# Estimator 248/2000, Train metric: 26.0387, Validation metric: 24.8284
# Estimator 249/2000, Train metric: 26.0377, Validation metric: 24.8274
# Estimator 250/2000, Train metric: 26.0367, Validation metric: 24.8264
# Estimator 251/2000, Train metric: 26.0357, Validation metric: 24.8251
# Estimator 252/2000, Train metric: 26.0344, Validation metric: 24.8231
# Estimator 253/2000, Train metric: 26.0334, Validation metric: 24.8223
# Estimator 254/2000, Train metric: 26.0325, Validation metric: 24.8217
# Estimator 255/2000, Train metric: 26.0298, Validation metric: 24.8211
# Estimator 256/2000, Train metric: 26.0290, Validation metric: 24.8203
# Estimator 257/2000, Train metric: 26.0271, Validation metric: 24.8182
# Estimator 258/2000, Train metric: 26.0259, Validation metric: 24.8165
# Estimator 259/2000, Train metric: 26.0203, Validation metric: 24.8082
# Estimator 260/2000, Train metric: 26.0164, Validation metric: 24.8016
# Estimator 261/2000, Train metric: 26.0119, Validation metric: 24.7963
# Estimator 262/2000, Train metric: 26.0111, Validation metric: 24.7958
# Estimator 263/2000, Train metric: 26.0087, Validation metric: 24.7950
# Estimator 264/2000, Train metric: 26.0079, Validation metric: 24.7942
# Estimator 265/2000, Train metric: 26.0058, Validation metric: 24.7937
# Estimator 266/2000, Train metric: 26.0050, Validation metric: 24.7930
# Estimator 267/2000, Train metric: 26.0037, Validation metric: 24.7929
# Estimator 268/2000, Train metric: 26.0023, Validation metric: 24.7918
# Estimator 269/2000, Train metric: 26.0016, Validation metric: 24.7911
# Estimator 270/2000, Train metric: 26.0007, Validation metric: 24.7895
# Estimator 271/2000, Train metric: 25.9972, Validation metric: 24.7859
# Estimator 272/2000, Train metric: 25.9947, Validation metric: 24.7838
# Estimator 273/2000, Train metric: 25.9934, Validation metric: 24.7819
# Estimator 274/2000, Train metric: 25.9925, Validation metric: 24.7811
# Estimator 275/2000, Train metric: 25.9918, Validation metric: 24.7808
# Estimator 276/2000, Train metric: 25.9906, Validation metric: 24.7794
# Estimator 277/2000, Train metric: 25.9889, Validation metric: 24.7770
# Estimator 278/2000, Train metric: 25.9866, Validation metric: 24.7765
# Estimator 279/2000, Train metric: 25.9793, Validation metric: 24.7614
# Estimator 280/2000, Train metric: 25.9783, Validation metric: 24.7600
# Estimator 281/2000, Train metric: 25.9772, Validation metric: 24.7593
# Estimator 282/2000, Train metric: 25.9727, Validation metric: 24.7561
# Estimator 283/2000, Train metric: 25.9720, Validation metric: 24.7555
# Estimator 284/2000, Train metric: 25.9709, Validation metric: 24.7546
# Estimator 285/2000, Train metric: 25.9658, Validation metric: 24.7339
# Estimator 286/2000, Train metric: 25.9649, Validation metric: 24.7331
# Estimator 287/2000, Train metric: 25.9641, Validation metric: 24.7322
# Estimator 288/2000, Train metric: 25.9624, Validation metric: 24.7292
# Estimator 289/2000, Train metric: 25.9609, Validation metric: 24.7276
# Estimator 290/2000, Train metric: 25.9601, Validation metric: 24.7265
# Estimator 291/2000, Train metric: 25.9594, Validation metric: 24.7260
# Estimator 292/2000, Train metric: 25.9586, Validation metric: 24.7251
# Estimator 293/2000, Train metric: 25.9578, Validation metric: 24.7240
# Estimator 294/2000, Train metric: 25.9564, Validation metric: 24.7234
# Estimator 295/2000, Train metric: 25.9558, Validation metric: 24.7226
# Estimator 296/2000, Train metric: 25.9544, Validation metric: 24.7218
# Estimator 297/2000, Train metric: 25.9513, Validation metric: 24.7214
# Estimator 298/2000, Train metric: 25.9499, Validation metric: 24.7199
# Estimator 299/2000, Train metric: 25.9352, Validation metric: 24.6554
# Estimator 300/2000, Train metric: 25.9341, Validation metric: 24.6545
# Estimator 301/2000, Train metric: 25.9321, Validation metric: 24.6534
# Estimator 302/2000, Train metric: 25.9312, Validation metric: 24.6524
# Estimator 303/2000, Train metric: 25.9302, Validation metric: 24.6511
# Estimator 304/2000, Train metric: 25.9292, Validation metric: 24.6507
# Estimator 305/2000, Train metric: 25.9284, Validation metric: 24.6495
# Estimator 306/2000, Train metric: 25.9261, Validation metric: 24.6473
# Estimator 307/2000, Train metric: 25.9248, Validation metric: 24.6474
# Estimator 308/2000, Train metric: 25.9228, Validation metric: 24.6469
# Estimator 309/2000, Train metric: 25.9182, Validation metric: 24.6290
# Estimator 310/2000, Train metric: 25.9172, Validation metric: 24.6277
# Estimator 311/2000, Train metric: 25.9162, Validation metric: 24.6267
# Estimator 312/2000, Train metric: 25.9148, Validation metric: 24.6245
# Estimator 313/2000, Train metric: 25.9141, Validation metric: 24.6239
# Estimator 314/2000, Train metric: 25.9133, Validation metric: 24.6231
# Estimator 315/2000, Train metric: 25.9122, Validation metric: 24.6213
# Estimator 316/2000, Train metric: 25.9082, Validation metric: 24.6144
# Estimator 317/2000, Train metric: 25.9059, Validation metric: 24.6134
# Estimator 318/2000, Train metric: 25.9050, Validation metric: 24.6121
# Estimator 319/2000, Train metric: 25.9043, Validation metric: 24.6116
# Estimator 320/2000, Train metric: 25.9032, Validation metric: 24.6100
# Estimator 321/2000, Train metric: 25.9026, Validation metric: 24.6097
# Estimator 322/2000, Train metric: 25.9017, Validation metric: 24.6083
# Estimator 323/2000, Train metric: 25.8991, Validation metric: 24.6076
# Estimator 324/2000, Train metric: 25.8886, Validation metric: 24.5980
# Estimator 325/2000, Train metric: 25.8881, Validation metric: 24.5974
# Estimator 326/2000, Train metric: 25.8876, Validation metric: 24.5969
# Estimator 327/2000, Train metric: 25.8871, Validation metric: 24.5964
# Estimator 328/2000, Train metric: 25.8863, Validation metric: 24.5957
# Estimator 329/2000, Train metric: 25.8857, Validation metric: 24.5952
# Estimator 330/2000, Train metric: 25.8841, Validation metric: 24.5943
# Estimator 331/2000, Train metric: 25.8836, Validation metric: 24.5937
# Estimator 332/2000, Train metric: 25.8829, Validation metric: 24.5930
# Estimator 333/2000, Train metric: 25.8823, Validation metric: 24.5924
# Estimator 334/2000, Train metric: 25.8813, Validation metric: 24.5911
# Estimator 335/2000, Train metric: 25.8789, Validation metric: 24.5899
# Estimator 336/2000, Train metric: 25.8724, Validation metric: 24.5847
# Estimator 337/2000, Train metric: 25.8697, Validation metric: 24.5829
# Estimator 338/2000, Train metric: 25.8661, Validation metric: 24.5748
# Estimator 339/2000, Train metric: 25.8652, Validation metric: 24.5741
# Estimator 340/2000, Train metric: 25.8627, Validation metric: 24.5715
# Estimator 341/2000, Train metric: 25.8619, Validation metric: 24.5710
# Estimator 342/2000, Train metric: 25.8611, Validation metric: 24.5696
# Estimator 343/2000, Train metric: 25.8602, Validation metric: 24.5687
# Estimator 344/2000, Train metric: 25.8585, Validation metric: 24.5681
# Estimator 345/2000, Train metric: 25.8562, Validation metric: 24.5668
# Estimator 346/2000, Train metric: 25.8550, Validation metric: 24.5663
# Estimator 347/2000, Train metric: 25.8540, Validation metric: 24.5645
# Estimator 348/2000, Train metric: 25.8513, Validation metric: 24.5622
# Estimator 349/2000, Train metric: 25.8501, Validation metric: 24.5610
# Estimator 350/2000, Train metric: 25.8492, Validation metric: 24.5598
# Estimator 351/2000, Train metric: 25.8486, Validation metric: 24.5592
# Estimator 352/2000, Train metric: 25.8480, Validation metric: 24.5587
# Estimator 353/2000, Train metric: 25.8475, Validation metric: 24.5581
# Estimator 354/2000, Train metric: 25.8469, Validation metric: 24.5579
# Estimator 355/2000, Train metric: 25.8463, Validation metric: 24.5575
# Estimator 356/2000, Train metric: 25.8459, Validation metric: 24.5569
# Estimator 357/2000, Train metric: 25.8453, Validation metric: 24.5564
# Estimator 358/2000, Train metric: 25.8443, Validation metric: 24.5554
# Estimator 359/2000, Train metric: 25.8429, Validation metric: 24.5539
# Estimator 360/2000, Train metric: 25.8390, Validation metric: 24.5475
# Estimator 361/2000, Train metric: 25.8385, Validation metric: 24.5471
# Estimator 362/2000, Train metric: 25.8378, Validation metric: 24.5464
# Estimator 363/2000, Train metric: 25.8368, Validation metric: 24.5462
# Estimator 364/2000, Train metric: 25.8362, Validation metric: 24.5458
# Estimator 365/2000, Train metric: 25.8357, Validation metric: 24.5453
# Estimator 366/2000, Train metric: 25.8352, Validation metric: 24.5450
# Estimator 367/2000, Train metric: 25.8346, Validation metric: 24.5439
# Estimator 368/2000, Train metric: 25.8337, Validation metric: 24.5428
# Estimator 369/2000, Train metric: 25.8331, Validation metric: 24.5419
# Estimator 370/2000, Train metric: 25.8326, Validation metric: 24.5413
# Estimator 371/2000, Train metric: 25.8313, Validation metric: 24.5402
# Estimator 372/2000, Train metric: 25.8293, Validation metric: 24.5380
# Estimator 373/2000, Train metric: 25.8265, Validation metric: 24.5299
# Estimator 374/2000, Train metric: 25.8261, Validation metric: 24.5295
# Estimator 375/2000, Train metric: 25.8257, Validation metric: 24.5290
# Estimator 376/2000, Train metric: 25.8243, Validation metric: 24.5290
# Estimator 377/2000, Train metric: 25.8097, Validation metric: 24.5030
# Estimator 378/2000, Train metric: 25.8075, Validation metric: 24.5010
# Estimator 379/2000, Train metric: 25.8059, Validation metric: 24.4991
# Estimator 380/2000, Train metric: 25.8052, Validation metric: 24.4983
# Estimator 381/2000, Train metric: 25.8046, Validation metric: 24.4978
# Estimator 382/2000, Train metric: 25.8031, Validation metric: 24.4974
# Estimator 383/2000, Train metric: 25.8003, Validation metric: 24.4952
# Estimator 384/2000, Train metric: 25.7990, Validation metric: 24.4933
# Estimator 385/2000, Train metric: 25.7984, Validation metric: 24.4925
# Estimator 386/2000, Train metric: 25.7976, Validation metric: 24.4913
# Estimator 387/2000, Train metric: 25.7962, Validation metric: 24.4907
# Estimator 388/2000, Train metric: 25.7955, Validation metric: 24.4901
# Estimator 389/2000, Train metric: 25.7949, Validation metric: 24.4897
# Estimator 390/2000, Train metric: 25.7942, Validation metric: 24.4888
# Estimator 391/2000, Train metric: 25.7829, Validation metric: 24.4751
# Estimator 392/2000, Train metric: 25.7684, Validation metric: 24.4392
# Estimator 393/2000, Train metric: 25.7681, Validation metric: 24.4388
# Estimator 394/2000, Train metric: 25.7675, Validation metric: 24.4382
# Estimator 395/2000, Train metric: 25.7670, Validation metric: 24.4380
# Estimator 396/2000, Train metric: 25.7663, Validation metric: 24.4376
# Estimator 397/2000, Train metric: 25.7648, Validation metric: 24.4352
# Estimator 398/2000, Train metric: 25.7643, Validation metric: 24.4347
# Estimator 399/2000, Train metric: 25.7639, Validation metric: 24.4343
# Estimator 400/2000, Train metric: 25.7632, Validation metric: 24.4339
# Estimator 401/2000, Train metric: 25.7626, Validation metric: 24.4331
# Estimator 402/2000, Train metric: 25.7501, Validation metric: 24.3807
# Estimator 403/2000, Train metric: 25.7495, Validation metric: 24.3801
# Estimator 404/2000, Train metric: 25.7486, Validation metric: 24.3786
# Estimator 405/2000, Train metric: 25.7474, Validation metric: 24.3762
# Estimator 406/2000, Train metric: 25.7468, Validation metric: 24.3757
# Estimator 407/2000, Train metric: 25.7461, Validation metric: 24.3747
# Estimator 408/2000, Train metric: 25.7453, Validation metric: 24.3737
# Estimator 409/2000, Train metric: 25.7446, Validation metric: 24.3730
# Estimator 410/2000, Train metric: 25.7443, Validation metric: 24.3727
# Estimator 411/2000, Train metric: 25.7437, Validation metric: 24.3721
# Estimator 412/2000, Train metric: 25.7406, Validation metric: 24.3693
# Estimator 413/2000, Train metric: 25.7370, Validation metric: 24.3656
# Estimator 414/2000, Train metric: 25.7367, Validation metric: 24.3652
# Estimator 415/2000, Train metric: 25.7363, Validation metric: 24.3649
# Estimator 416/2000, Train metric: 25.7358, Validation metric: 24.3645
# Estimator 417/2000, Train metric: 25.7353, Validation metric: 24.3640
# Estimator 418/2000, Train metric: 25.7349, Validation metric: 24.3637
# Estimator 419/2000, Train metric: 25.7346, Validation metric: 24.3632
# Estimator 420/2000, Train metric: 25.7331, Validation metric: 24.3619
# Estimator 421/2000, Train metric: 25.7324, Validation metric: 24.3610
# Estimator 422/2000, Train metric: 25.7320, Validation metric: 24.3604
# Estimator 423/2000, Train metric: 25.7317, Validation metric: 24.3602
# Estimator 424/2000, Train metric: 25.7305, Validation metric: 24.3603
# Estimator 425/2000, Train metric: 25.7296, Validation metric: 24.3600
# Estimator 426/2000, Train metric: 25.7290, Validation metric: 24.3595
# Estimator 427/2000, Train metric: 25.7285, Validation metric: 24.3590
# Estimator 428/2000, Train metric: 25.7280, Validation metric: 24.3586
# Estimator 429/2000, Train metric: 25.7275, Validation metric: 24.3578
# Estimator 430/2000, Train metric: 25.7270, Validation metric: 24.3570
# Estimator 431/2000, Train metric: 25.7265, Validation metric: 24.3563
# Estimator 432/2000, Train metric: 25.7261, Validation metric: 24.3559
# Estimator 433/2000, Train metric: 25.7257, Validation metric: 24.3554
# Estimator 434/2000, Train metric: 25.7170, Validation metric: 24.3475
# Estimator 435/2000, Train metric: 25.7100, Validation metric: 24.3384
# Estimator 436/2000, Train metric: 25.6979, Validation metric: 24.3234
# Estimator 437/2000, Train metric: 25.6884, Validation metric: 24.2781
# Estimator 438/2000, Train metric: 25.6860, Validation metric: 24.2778
# Estimator 439/2000, Train metric: 25.6827, Validation metric: 24.2744
# Estimator 440/2000, Train metric: 25.6808, Validation metric: 24.2733
# Estimator 441/2000, Train metric: 25.6800, Validation metric: 24.2726
# Estimator 442/2000, Train metric: 25.6794, Validation metric: 24.2723
# Estimator 443/2000, Train metric: 25.6789, Validation metric: 24.2718
# Estimator 444/2000, Train metric: 25.6784, Validation metric: 24.2711
# Estimator 445/2000, Train metric: 25.6774, Validation metric: 24.2696
# Estimator 446/2000, Train metric: 25.6771, Validation metric: 24.2696
# Estimator 447/2000, Train metric: 25.6760, Validation metric: 24.2681
# Estimator 448/2000, Train metric: 25.6697, Validation metric: 24.2624
# Estimator 449/2000, Train metric: 25.6686, Validation metric: 24.2612
# Estimator 450/2000, Train metric: 25.6677, Validation metric: 24.2600
# Estimator 451/2000, Train metric: 25.6668, Validation metric: 24.2594
# Estimator 452/2000, Train metric: 25.6663, Validation metric: 24.2589
# Estimator 453/2000, Train metric: 25.6658, Validation metric: 24.2587
# Estimator 454/2000, Train metric: 25.6650, Validation metric: 24.2585
# Estimator 455/2000, Train metric: 25.6646, Validation metric: 24.2582
# Estimator 456/2000, Train metric: 25.6643, Validation metric: 24.2579
# Estimator 457/2000, Train metric: 25.6639, Validation metric: 24.2574
# Estimator 458/2000, Train metric: 25.6636, Validation metric: 24.2570
# Estimator 459/2000, Train metric: 25.6631, Validation metric: 24.2568
# Estimator 460/2000, Train metric: 25.6626, Validation metric: 24.2567
# Estimator 461/2000, Train metric: 25.6613, Validation metric: 24.2548
# Estimator 462/2000, Train metric: 25.6610, Validation metric: 24.2542
# Estimator 463/2000, Train metric: 25.6604, Validation metric: 24.2536
# Estimator 464/2000, Train metric: 25.6599, Validation metric: 24.2532
# Estimator 465/2000, Train metric: 25.6566, Validation metric: 24.2522
# Estimator 466/2000, Train metric: 25.6560, Validation metric: 24.2515
# Estimator 467/2000, Train metric: 25.6535, Validation metric: 24.2480
# Estimator 468/2000, Train metric: 25.6531, Validation metric: 24.2474
# Estimator 469/2000, Train metric: 25.6505, Validation metric: 24.2454
# Estimator 470/2000, Train metric: 25.6501, Validation metric: 24.2449
# Estimator 471/2000, Train metric: 25.6497, Validation metric: 24.2444
# Estimator 472/2000, Train metric: 25.6492, Validation metric: 24.2438
# Estimator 473/2000, Train metric: 25.6488, Validation metric: 24.2434
# Estimator 474/2000, Train metric: 25.6485, Validation metric: 24.2431
# Estimator 475/2000, Train metric: 25.6471, Validation metric: 24.2425
# Estimator 476/2000, Train metric: 25.6466, Validation metric: 24.2424
# Estimator 477/2000, Train metric: 25.6409, Validation metric: 24.2369
# Estimator 478/2000, Train metric: 25.6406, Validation metric: 24.2365
# Estimator 479/2000, Train metric: 25.6394, Validation metric: 24.2361
# Estimator 480/2000, Train metric: 25.6391, Validation metric: 24.2358
# Estimator 481/2000, Train metric: 25.6385, Validation metric: 24.2350
# Estimator 482/2000, Train metric: 25.6382, Validation metric: 24.2348
# Estimator 483/2000, Train metric: 25.6378, Validation metric: 24.2343
# Estimator 484/2000, Train metric: 25.6375, Validation metric: 24.2339
# Estimator 485/2000, Train metric: 25.6364, Validation metric: 24.2336
# Estimator 486/2000, Train metric: 25.6356, Validation metric: 24.2328
# Estimator 487/2000, Train metric: 25.6353, Validation metric: 24.2327
# Estimator 488/2000, Train metric: 25.6349, Validation metric: 24.2322
# Estimator 489/2000, Train metric: 25.6345, Validation metric: 24.2317
# Estimator 490/2000, Train metric: 25.6337, Validation metric: 24.2302
# Estimator 491/2000, Train metric: 25.6330, Validation metric: 24.2297
# Estimator 492/2000, Train metric: 25.6326, Validation metric: 24.2293
# Estimator 493/2000, Train metric: 25.6323, Validation metric: 24.2291
# Estimator 494/2000, Train metric: 25.6319, Validation metric: 24.2287
# Estimator 495/2000, Train metric: 25.6236, Validation metric: 24.2199
# Estimator 496/2000, Train metric: 25.6201, Validation metric: 24.2173
# Estimator 497/2000, Train metric: 25.6198, Validation metric: 24.2171
# Estimator 498/2000, Train metric: 25.6192, Validation metric: 24.2163
# Estimator 499/2000, Train metric: 25.6190, Validation metric: 24.2161
# Estimator 500/2000, Train metric: 25.6186, Validation metric: 24.2157
# Estimator 501/2000, Train metric: 25.6184, Validation metric: 24.2155
# Estimator 502/2000, Train metric: 25.6180, Validation metric: 24.2154
# Estimator 503/2000, Train metric: 25.6177, Validation metric: 24.2151
# Estimator 504/2000, Train metric: 25.6173, Validation metric: 24.2146
# Estimator 505/2000, Train metric: 25.6170, Validation metric: 24.2143
# Estimator 506/2000, Train metric: 25.6165, Validation metric: 24.2137
# Estimator 507/2000, Train metric: 25.6162, Validation metric: 24.2134
# Estimator 508/2000, Train metric: 25.6146, Validation metric: 24.2128
# Estimator 509/2000, Train metric: 25.6140, Validation metric: 24.2119
# Estimator 510/2000, Train metric: 25.6125, Validation metric: 24.2124
# Estimator 511/2000, Train metric: 25.6097, Validation metric: 24.2093
# Estimator 512/2000, Train metric: 25.6085, Validation metric: 24.2078
# Estimator 513/2000, Train metric: 25.6068, Validation metric: 24.2068
# Estimator 514/2000, Train metric: 25.6062, Validation metric: 24.2062
# Estimator 515/2000, Train metric: 25.6030, Validation metric: 24.2005
# Estimator 516/2000, Train metric: 25.6025, Validation metric: 24.1996
# Estimator 517/2000, Train metric: 25.6011, Validation metric: 24.1978
# Estimator 518/2000, Train metric: 25.6007, Validation metric: 24.1973
# Estimator 519/2000, Train metric: 25.5990, Validation metric: 24.1967
# Estimator 520/2000, Train metric: 25.5986, Validation metric: 24.1963
# Estimator 521/2000, Train metric: 25.5983, Validation metric: 24.1960
# Estimator 522/2000, Train metric: 25.5973, Validation metric: 24.1940
# Estimator 523/2000, Train metric: 25.5970, Validation metric: 24.1935
# Estimator 524/2000, Train metric: 25.5967, Validation metric: 24.1932
# Estimator 525/2000, Train metric: 25.5963, Validation metric: 24.1926
# Estimator 526/2000, Train metric: 25.5916, Validation metric: 24.1764
# Estimator 527/2000, Train metric: 25.5894, Validation metric: 24.1738
# Estimator 528/2000, Train metric: 25.5890, Validation metric: 24.1735
# Estimator 529/2000, Train metric: 25.5887, Validation metric: 24.1732
# Estimator 530/2000, Train metric: 25.5883, Validation metric: 24.1728
# Estimator 531/2000, Train metric: 25.5880, Validation metric: 24.1721
# Estimator 532/2000, Train metric: 25.5873, Validation metric: 24.1714
# Estimator 533/2000, Train metric: 25.5830, Validation metric: 24.1671
# Estimator 534/2000, Train metric: 25.5792, Validation metric: 24.1616
# Estimator 535/2000, Train metric: 25.5777, Validation metric: 24.1606
# Estimator 536/2000, Train metric: 25.5763, Validation metric: 24.1604
# Estimator 537/2000, Train metric: 25.5728, Validation metric: 24.1561
# Estimator 538/2000, Train metric: 25.5718, Validation metric: 24.1561
# Estimator 539/2000, Train metric: 25.5711, Validation metric: 24.1557
# Estimator 540/2000, Train metric: 25.5700, Validation metric: 24.1546
# Estimator 541/2000, Train metric: 25.5694, Validation metric: 24.1542
# Estimator 542/2000, Train metric: 25.5692, Validation metric: 24.1539
# Estimator 543/2000, Train metric: 25.5690, Validation metric: 24.1536
# Estimator 544/2000, Train metric: 25.5687, Validation metric: 24.1534
# Estimator 545/2000, Train metric: 25.5684, Validation metric: 24.1533
# Estimator 546/2000, Train metric: 25.5681, Validation metric: 24.1527
# Estimator 547/2000, Train metric: 25.5651, Validation metric: 24.1498
# Estimator 548/2000, Train metric: 25.5646, Validation metric: 24.1494
# Estimator 549/2000, Train metric: 25.5642, Validation metric: 24.1492
# Estimator 550/2000, Train metric: 25.5638, Validation metric: 24.1488
# Estimator 551/2000, Train metric: 25.5636, Validation metric: 24.1485
# Estimator 552/2000, Train metric: 25.5633, Validation metric: 24.1480
# Estimator 553/2000, Train metric: 25.5627, Validation metric: 24.1479
# Estimator 554/2000, Train metric: 25.5618, Validation metric: 24.1477
# Estimator 555/2000, Train metric: 25.5615, Validation metric: 24.1475
# Estimator 556/2000, Train metric: 25.5610, Validation metric: 24.1465
# Estimator 557/2000, Train metric: 25.5607, Validation metric: 24.1461
# Estimator 558/2000, Train metric: 25.5604, Validation metric: 24.1457
# Estimator 559/2000, Train metric: 25.5600, Validation metric: 24.1454
# Estimator 560/2000, Train metric: 25.5597, Validation metric: 24.1450
# Estimator 561/2000, Train metric: 25.5592, Validation metric: 24.1448
# Estimator 562/2000, Train metric: 25.5538, Validation metric: 24.1392
# Estimator 563/2000, Train metric: 25.5534, Validation metric: 24.1387
# Estimator 564/2000, Train metric: 25.5526, Validation metric: 24.1379
# Estimator 565/2000, Train metric: 25.5518, Validation metric: 24.1362
# Estimator 566/2000, Train metric: 25.5514, Validation metric: 24.1360
# Estimator 567/2000, Train metric: 25.5474, Validation metric: 24.1262
# Estimator 568/2000, Train metric: 25.5471, Validation metric: 24.1258
# Estimator 569/2000, Train metric: 25.5446, Validation metric: 24.1206
# Estimator 570/2000, Train metric: 25.5442, Validation metric: 24.1204
# Estimator 571/2000, Train metric: 25.5438, Validation metric: 24.1201
# Estimator 572/2000, Train metric: 25.5435, Validation metric: 24.1195
# Estimator 573/2000, Train metric: 25.5432, Validation metric: 24.1190
# Estimator 574/2000, Train metric: 25.5429, Validation metric: 24.1188
# Estimator 575/2000, Train metric: 25.5426, Validation metric: 24.1185
# Estimator 576/2000, Train metric: 25.5417, Validation metric: 24.1175
# Estimator 577/2000, Train metric: 25.5412, Validation metric: 24.1171
# Estimator 578/2000, Train metric: 25.5401, Validation metric: 24.1167
# Estimator 579/2000, Train metric: 25.5394, Validation metric: 24.1162
# Estimator 580/2000, Train metric: 25.5385, Validation metric: 24.1160
# Estimator 581/2000, Train metric: 25.5377, Validation metric: 24.1149
# Estimator 582/2000, Train metric: 25.5372, Validation metric: 24.1143
# Estimator 583/2000, Train metric: 25.5366, Validation metric: 24.1137
# Estimator 584/2000, Train metric: 25.5362, Validation metric: 24.1134
# Estimator 585/2000, Train metric: 25.5359, Validation metric: 24.1134
# Estimator 586/2000, Train metric: 25.5356, Validation metric: 24.1130
# Estimator 587/2000, Train metric: 25.5349, Validation metric: 24.1119
# Estimator 588/2000, Train metric: 25.5342, Validation metric: 24.1109
# Estimator 589/2000, Train metric: 25.5259, Validation metric: 24.0690
# Estimator 590/2000, Train metric: 25.5181, Validation metric: 24.0557
# Estimator 591/2000, Train metric: 25.5167, Validation metric: 24.0531
# Estimator 592/2000, Train metric: 25.5160, Validation metric: 24.0512
# Estimator 593/2000, Train metric: 25.5157, Validation metric: 24.0508
# Estimator 594/2000, Train metric: 25.5154, Validation metric: 24.0506
# Estimator 595/2000, Train metric: 25.5146, Validation metric: 24.0504
# Estimator 596/2000, Train metric: 25.5144, Validation metric: 24.0503
# Estimator 597/2000, Train metric: 25.5141, Validation metric: 24.0497
# Estimator 598/2000, Train metric: 25.5119, Validation metric: 24.0474
# Estimator 599/2000, Train metric: 25.5110, Validation metric: 24.0474
# Estimator 600/2000, Train metric: 25.5108, Validation metric: 24.0472
# Estimator 601/2000, Train metric: 25.5106, Validation metric: 24.0471
# Estimator 602/2000, Train metric: 25.5100, Validation metric: 24.0468
# Estimator 603/2000, Train metric: 25.5097, Validation metric: 24.0467
# Estimator 604/2000, Train metric: 25.5095, Validation metric: 24.0466
# Estimator 605/2000, Train metric: 25.5091, Validation metric: 24.0462
# Estimator 606/2000, Train metric: 25.5088, Validation metric: 24.0455
# Estimator 607/2000, Train metric: 25.5086, Validation metric: 24.0454
# Estimator 608/2000, Train metric: 25.5077, Validation metric: 24.0454
# Estimator 609/2000, Train metric: 25.5074, Validation metric: 24.0449
# Estimator 610/2000, Train metric: 25.5072, Validation metric: 24.0447
# Estimator 611/2000, Train metric: 25.5068, Validation metric: 24.0445
# Estimator 612/2000, Train metric: 25.5046, Validation metric: 24.0400
# Estimator 613/2000, Train metric: 25.5044, Validation metric: 24.0398
# Estimator 614/2000, Train metric: 25.5041, Validation metric: 24.0396
# Estimator 615/2000, Train metric: 25.5033, Validation metric: 24.0386
# Estimator 616/2000, Train metric: 25.4950, Validation metric: 24.0251
# Estimator 617/2000, Train metric: 25.4943, Validation metric: 24.0239
# Estimator 618/2000, Train metric: 25.4941, Validation metric: 24.0238
# Estimator 619/2000, Train metric: 25.4934, Validation metric: 24.0227
# Estimator 620/2000, Train metric: 25.4931, Validation metric: 24.0225
# Estimator 621/2000, Train metric: 25.4928, Validation metric: 24.0222
# Estimator 622/2000, Train metric: 25.4927, Validation metric: 24.0220
# Estimator 623/2000, Train metric: 25.4922, Validation metric: 24.0219
# Estimator 624/2000, Train metric: 25.4913, Validation metric: 24.0219
# Estimator 625/2000, Train metric: 25.4906, Validation metric: 24.0214
# Estimator 626/2000, Train metric: 25.4903, Validation metric: 24.0209
# Estimator 627/2000, Train metric: 25.4889, Validation metric: 24.0197
# Estimator 628/2000, Train metric: 25.4851, Validation metric: 24.0156
# Estimator 629/2000, Train metric: 25.4836, Validation metric: 24.0149
# Estimator 630/2000, Train metric: 25.4815, Validation metric: 24.0117
# Estimator 631/2000, Train metric: 25.4811, Validation metric: 24.0112
# Estimator 632/2000, Train metric: 25.4807, Validation metric: 24.0108
# Estimator 633/2000, Train metric: 25.4741, Validation metric: 24.0045
# Estimator 634/2000, Train metric: 25.4738, Validation metric: 24.0041
# Estimator 635/2000, Train metric: 25.4733, Validation metric: 24.0035
# Estimator 636/2000, Train metric: 25.4688, Validation metric: 23.9952
# Estimator 637/2000, Train metric: 25.4686, Validation metric: 23.9949
# Estimator 638/2000, Train metric: 25.4673, Validation metric: 23.9926
# Estimator 639/2000, Train metric: 25.4671, Validation metric: 23.9923
# Estimator 640/2000, Train metric: 25.4668, Validation metric: 23.9920
# Estimator 641/2000, Train metric: 25.4653, Validation metric: 23.9930
# Estimator 642/2000, Train metric: 25.4650, Validation metric: 23.9930
# Estimator 643/2000, Train metric: 25.4648, Validation metric: 23.9927
# Estimator 644/2000, Train metric: 25.4645, Validation metric: 23.9924
# Estimator 645/2000, Train metric: 25.4643, Validation metric: 23.9923
# Estimator 646/2000, Train metric: 25.4640, Validation metric: 23.9922
# Estimator 647/2000, Train metric: 25.4634, Validation metric: 23.9920
# Estimator 648/2000, Train metric: 25.4630, Validation metric: 23.9919
# Estimator 649/2000, Train metric: 25.4623, Validation metric: 23.9910
# Estimator 650/2000, Train metric: 25.4608, Validation metric: 23.9880
# Estimator 651/2000, Train metric: 25.4605, Validation metric: 23.9878
# Estimator 652/2000, Train metric: 25.4603, Validation metric: 23.9874
# Estimator 653/2000, Train metric: 25.4598, Validation metric: 23.9865
# Estimator 654/2000, Train metric: 25.4597, Validation metric: 23.9864
# Estimator 655/2000, Train metric: 25.4583, Validation metric: 23.9861
# Estimator 656/2000, Train metric: 25.4581, Validation metric: 23.9857
# Estimator 657/2000, Train metric: 25.4562, Validation metric: 23.9821
# Estimator 658/2000, Train metric: 25.4560, Validation metric: 23.9816
# Estimator 659/2000, Train metric: 25.4558, Validation metric: 23.9815
# Estimator 660/2000, Train metric: 25.4555, Validation metric: 23.9811
# Estimator 661/2000, Train metric: 25.4554, Validation metric: 23.9810
# Estimator 662/2000, Train metric: 25.4552, Validation metric: 23.9808
# Estimator 663/2000, Train metric: 25.4545, Validation metric: 23.9807
# Estimator 664/2000, Train metric: 25.4539, Validation metric: 23.9802
# Estimator 665/2000, Train metric: 25.4537, Validation metric: 23.9802
# Estimator 666/2000, Train metric: 25.4535, Validation metric: 23.9799
# Estimator 667/2000, Train metric: 25.4533, Validation metric: 23.9798
# Estimator 668/2000, Train metric: 25.4530, Validation metric: 23.9793
# Estimator 669/2000, Train metric: 25.4520, Validation metric: 23.9778
# Estimator 670/2000, Train metric: 25.4518, Validation metric: 23.9777
# Estimator 671/2000, Train metric: 25.4516, Validation metric: 23.9776
# Estimator 672/2000, Train metric: 25.4514, Validation metric: 23.9773
# Estimator 673/2000, Train metric: 25.4512, Validation metric: 23.9769
# Estimator 674/2000, Train metric: 25.4509, Validation metric: 23.9766
# Estimator 675/2000, Train metric: 25.4507, Validation metric: 23.9764
# Estimator 676/2000, Train metric: 25.4505, Validation metric: 23.9762
# Estimator 677/2000, Train metric: 25.4457, Validation metric: 23.9533
# Estimator 678/2000, Train metric: 25.4454, Validation metric: 23.9533
# Estimator 679/2000, Train metric: 25.4448, Validation metric: 23.9526
# Estimator 680/2000, Train metric: 25.4437, Validation metric: 23.9528
# Estimator 681/2000, Train metric: 25.4401, Validation metric: 23.9486
# Estimator 682/2000, Train metric: 25.4390, Validation metric: 23.9464
# Estimator 683/2000, Train metric: 25.4373, Validation metric: 23.9415
# Estimator 684/2000, Train metric: 25.4349, Validation metric: 23.9382
# Estimator 685/2000, Train metric: 25.4342, Validation metric: 23.9368
# Estimator 686/2000, Train metric: 25.4340, Validation metric: 23.9365
# ...
# Estimator 1775/2000, Train metric: 24.9470, Validation metric: 23.1641
# Estimator 1776/2000, Train metric: 24.9470, Validation metric: 23.1641
# Estimator 1777/2000, Train metric: 24.9469, Validation metric: 23.1640
# Estimator 1778/2000, Train metric: 24.9466, Validation metric: 23.1641
# Estimator 1779/2000, Train metric: 24.9465, Validation metric: 23.1640
# Estimator 1780/2000, Train metric: 24.9464, Validation metric: 23.1640
# Estimator 1781/2000, Train metric: 24.9464, Validation metric: 23.1640
# Estimator 1782/2000, Train metric: 24.9460, Validation metric: 23.1637
# Estimator 1783/2000, Train metric: 24.9448, Validation metric: 23.1614
# Estimator 1784/2000, Train metric: 24.9447, Validation metric: 23.1614
# Estimator 1785/2000, Train metric: 24.9444, Validation metric: 23.1610
# Estimator 1786/2000, Train metric: 24.9443, Validation metric: 23.1609
# Estimator 1787/2000, Train metric: 24.9443, Validation metric: 23.1609
# Estimator 1788/2000, Train metric: 24.9442, Validation metric: 23.1608
# Estimator 1789/2000, Train metric: 24.9442, Validation metric: 23.1608
# Estimator 1790/2000, Train metric: 24.9441, Validation metric: 23.1608
# Estimator 1791/2000, Train metric: 24.9441, Validation metric: 23.1606
# Estimator 1792/2000, Train metric: 24.9440, Validation metric: 23.1606
# Estimator 1793/2000, Train metric: 24.9440, Validation metric: 23.1606
# Estimator 1794/2000, Train metric: 24.9439, Validation metric: 23.1605
# Estimator 1795/2000, Train metric: 24.9438, Validation metric: 23.1604
# Estimator 1796/2000, Train metric: 24.9437, Validation metric: 23.1603
# Estimator 1797/2000, Train metric: 24.9436, Validation metric: 23.1603
# Estimator 1798/2000, Train metric: 24.9431, Validation metric: 23.1601
# Estimator 1799/2000, Train metric: 24.9430, Validation metric: 23.1601
# Estimator 1800/2000, Train metric: 24.9430, Validation metric: 23.1601
# Estimator 1801/2000, Train metric: 24.9429, Validation metric: 23.1601
# Estimator 1802/2000, Train metric: 24.9425, Validation metric: 23.1607
# Estimator 1803/2000, Train metric: 24.9424, Validation metric: 23.1608
# Estimator 1804/2000, Train metric: 24.9423, Validation metric: 23.1607
# Estimator 1805/2000, Train metric: 24.9423, Validation metric: 23.1607
# Estimator 1806/2000, Train metric: 24.9422, Validation metric: 23.1606
# Estimator 1807/2000, Train metric: 24.9421, Validation metric: 23.1604
# Estimator 1808/2000, Train metric: 24.9421, Validation metric: 23.1604
# Estimator 1809/2000, Train metric: 24.9421, Validation metric: 23.1603
# Estimator 1810/2000, Train metric: 24.9419, Validation metric: 23.1599
# Estimator 1811/2000, Train metric: 24.9417, Validation metric: 23.1593
# Estimator 1812/2000, Train metric: 24.9416, Validation metric: 23.1593
# Estimator 1813/2000, Train metric: 24.9416, Validation metric: 23.1593
# Estimator 1814/2000, Train metric: 24.9415, Validation metric: 23.1592
# Estimator 1815/2000, Train metric: 24.9414, Validation metric: 23.1592
# Estimator 1816/2000, Train metric: 24.9413, Validation metric: 23.1591
# Estimator 1817/2000, Train metric: 24.9410, Validation metric: 23.1591
# Estimator 1818/2000, Train metric: 24.9409, Validation metric: 23.1591
# Estimator 1819/2000, Train metric: 24.9406, Validation metric: 23.1587
# Estimator 1820/2000, Train metric: 24.9405, Validation metric: 23.1585
# Estimator 1821/2000, Train metric: 24.9404, Validation metric: 23.1585
# Estimator 1822/2000, Train metric: 24.9403, Validation metric: 23.1585
# Estimator 1823/2000, Train metric: 24.9403, Validation metric: 23.1586
# Estimator 1824/2000, Train metric: 24.9401, Validation metric: 23.1584
# Estimator 1825/2000, Train metric: 24.9400, Validation metric: 23.1581
# Estimator 1826/2000, Train metric: 24.9399, Validation metric: 23.1579
# Estimator 1827/2000, Train metric: 24.9398, Validation metric: 23.1578
# Estimator 1828/2000, Train metric: 24.9398, Validation metric: 23.1578
# Estimator 1829/2000, Train metric: 24.9398, Validation metric: 23.1578
# Estimator 1830/2000, Train metric: 24.9396, Validation metric: 23.1576
# Estimator 1831/2000, Train metric: 24.9393, Validation metric: 23.1577
# Estimator 1832/2000, Train metric: 24.9393, Validation metric: 23.1576
# Estimator 1833/2000, Train metric: 24.9392, Validation metric: 23.1576
# Estimator 1834/2000, Train metric: 24.9391, Validation metric: 23.1575
# Estimator 1835/2000, Train metric: 24.9390, Validation metric: 23.1573
# Estimator 1836/2000, Train metric: 24.9390, Validation metric: 23.1572
# Estimator 1837/2000, Train metric: 24.9385, Validation metric: 23.1555
# Estimator 1838/2000, Train metric: 24.9384, Validation metric: 23.1553
# Estimator 1839/2000, Train metric: 24.9383, Validation metric: 23.1554
# Estimator 1840/2000, Train metric: 24.9383, Validation metric: 23.1554
# Estimator 1841/2000, Train metric: 24.9383, Validation metric: 23.1554
# Estimator 1842/2000, Train metric: 24.9378, Validation metric: 23.1559
# Estimator 1843/2000, Train metric: 24.9377, Validation metric: 23.1558
# Estimator 1844/2000, Train metric: 24.9376, Validation metric: 23.1557
# Estimator 1845/2000, Train metric: 24.9374, Validation metric: 23.1556
# Estimator 1846/2000, Train metric: 24.9374, Validation metric: 23.1555
# Estimator 1847/2000, Train metric: 24.9372, Validation metric: 23.1553
# Estimator 1848/2000, Train metric: 24.9368, Validation metric: 23.1545
# Estimator 1849/2000, Train metric: 24.9367, Validation metric: 23.1545
# Estimator 1850/2000, Train metric: 24.9367, Validation metric: 23.1544
# Estimator 1851/2000, Train metric: 24.9366, Validation metric: 23.1544
# Estimator 1852/2000, Train metric: 24.9366, Validation metric: 23.1543
# Estimator 1853/2000, Train metric: 24.9365, Validation metric: 23.1543
# Estimator 1854/2000, Train metric: 24.9363, Validation metric: 23.1543
# Estimator 1855/2000, Train metric: 24.9363, Validation metric: 23.1542
# Estimator 1856/2000, Train metric: 24.9362, Validation metric: 23.1540
# Estimator 1857/2000, Train metric: 24.9361, Validation metric: 23.1539
# Estimator 1858/2000, Train metric: 24.9360, Validation metric: 23.1539
# Estimator 1859/2000, Train metric: 24.9360, Validation metric: 23.1538
# Estimator 1860/2000, Train metric: 24.9359, Validation metric: 23.1538
# Estimator 1861/2000, Train metric: 24.9359, Validation metric: 23.1537
# Estimator 1862/2000, Train metric: 24.9358, Validation metric: 23.1536
# Estimator 1863/2000, Train metric: 24.9358, Validation metric: 23.1536
# Estimator 1864/2000, Train metric: 24.9336, Validation metric: 23.1506
# Estimator 1865/2000, Train metric: 24.9329, Validation metric: 23.1507
# Estimator 1866/2000, Train metric: 24.9328, Validation metric: 23.1506
# Estimator 1867/2000, Train metric: 24.9328, Validation metric: 23.1506
# Estimator 1868/2000, Train metric: 24.9328, Validation metric: 23.1506
# Estimator 1869/2000, Train metric: 24.9327, Validation metric: 23.1506
# Estimator 1870/2000, Train metric: 24.9327, Validation metric: 23.1505
# Estimator 1871/2000, Train metric: 24.9326, Validation metric: 23.1503
# Estimator 1872/2000, Train metric: 24.9324, Validation metric: 23.1503
# Estimator 1873/2000, Train metric: 24.9324, Validation metric: 23.1503
# Estimator 1874/2000, Train metric: 24.9324, Validation metric: 23.1502
# Estimator 1875/2000, Train metric: 24.9317, Validation metric: 23.1493
# Estimator 1876/2000, Train metric: 24.9316, Validation metric: 23.1490
# Estimator 1877/2000, Train metric: 24.9304, Validation metric: 23.1491
# Estimator 1878/2000, Train metric: 24.9303, Validation metric: 23.1489
# Estimator 1879/2000, Train metric: 24.9300, Validation metric: 23.1490
# Estimator 1880/2000, Train metric: 24.9250, Validation metric: 23.1296
# Estimator 1881/2000, Train metric: 24.9248, Validation metric: 23.1294
# Estimator 1882/2000, Train metric: 24.9248, Validation metric: 23.1293
# Estimator 1883/2000, Train metric: 24.9247, Validation metric: 23.1296
# Estimator 1884/2000, Train metric: 24.9246, Validation metric: 23.1296
# Estimator 1885/2000, Train metric: 24.9245, Validation metric: 23.1295
# Estimator 1886/2000, Train metric: 24.9245, Validation metric: 23.1295
# Estimator 1887/2000, Train metric: 24.9244, Validation metric: 23.1293
# Estimator 1888/2000, Train metric: 24.9243, Validation metric: 23.1292
# Estimator 1889/2000, Train metric: 24.9243, Validation metric: 23.1292
# Estimator 1890/2000, Train metric: 24.9241, Validation metric: 23.1290
# Estimator 1891/2000, Train metric: 24.9241, Validation metric: 23.1290
# Estimator 1892/2000, Train metric: 24.9237, Validation metric: 23.1286
# Estimator 1893/2000, Train metric: 24.9228, Validation metric: 23.1279
# Estimator 1894/2000, Train metric: 24.9227, Validation metric: 23.1278
# Estimator 1895/2000, Train metric: 24.9227, Validation metric: 23.1277
# Estimator 1896/2000, Train metric: 24.9226, Validation metric: 23.1277
# Estimator 1897/2000, Train metric: 24.9226, Validation metric: 23.1276
# Estimator 1898/2000, Train metric: 24.9226, Validation metric: 23.1276
# Estimator 1899/2000, Train metric: 24.9225, Validation metric: 23.1275
# Estimator 1900/2000, Train metric: 24.9225, Validation metric: 23.1275
# Estimator 1901/2000, Train metric: 24.9223, Validation metric: 23.1277
# Estimator 1902/2000, Train metric: 24.9223, Validation metric: 23.1276
# Estimator 1903/2000, Train metric: 24.9222, Validation metric: 23.1276
# Estimator 1904/2000, Train metric: 24.9222, Validation metric: 23.1276
# Estimator 1905/2000, Train metric: 24.9222, Validation metric: 23.1276
# Estimator 1906/2000, Train metric: 24.9217, Validation metric: 23.1272
# Estimator 1907/2000, Train metric: 24.9217, Validation metric: 23.1272
# Estimator 1908/2000, Train metric: 24.9207, Validation metric: 23.1274
# Estimator 1909/2000, Train metric: 24.9206, Validation metric: 23.1273
# Estimator 1910/2000, Train metric: 24.9202, Validation metric: 23.1268
# Estimator 1911/2000, Train metric: 24.9194, Validation metric: 23.1260
# Estimator 1912/2000, Train metric: 24.9180, Validation metric: 23.1239
# Estimator 1913/2000, Train metric: 24.9179, Validation metric: 23.1238
# Estimator 1914/2000, Train metric: 24.9177, Validation metric: 23.1236
# Estimator 1915/2000, Train metric: 24.9175, Validation metric: 23.1237
# Estimator 1916/2000, Train metric: 24.9160, Validation metric: 23.1223
# Estimator 1917/2000, Train metric: 24.9136, Validation metric: 23.1197
# Estimator 1918/2000, Train metric: 24.9134, Validation metric: 23.1191
# Estimator 1919/2000, Train metric: 24.9133, Validation metric: 23.1191
# Estimator 1920/2000, Train metric: 24.9131, Validation metric: 23.1187
# Estimator 1921/2000, Train metric: 24.9131, Validation metric: 23.1187
# Estimator 1922/2000, Train metric: 24.9130, Validation metric: 23.1187
# Estimator 1923/2000, Train metric: 24.9119, Validation metric: 23.1135
# Estimator 1924/2000, Train metric: 24.9115, Validation metric: 23.1059
# Estimator 1925/2000, Train metric: 24.9112, Validation metric: 23.1050
# Estimator 1926/2000, Train metric: 24.9108, Validation metric: 23.1047
# Estimator 1927/2000, Train metric: 24.9106, Validation metric: 23.1045
# Estimator 1928/2000, Train metric: 24.9105, Validation metric: 23.1042
# Estimator 1929/2000, Train metric: 24.9098, Validation metric: 23.0968
# Estimator 1930/2000, Train metric: 24.9097, Validation metric: 23.0966
# Estimator 1931/2000, Train metric: 24.9096, Validation metric: 23.0965
# Estimator 1932/2000, Train metric: 24.9096, Validation metric: 23.0965
# Estimator 1933/2000, Train metric: 24.9095, Validation metric: 23.0965
# Estimator 1934/2000, Train metric: 24.9092, Validation metric: 23.0967
# Estimator 1935/2000, Train metric: 24.9091, Validation metric: 23.0968
# Estimator 1936/2000, Train metric: 24.9090, Validation metric: 23.0966
# Estimator 1937/2000, Train metric: 24.9089, Validation metric: 23.0964
# Estimator 1938/2000, Train metric: 24.9089, Validation metric: 23.0964
# Estimator 1939/2000, Train metric: 24.9089, Validation metric: 23.0963
# Estimator 1940/2000, Train metric: 24.9089, Validation metric: 23.0963
# Estimator 1941/2000, Train metric: 24.9085, Validation metric: 23.0961
# Estimator 1942/2000, Train metric: 24.9084, Validation metric: 23.0961
# Estimator 1943/2000, Train metric: 24.9072, Validation metric: 23.0961
# Estimator 1944/2000, Train metric: 24.9071, Validation metric: 23.0960
# Estimator 1945/2000, Train metric: 24.9071, Validation metric: 23.0960
# Estimator 1946/2000, Train metric: 24.9071, Validation metric: 23.0959
# Estimator 1947/2000, Train metric: 24.9070, Validation metric: 23.0959
# Estimator 1948/2000, Train metric: 24.9069, Validation metric: 23.0957
# Estimator 1949/2000, Train metric: 24.9069, Validation metric: 23.0956
# Estimator 1950/2000, Train metric: 24.9068, Validation metric: 23.0956
# Estimator 1951/2000, Train metric: 24.9068, Validation metric: 23.0956
# Estimator 1952/2000, Train metric: 24.9067, Validation metric: 23.0955
# Estimator 1953/2000, Train metric: 24.9062, Validation metric: 23.0962
# Estimator 1954/2000, Train metric: 24.9062, Validation metric: 23.0962
# Estimator 1955/2000, Train metric: 24.9062, Validation metric: 23.0961
# Estimator 1956/2000, Train metric: 24.9060, Validation metric: 23.0959
# Estimator 1957/2000, Train metric: 24.9059, Validation metric: 23.0955
# Estimator 1958/2000, Train metric: 24.9057, Validation metric: 23.0946
# Estimator 1959/2000, Train metric: 24.9035, Validation metric: 23.0830
# Estimator 1960/2000, Train metric: 24.9031, Validation metric: 23.0829
# Estimator 1961/2000, Train metric: 24.9012, Validation metric: 23.0744
# Estimator 1962/2000, Train metric: 24.9012, Validation metric: 23.0743
# Estimator 1963/2000, Train metric: 24.9010, Validation metric: 23.0740
# Estimator 1964/2000, Train metric: 24.9010, Validation metric: 23.0740
# Estimator 1965/2000, Train metric: 24.9008, Validation metric: 23.0738
# Estimator 1966/2000, Train metric: 24.9008, Validation metric: 23.0739
# Estimator 1967/2000, Train metric: 24.9005, Validation metric: 23.0730
# Estimator 1968/2000, Train metric: 24.9004, Validation metric: 23.0729
# Estimator 1969/2000, Train metric: 24.9004, Validation metric: 23.0728
# Estimator 1970/2000, Train metric: 24.9003, Validation metric: 23.0727
# Estimator 1971/2000, Train metric: 24.9001, Validation metric: 23.0726
# Estimator 1972/2000, Train metric: 24.9000, Validation metric: 23.0725
# Estimator 1973/2000, Train metric: 24.8999, Validation metric: 23.0724
# Estimator 1974/2000, Train metric: 24.8999, Validation metric: 23.0724
# Estimator 1975/2000, Train metric: 24.8998, Validation metric: 23.0723
# Estimator 1976/2000, Train metric: 24.8998, Validation metric: 23.0723
# Estimator 1977/2000, Train metric: 24.8998, Validation metric: 23.0723
# Estimator 1978/2000, Train metric: 24.8997, Validation metric: 23.0723
# Estimator 1979/2000, Train metric: 24.8997, Validation metric: 23.0723
# Estimator 1980/2000, Train metric: 24.8997, Validation metric: 23.0722
# Estimator 1981/2000, Train metric: 24.8996, Validation metric: 23.0722
# Estimator 1982/2000, Train metric: 24.8996, Validation metric: 23.0721
# Estimator 1983/2000, Train metric: 24.8995, Validation metric: 23.0721
# Estimator 1984/2000, Train metric: 24.8995, Validation metric: 23.0720
# Estimator 1985/2000, Train metric: 24.8994, Validation metric: 23.0720
# Estimator 1986/2000, Train metric: 24.8994, Validation metric: 23.0720
# Estimator 1987/2000, Train metric: 24.8993, Validation metric: 23.0720
# Estimator 1988/2000, Train metric: 24.8991, Validation metric: 23.0717
# Estimator 1989/2000, Train metric: 24.8987, Validation metric: 23.0714
# Estimator 1990/2000, Train metric: 24.8985, Validation metric: 23.0712
# Estimator 1991/2000, Train metric: 24.8983, Validation metric: 23.0707
# Estimator 1992/2000, Train metric: 24.8982, Validation metric: 23.0705
# Estimator 1993/2000, Train metric: 24.8981, Validation metric: 23.0705
# Estimator 1994/2000, Train metric: 24.8981, Validation metric: 23.0705
# Estimator 1995/2000, Train metric: 24.8980, Validation metric: 23.0705
# Estimator 1996/2000, Train metric: 24.8980, Validation metric: 23.0704
# Estimator 1997/2000, Train metric: 24.8975, Validation metric: 23.0706
# Estimator 1998/2000, Train metric: 24.8975, Validation metric: 23.0705
# Estimator 1999/2000, Train metric: 24.8975, Validation metric: 23.0705

# %%
model.optimize_distribution(x_val.values, y_val.values.reshape(-1))
# Out:
# CRPS: 28.48 (Distribution: normal, Tree correlation: 0.000)
# CRPS: 21.50 (Distribution: normal, Tree correlation: 0.010)
# CRPS: 16.26 (Distribution: normal, Tree correlation: 0.020)
# CRPS: 12.95 (Distribution: normal, Tree correlation: 0.030)
# CRPS: 11.14 (Distribution: normal, Tree correlation: 0.040)
# CRPS: 10.18 (Distribution: normal, Tree correlation: 0.050)
# CRPS: 9.65 (Distribution: normal, Tree correlation: 0.060)
# CRPS: 9.36 (Distribution: normal, Tree correlation: 0.070)
# CRPS: 9.19 (Distribution: normal, Tree correlation: 0.080)
# CRPS: 9.11 (Distribution: normal, Tree correlation: 0.090)
# CRPS: 9.07 (Distribution: normal, Tree correlation: 0.100)
# CRPS: 9.07 (Distribution: normal, Tree correlation: 0.110)
# CRPS: 9.09 (Distribution: normal, Tree correlation: 0.120)
# CRPS: 9.12 (Distribution: normal, Tree correlation: 0.130)
# CRPS: 9.17 (Distribution: normal, Tree correlation: 0.140)
# CRPS: 9.21 (Distribution: normal, Tree correlation: 0.150)
# CRPS: 9.26 (Distribution: normal, Tree correlation: 0.160)
# CRPS: 9.31 (Distribution: normal, Tree correlation: 0.170)
# CRPS: 9.37 (Distribution: normal, Tree correlation: 0.180)
# CRPS: 9.42 (Distribution: normal, Tree correlation: 0.190)
# CRPS: 20.54 (Distribution: studentt, Tree correlation: 0.000)
# CRPS: 15.99 (Distribution: studentt, Tree correlation: 0.010)
# CRPS: 12.70 (Distribution: studentt, Tree correlation: 0.020)
# CRPS: 10.73 (Distribution: studentt, Tree correlation: 0.030)
# CRPS: 9.76 (Distribution: studentt, Tree correlation: 0.040)
# CRPS: 9.31 (Distribution: studentt, Tree correlation: 0.050)
# CRPS: 9.11 (Distribution: studentt, Tree correlation: 0.060)
# CRPS: 9.04 (Distribution: studentt, Tree correlation: 0.070)
# CRPS: 9.03 (Distribution: studentt, Tree correlation: 0.080)
# CRPS: 9.06 (Distribution: studentt, Tree correlation: 0.090)
# CRPS: 9.11 (Distribution: studentt, Tree correlation: 0.100)
# CRPS: 9.17 (Distribution: studentt, Tree correlation: 0.110)
# CRPS: 9.23 (Distribution: studentt, Tree correlation: 0.120)
# CRPS: 9.30 (Distribution: studentt, Tree correlation: 0.130)
# CRPS: 9.37 (Distribution: studentt, Tree correlation: 0.140)
# CRPS: 9.44 (Distribution: studentt, Tree correlation: 0.150)
# CRPS: 9.50 (Distribution: studentt, Tree correlation: 0.160)
# CRPS: 9.56 (Distribution: studentt, Tree correlation: 0.170)
# CRPS: 9.62 (Distribution: studentt, Tree correlation: 0.180)
# CRPS: 9.68 (Distribution: studentt, Tree correlation: 0.190)
# CRPS: 22.56 (Distribution: laplace, Tree correlation: 0.000)
# CRPS: 17.42 (Distribution: laplace, Tree correlation: 0.010)
# CRPS: 13.65 (Distribution: laplace, Tree correlation: 0.020)
# CRPS: 11.34 (Distribution: laplace, Tree correlation: 0.030)
# CRPS: 10.14 (Distribution: laplace, Tree correlation: 0.040)
# CRPS: 9.54 (Distribution: laplace, Tree correlation: 0.050)
# CRPS: 9.24 (Distribution: laplace, Tree correlation: 0.060)
# CRPS: 9.10 (Distribution: laplace, Tree correlation: 0.070)
# CRPS: 9.04 (Distribution: laplace, Tree correlation: 0.080)
# CRPS: 9.03 (Distribution: laplace, Tree correlation: 0.090)
# CRPS: 9.05 (Distribution: laplace, Tree correlation: 0.100)
# CRPS: 9.09 (Distribution: laplace, Tree correlation: 0.110)
# CRPS: 9.14 (Distribution: laplace, Tree correlation: 0.120)
# CRPS: 9.19 (Distribution: laplace, Tree correlation: 0.130)
# CRPS: 9.25 (Distribution: laplace, Tree correlation: 0.140)
# CRPS: 9.31 (Distribution: laplace, Tree correlation: 0.150)
# CRPS: 9.37 (Distribution: laplace, Tree correlation: 0.160)
# CRPS: 9.42 (Distribution: laplace, Tree correlation: 0.170)
# CRPS: 9.48 (Distribution: laplace, Tree correlation: 0.180)
# CRPS: 9.53 (Distribution: laplace, Tree correlation: 0.190)
# CRPS: 26.29 (Distribution: logistic, Tree correlation: 0.000)
# CRPS: 19.96 (Distribution: logistic, Tree correlation: 0.010)
# CRPS: 15.26 (Distribution: logistic, Tree correlation: 0.020)
# CRPS: 12.31 (Distribution: logistic, Tree correlation: 0.030)
# CRPS: 10.72 (Distribution: logistic, Tree correlation: 0.040)
# CRPS: 9.90 (Distribution: logistic, Tree correlation: 0.050)
# CRPS: 9.47 (Distribution: logistic, Tree correlation: 0.060)
# CRPS: 9.23 (Distribution: logistic, Tree correlation: 0.070)
# CRPS: 9.11 (Distribution: logistic, Tree correlation: 0.080)
# CRPS: 9.05 (Distribution: logistic, Tree correlation: 0.090)
# CRPS: 9.04 (Distribution: logistic, Tree correlation: 0.100)
# CRPS: 9.06 (Distribution: logistic, Tree correlation: 0.110)
# CRPS: 9.09 (Distribution: logistic, Tree correlation: 0.120)
# CRPS: 9.14 (Distribution: logistic, Tree correlation: 0.130)
# CRPS: 9.19 (Distribution: logistic, Tree correlation: 0.140)
# CRPS: 9.24 (Distribution: logistic, Tree correlation: 0.150)
# CRPS: 9.29 (Distribution: logistic, Tree correlation: 0.160)
# CRPS: 9.35 (Distribution: logistic, Tree correlation: 0.170)
# CRPS: 9.40 (Distribution: logistic, Tree correlation: 0.180)
# CRPS: 9.46 (Distribution: logistic, Tree correlation: 0.190)
# CRPS: 20.66 (Distribution: gamma, Tree correlation: 0.000)
# CRPS: 17.64 (Distribution: gamma, Tree correlation: 0.010)
# CRPS: 14.58 (Distribution: gamma, Tree correlation: 0.020)
# CRPS: 12.17 (Distribution: gamma, Tree correlation: 0.030)
# CRPS: 10.68 (Distribution: gamma, Tree correlation: 0.040)
# CRPS: 9.86 (Distribution: gamma, Tree correlation: 0.050)
# CRPS: 9.39 (Distribution: gamma, Tree correlation: 0.060)
# CRPS: 9.16 (Distribution: gamma, Tree correlation: 0.070)
# CRPS: 9.02 (Distribution: gamma, Tree correlation: 0.080)
# CRPS: 8.96 (Distribution: gamma, Tree correlation: 0.090)
# CRPS: 8.94 (Distribution: gamma, Tree correlation: 0.100)
# CRPS: 8.97 (Distribution: gamma, Tree correlation: 0.110)
# CRPS: 8.99 (Distribution: gamma, Tree correlation: 0.120)
# CRPS: 9.04 (Distribution: gamma, Tree correlation: 0.130)
# CRPS: 9.10 (Distribution: gamma, Tree correlation: 0.140)
# CRPS: 9.16 (Distribution: gamma, Tree correlation: 0.150)
# CRPS: 9.21 (Distribution: gamma, Tree correlation: 0.160)
# CRPS: 9.27 (Distribution: gamma, Tree correlation: 0.170)
# CRPS: 9.32 (Distribution: gamma, Tree correlation: 0.180)
# CRPS: 9.38 (Distribution: gamma, Tree correlation: 0.190)
# CRPS: 27.54 (Distribution: gumbel, Tree correlation: 0.000)
# CRPS: 20.78 (Distribution: gumbel, Tree correlation: 0.010)
# CRPS: 15.70 (Distribution: gumbel, Tree correlation: 0.020)
# CRPS: 12.51 (Distribution: gumbel, Tree correlation: 0.030)
# CRPS: 10.77 (Distribution: gumbel, Tree correlation: 0.040)
# CRPS: 9.87 (Distribution: gumbel, Tree correlation: 0.050)
# CRPS: 9.39 (Distribution: gumbel, Tree correlation: 0.060)
# CRPS: 9.13 (Distribution: gumbel, Tree correlation: 0.070)
# CRPS: 9.00 (Distribution: gumbel, Tree correlation: 0.080)
# CRPS: 8.95 (Distribution: gumbel, Tree correlation: 0.090)
# CRPS: 8.94 (Distribution: gumbel, Tree correlation: 0.100)
# CRPS: 8.97 (Distribution: gumbel, Tree correlation: 0.110)
# CRPS: 9.01 (Distribution: gumbel, Tree correlation: 0.120)
# CRPS: 9.06 (Distribution: gumbel, Tree correlation: 0.130)
# CRPS: 9.11 (Distribution: gumbel, Tree correlation: 0.140)
# CRPS: 9.18 (Distribution: gumbel, Tree correlation: 0.150)
# CRPS: 9.24 (Distribution: gumbel, Tree correlation: 0.160)
# CRPS: 9.30 (Distribution: gumbel, Tree correlation: 0.170)
# CRPS: 9.36 (Distribution: gumbel, Tree correlation: 0.180)
# CRPS: 9.42 (Distribution: gumbel, Tree correlation: 0.190)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.000)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.010)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.020)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.030)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.040)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.050)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.060)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.070)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.080)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.090)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.100)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.110)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.120)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.130)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.140)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.150)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.160)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.170)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.180)
# CRPS: 9.41 (Distribution: poisson, Tree correlation: 0.190)
# Lowest CRPS: 8.9433 (Distribution: gumbel, Tree correlation: 0.100)
# ('gumbel', 0.1)

# %%
y_train_dist = model.predict_dist(x_train.values, n_forecasts=1000)
y_val_dist = model.predict_dist(x_val.values, n_forecasts=1000)
y_test_dist = model.predict_dist(x_test.values, n_forecasts=1000)

# %%
print(model.crps_ensemble(y_train_dist, y_train.values.reshape(-1)).mean())
print(model.crps_ensemble(y_val_dist, y_val.values.reshape(-1)).mean())
print(model.crps_ensemble(y_test_dist, y_test.values.reshape(-1)).mean())
# Out:
# 9.159219991680366
# 8.886825367092108
# 9.240899956844492
